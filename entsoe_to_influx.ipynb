# %%
import logging
import pandas as pd
import os
import random
import time, datetime
from entsoe import EntsoePandasClient
from influxdb_client import InfluxDBClient, Point, WritePrecision
from influxdb_client.client.write_api import SYNCHRONOUS
from influxdb_client.client.query_api import QueryApi

# %%
# Set up logging
logging.basicConfig(filename='entsoe.log', level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logging.info('Script started at %s', pd.Timestamp.now(tz='UTC'))

# %%
# Set API key
API_KEY = '6276342c-e10c-4d88-8688-cb0a1cf163ca'

# %%
# Define InfluxDB connection details
influxdb_url = 'http://159.89.103.242:8086'
influxdb_token = 'dfRMxqDtwyHK7vDJHelAm0WKISLvKFUrmhclvaaAoMFOHRRTGNnYkV8bXd0jR9r4arvkg3l_lWNSHyKMG0WxSg=='
influxdb_org = 'entra'
influxdb_bucket = 'entra'

# %%
# Initialize the Entsoe client
client = EntsoePandasClient(api_key=API_KEY)

# %%
# Create InfluxDB client
influx_client = InfluxDBClient(url=influxdb_url, token=influxdb_token, org=influxdb_org)

# %%
# Create the write API
write_api = influx_client.write_api(write_options=SYNCHRONOUS)
# Instantiate the query API
query_api = QueryApi(influx_client)

# %%
# Define the time period
start = pd.Timestamp('2023-07-18', tz='UTC')
end = pd.Timestamp('2023-08-03', tz='UTC')

# %%
# Define the categories and their corresponding measurements
categories = {
    '6.1.A': 'actual_total_load',
    '6.1.B': 'day_ahead_total_load_forecast',
    '14.1.A': 'installed_generation_capacity',
    '16.1.B&C': 'actual_generation'
}

# Country codes
country_codes = sorted(["DE_50HZ", "IT_NORD_SI", "AL", "IT_PRGP", "DE_AMPRION", "IT_ROSN", "AT", "IT_SARD", "BY", "IT_SICI",
                 "BE", "IT_SUD", "BA", "RU_KGD", "BG", "LV", "CZ_DE_SK", "LT", "HR", "LU", "CWE", "MT", "CY", "ME",
                 "CZ", "GB", "DE_AT_LU", "NL", "DE_LU", "NO_1", "DK", "NO_2", "DK_1", "NO_3", "DK_2", "NO_4", "DK_CA",
                 "NO_5", "EE", "NO", "FI", "PL_CZ", "MK", "PL", "FR", "PT", "DE", "MD", "GR", "RO", "HU", "RU", "IS",
                 "SE_1", "IE_SEM", "SE_2", "IE", "SE_3", "IT", "SE_4", "IT_SACO_AC", "RS", "IT_SACO_DC", "SK", "IT_BRNN",
                 "SI", "IT_CNOR", "GB_NIR", "IT_CSUD", "ES", "IT_FOGN", "SE", "IT_GR", "CH", "IT_MACRO_NORTH",
                 "DE_TENNET", "IT_MACRO_SOUTH", "DE_TRANSNET", "IT_MALTA", "TR", "IT_NORD", "UA", "IT_NORD_AT",
                 "UA_DOBTPP", "IT_NORD_CH", "UA_BEI", "IT_NORD_FR", "UA_IPS"])

# %%
country_codes
# Out:
# ['AL',
#  'AT',
#  'BA',
#  'BE',
#  'BG',
#  'BY',
#  'CH',
#  'CWE',
#  'CY',
#  'CZ',
#  'CZ_DE_SK',
#  'DE',
#  'DE_50HZ',
#  'DE_AMPRION',
#  'DE_AT_LU',
#  'DE_LU',
#  'DE_TENNET',
#  'DE_TRANSNET',
#  'DK',
#  'DK_1',
#  'DK_2',
#  'DK_CA',
#  'EE',
#  'ES',
#  'FI',
#  'FR',
#  'GB',
#  'GB_NIR',
#  'GR',
#  'HR',
#  'HU',
#  'IE',
#  'IE_SEM',
#  'IS',
#  'IT',
#  'IT_BRNN',
#  'IT_CNOR',
#  'IT_CSUD',
#  'IT_FOGN',
#  'IT_GR',
#  'IT_MACRO_NORTH',
#  'IT_MACRO_SOUTH',
#  'IT_MALTA',
#  'IT_NORD',
#  'IT_NORD_AT',
#  'IT_NORD_CH',
#  'IT_NORD_FR',
#  'IT_NORD_SI',
#  'IT_PRGP',
#  'IT_ROSN',
#  'IT_SACO_AC',
#  'IT_SACO_DC',
#  'IT_SARD',
#  'IT_SICI',
#  'IT_SUD',
#  'LT',
#  'LU',
#  'LV',
#  'MD',
#  'ME',
#  'MK',
#  'MT',
#  'NL',
#  'NO',
#  'NO_1',
#  'NO_2',
#  'NO_3',
#  'NO_4',
#  'NO_5',
#  'PL',
#  'PL_CZ',
#  'PT',
#  'RO',
#  'RS',
#  'RU',
#  'RU_KGD',
#  'SE',
#  'SE_1',
#  'SE_2',
#  'SE_3',
#  'SE_4',
#  'SI',
#  'SK',
#  'TR',
#  'UA',
#  'UA_BEI',
#  'UA_DOBTPP',
#  'UA_IPS']

# %%
measurements = list(categories.values())

# %%
#Actual Total Load - 1
for country_code in country_codes:
    try:
        # Download the actual total load data
        actual_total_load = client.query_load(country_code=country_code, start=start, end=end)
        print(f"Actual Total Load for {country_code}:")
        print(actual_total_load)  # Print the data

        # Rename the columns
        actual_total_load.columns = ['value']

        # Convert the index to UTC and format it as string
        actual_total_load.index = actual_total_load.index.tz_convert('UTC').strftime('%Y-%m-%dT%H:%M:%SZ')

        # Convert the data to InfluxDB Line Protocol format
        data_points = []
        for timestamp, value in actual_total_load.iterrows():
            data_point = Point("actual_total_load") \
                .tag("country", country_code) \
                .field("value", value['value']) \
                .time(timestamp, WritePrecision.NS)
            data_points.append(data_point)
            
        write_api.write(bucket=influxdb_bucket, record=data_points)
        logging.info('Data extraction (day_ahead_total_load_forecast) completed for country: %s', country_code)
    except Exception as e:
        print(f'Data extraction (actual_total_load) failed for country: {country_code}: {str(e)}')
        logging.error(f'Data extraction (actual_total_load) failed for country: {country_code}: {str(e)}')
# Out:
# Actual Total Load for AT:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       5193.0
# 2023-07-18 02:15:00+02:00       5140.0
# 2023-07-18 02:30:00+02:00       5090.0
# 2023-07-18 02:45:00+02:00       5048.0
# 2023-07-18 03:00:00+02:00       5018.0
# ...                                ...
# 2023-08-03 00:45:00+02:00       4920.0
# 2023-08-03 01:00:00+02:00       4882.0
# 2023-08-03 01:15:00+02:00       4820.0
# 2023-08-03 01:30:00+02:00       4758.0
# 2023-08-03 01:45:00+02:00       4701.0
#
# [1536 rows x 1 columns]
# Actual Total Load for BA:
#                            Actual Load
# 2023-07-18 02:00:00+02:00        884.0
# 2023-07-18 03:00:00+02:00        848.0
# 2023-07-18 04:00:00+02:00        846.0
# 2023-07-18 05:00:00+02:00        917.0
# 2023-07-18 06:00:00+02:00       1138.0
# ...                                ...
# 2023-08-02 21:00:00+02:00       1191.0
# 2023-08-02 22:00:00+02:00       1145.0
# 2023-08-02 23:00:00+02:00       1024.0
# 2023-08-03 00:00:00+02:00        846.0
# 2023-08-03 01:00:00+02:00        769.0
#
# [384 rows x 1 columns]
# Actual Total Load for BE:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       6676.0
# 2023-07-18 02:15:00+02:00       6730.0
# 2023-07-18 02:30:00+02:00       6748.0
# 2023-07-18 02:45:00+02:00       6681.0
# 2023-07-18 03:00:00+02:00       6580.0
# ...                                ...
# 2023-08-03 00:45:00+02:00       7040.0
# 2023-08-03 01:00:00+02:00       6992.0
# 2023-08-03 01:15:00+02:00       6862.0
# 2023-08-03 01:30:00+02:00       6828.0
# 2023-08-03 01:45:00+02:00       6645.0
#
# [1536 rows x 1 columns]
# Actual Total Load for BG:
#                            Actual Load
# 2023-07-18 03:00:00+03:00       3270.0
# 2023-07-18 04:00:00+03:00       3242.0
# 2023-07-18 05:00:00+03:00       3322.0
# 2023-07-18 06:00:00+03:00       3561.0
# 2023-07-18 07:00:00+03:00       3882.0
# ...                                ...
# 2023-08-02 22:00:00+03:00       4142.0
# 2023-08-02 23:00:00+03:00       3858.0
# 2023-08-03 00:00:00+03:00       3519.0
# 2023-08-03 01:00:00+03:00       3290.0
# 2023-08-03 02:00:00+03:00       3149.0
#
# [384 rows x 1 columns]
# Actual Total Load for CH:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       5583.0
# 2023-07-18 03:00:00+02:00       5347.0
# 2023-07-18 04:00:00+02:00       5929.0
# 2023-07-18 05:00:00+02:00       5612.0
# 2023-07-18 06:00:00+02:00       6063.0
# ...                                ...
# 2023-08-02 21:00:00+02:00       6250.0
# 2023-08-02 22:00:00+02:00       6224.0
# 2023-08-02 23:00:00+02:00       6040.0
# 2023-08-03 00:00:00+02:00       6574.0
# 2023-08-03 01:00:00+02:00       5347.0
#
# [384 rows x 1 columns]
# Actual Total Load for CZ:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       5181.0
# 2023-07-18 03:00:00+02:00       5112.0
# 2023-07-18 04:00:00+02:00       5140.0
# 2023-07-18 05:00:00+02:00       5375.0
# 2023-07-18 06:00:00+02:00       6204.0
# ...                                ...
# 2023-08-02 21:00:00+02:00       5832.0
# 2023-08-02 22:00:00+02:00       5512.0
# 2023-08-02 23:00:00+02:00       5133.0
# 2023-08-03 00:00:00+02:00       4871.0
# 2023-08-03 01:00:00+02:00       4828.0
#
# [384 rows x 1 columns]
# Actual Total Load for DE:
#                            Actual Load
# 2023-07-18 02:00:00+02:00      41398.0
# 2023-07-18 02:15:00+02:00      41283.0
# 2023-07-18 02:30:00+02:00      41297.0
# 2023-07-18 02:45:00+02:00      41319.0
# 2023-07-18 03:00:00+02:00      41168.0
# ...                                ...
# 2023-08-03 00:45:00+02:00      42496.0
# 2023-08-03 01:00:00+02:00      41966.0
# 2023-08-03 01:15:00+02:00      41762.0
# 2023-08-03 01:30:00+02:00      41438.0
# 2023-08-03 01:45:00+02:00      41295.0
#
# [1536 rows x 1 columns]
# Actual Total Load for DE_50HZ:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       8943.0
# 2023-07-18 02:15:00+02:00       8899.0
# 2023-07-18 02:30:00+02:00       8897.0
# 2023-07-18 02:45:00+02:00       8989.0
# 2023-07-18 03:00:00+02:00       8988.0
# ...                                ...
# 2023-08-03 00:45:00+02:00       9178.0
# 2023-08-03 01:00:00+02:00       8948.0
# 2023-08-03 01:15:00+02:00       9064.0
# 2023-08-03 01:30:00+02:00       9091.0
# 2023-08-03 01:45:00+02:00       9175.0
#
# [1536 rows x 1 columns]
# Actual Total Load for DE_AMPRION:
#                            Actual Load
# 2023-07-18 02:00:00+02:00      14280.0
# 2023-07-18 02:15:00+02:00      14210.0
# 2023-07-18 02:30:00+02:00      14175.0
# 2023-07-18 02:45:00+02:00      14154.0
# 2023-07-18 03:00:00+02:00      14029.0
# ...                                ...
# 2023-08-03 00:45:00+02:00      15264.0
# 2023-08-03 01:00:00+02:00      15082.0
# 2023-08-03 01:15:00+02:00      14985.0
# 2023-08-03 01:30:00+02:00      14756.0
# 2023-08-03 01:45:00+02:00      14657.0
#
# [1536 rows x 1 columns]
# Actual Total Load for DE_LU:
#                            Actual Load
# 2023-07-18 02:00:00+02:00      41801.0
# 2023-07-18 02:15:00+02:00      41682.0
# 2023-07-18 02:30:00+02:00      41694.0
# 2023-07-18 02:45:00+02:00      41715.0
# 2023-07-18 03:00:00+02:00      41565.0
# ...                                ...
# 2023-08-03 00:45:00+02:00      42925.0
# 2023-08-03 01:00:00+02:00      42388.0
# 2023-08-03 01:15:00+02:00      42178.0
# 2023-08-03 01:30:00+02:00      41857.0
# 2023-08-03 01:45:00+02:00      41709.0
#
# [1536 rows x 1 columns]
# Actual Total Load for DE_TENNET:
#                            Actual Load
# 2023-07-18 02:00:00+02:00      12492.0
# 2023-07-18 02:15:00+02:00      12520.0
# 2023-07-18 02:30:00+02:00      12576.0
# 2023-07-18 02:45:00+02:00      12551.0
# 2023-07-18 03:00:00+02:00      12538.0
# ...                                ...
# 2023-08-03 00:45:00+02:00      12679.0
# 2023-08-03 01:00:00+02:00      12638.0
# 2023-08-03 01:15:00+02:00      12413.0
# 2023-08-03 01:30:00+02:00      12341.0
# 2023-08-03 01:45:00+02:00      12217.0
#
# [1536 rows x 1 columns]
# Actual Total Load for DE_TRANSNET:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       5682.0
# 2023-07-18 02:15:00+02:00       5654.0
# 2023-07-18 02:30:00+02:00       5649.0
# 2023-07-18 02:45:00+02:00       5625.0
# 2023-07-18 03:00:00+02:00       5613.0
# ...                                ...
# 2023-08-03 00:45:00+02:00       5376.0
# 2023-08-03 01:00:00+02:00       5298.0
# 2023-08-03 01:15:00+02:00       5300.0
# 2023-08-03 01:30:00+02:00       5250.0
# 2023-08-03 01:45:00+02:00       5245.0
#
# [1536 rows x 1 columns]
# Actual Total Load for DK:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       2599.0
# 2023-07-18 03:00:00+02:00       2561.0
# 2023-07-18 04:00:00+02:00       2541.0
# 2023-07-18 05:00:00+02:00       2593.0
# 2023-07-18 06:00:00+02:00       2866.0
# ...                                ...
# 2023-08-02 21:00:00+02:00       3459.0
# 2023-08-02 22:00:00+02:00       3301.0
# 2023-08-02 23:00:00+02:00       3102.0
# 2023-08-03 00:00:00+02:00       3037.0
# 2023-08-03 01:00:00+02:00       3010.0
#
# [384 rows x 1 columns]
# Actual Total Load for DK_1:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       1568.0
# 2023-07-18 03:00:00+02:00       1547.0
# 2023-07-18 04:00:00+02:00       1553.0
# 2023-07-18 05:00:00+02:00       1591.0
# 2023-07-18 06:00:00+02:00       1730.0
# ...                                ...
# 2023-08-02 21:00:00+02:00       2044.0
# 2023-08-02 22:00:00+02:00       1961.0
# 2023-08-02 23:00:00+02:00       1846.0
# 2023-08-03 00:00:00+02:00       1808.0
# 2023-08-03 01:00:00+02:00       1790.0
#
# [384 rows x 1 columns]
# Actual Total Load for DK_2:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       1031.0
# 2023-07-18 03:00:00+02:00       1014.0
# 2023-07-18 04:00:00+02:00        988.0
# 2023-07-18 05:00:00+02:00       1002.0
# 2023-07-18 06:00:00+02:00       1136.0
# ...                                ...
# 2023-08-02 21:00:00+02:00       1415.0
# 2023-08-02 22:00:00+02:00       1340.0
# 2023-08-02 23:00:00+02:00       1256.0
# 2023-08-03 00:00:00+02:00       1228.0
# 2023-08-03 01:00:00+02:00       1220.0
#
# [384 rows x 1 columns]
# Actual Total Load for DK_CA:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       2599.0
# 2023-07-18 03:00:00+02:00       2561.0
# 2023-07-18 04:00:00+02:00       2541.0
# 2023-07-18 05:00:00+02:00       2593.0
# 2023-07-18 06:00:00+02:00       2866.0
# ...                                ...
# 2023-08-02 21:00:00+02:00       3459.0
# 2023-08-02 22:00:00+02:00       3301.0
# 2023-08-02 23:00:00+02:00       3102.0
# 2023-08-03 00:00:00+02:00       3037.0
# 2023-08-03 01:00:00+02:00       3010.0
#
# [384 rows x 1 columns]
# Actual Total Load for EE:
#                            Actual Load
# 2023-07-18 03:00:00+03:00        584.0
# 2023-07-18 04:00:00+03:00        567.0
# 2023-07-18 05:00:00+03:00        571.0
# 2023-07-18 06:00:00+03:00        662.0
# 2023-07-18 07:00:00+03:00        754.0
# ...                                ...
# 2023-08-02 22:00:00+03:00        793.0
# 2023-08-02 23:00:00+03:00        722.0
# 2023-08-03 00:00:00+03:00        666.0
# 2023-08-03 01:00:00+03:00        641.0
# 2023-08-03 02:00:00+03:00        624.0
#
# [384 rows x 1 columns]
# Actual Total Load for ES:
#                            Actual Load
# 2023-07-18 02:00:00+02:00      27176.0
# 2023-07-18 02:15:00+02:00      26976.0
# 2023-07-18 02:30:00+02:00      26708.0
# 2023-07-18 02:45:00+02:00      26396.0
# 2023-07-18 03:00:00+02:00      25968.0
# ...                                ...
# 2023-08-03 00:45:00+02:00      27676.0
# 2023-08-03 01:00:00+02:00      27160.0
# 2023-08-03 01:15:00+02:00      26696.0
# 2023-08-03 01:30:00+02:00      26288.0
# 2023-08-03 01:45:00+02:00      26012.0
#
# [1536 rows x 1 columns]
# Actual Total Load for FI:
#                            Actual Load
# 2023-07-18 03:00:00+03:00       6362.0
# 2023-07-18 03:15:00+03:00       6303.0
# 2023-07-18 03:30:00+03:00       6375.0
# 2023-07-18 03:45:00+03:00       6310.0
# 2023-07-18 04:00:00+03:00       6337.0
# ...                                ...
# 2023-08-03 01:45:00+03:00       6629.0
# 2023-08-03 02:00:00+03:00       6600.0
# 2023-08-03 02:15:00+03:00       6559.0
# 2023-08-03 02:30:00+03:00       6514.0
# 2023-08-03 02:45:00+03:00       6573.0
#
# [1536 rows x 1 columns]
# Actual Total Load for FR:
#                            Actual Load
# 2023-07-18 02:00:00+02:00      38898.0
# 2023-07-18 03:00:00+02:00      36886.0
# 2023-07-18 04:00:00+02:00      36295.0
# 2023-07-18 05:00:00+02:00      37618.0
# 2023-07-18 06:00:00+02:00      39810.0
# ...                                ...
# 2023-08-02 21:00:00+02:00      41238.0
# 2023-08-02 22:00:00+02:00      42143.0
# 2023-08-02 23:00:00+02:00      41605.0
# 2023-08-03 00:00:00+02:00      38204.0
# 2023-08-03 01:00:00+02:00      36086.0
#
# [384 rows x 1 columns]
# Actual Total Load for GR:
#                            Actual Load
# 2023-07-18 03:00:00+03:00       6304.0
# 2023-07-18 04:00:00+03:00       6170.0
# 2023-07-18 05:00:00+03:00       6177.0
# 2023-07-18 06:00:00+03:00       6217.0
# 2023-07-18 07:00:00+03:00       6841.0
# ...                                ...
# 2023-08-02 22:00:00+03:00       7721.0
# 2023-08-02 23:00:00+03:00       7379.0
# 2023-08-03 00:00:00+03:00       6935.0
# 2023-08-03 01:00:00+03:00       6501.0
# 2023-08-03 02:00:00+03:00       6222.0
#
# [384 rows x 1 columns]
# Actual Total Load for HR:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       1976.0
# 2023-07-18 03:00:00+02:00       1915.0
# 2023-07-18 04:00:00+02:00       1907.0
# 2023-07-18 05:00:00+02:00       1917.0
# 2023-07-18 06:00:00+02:00       2166.0
# ...                                ...
# 2023-08-02 21:00:00+02:00       2574.0
# 2023-08-02 22:00:00+02:00       2453.0
# 2023-08-02 23:00:00+02:00       2219.0
# 2023-08-03 00:00:00+02:00       1977.0
# 2023-08-03 01:00:00+02:00       1799.0
#
# [384 rows x 1 columns]
# Actual Total Load for HU:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       4367.0
# 2023-07-18 02:15:00+02:00       4345.0
# 2023-07-18 02:30:00+02:00       4340.0
# 2023-07-18 02:45:00+02:00       4309.0
# 2023-07-18 03:00:00+02:00       4289.0
# ...                                ...
# 2023-08-03 00:45:00+02:00       4079.0
# 2023-08-03 01:00:00+02:00       4018.0
# 2023-08-03 01:15:00+02:00       3959.0
# 2023-08-03 01:30:00+02:00       3891.0
# 2023-08-03 01:45:00+02:00       3835.0
#
# [1536 rows x 1 columns]
# Actual Total Load for IT:
#                            Actual Load
# 2023-07-18 02:00:00+02:00      32618.0
# 2023-07-18 03:00:00+02:00      31866.0
# 2023-07-18 04:00:00+02:00      31733.0
# 2023-07-18 05:00:00+02:00      32119.0
# 2023-07-18 06:00:00+02:00      34961.0
# ...                                ...
# 2023-08-02 21:00:00+02:00      38959.0
# 2023-08-02 22:00:00+02:00      35976.0
# 2023-08-02 23:00:00+02:00      33013.0
# 2023-08-03 00:00:00+02:00      30362.0
# 2023-08-03 01:00:00+02:00      28518.0
#
# [384 rows x 1 columns]
# Actual Total Load for IT_CNOR:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       2567.0
# 2023-07-18 03:00:00+02:00       2527.0
# 2023-07-18 04:00:00+02:00       2521.0
# 2023-07-18 05:00:00+02:00       2581.0
# 2023-07-18 06:00:00+02:00       2915.0
# ...                                ...
# 2023-08-02 21:00:00+02:00       3312.0
# 2023-08-02 22:00:00+02:00       3055.0
# 2023-08-02 23:00:00+02:00       2807.0
# 2023-08-03 00:00:00+02:00       2540.0
# 2023-08-03 01:00:00+02:00       2412.0
#
# [384 rows x 1 columns]
# Actual Total Load for IT_CSUD:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       5472.0
# 2023-07-18 03:00:00+02:00       5324.0
# 2023-07-18 04:00:00+02:00       5173.0
# 2023-07-18 05:00:00+02:00       5226.0
# 2023-07-18 06:00:00+02:00       5658.0
# ...                                ...
# 2023-08-02 21:00:00+02:00       6719.0
# 2023-08-02 22:00:00+02:00       6293.0
# 2023-08-02 23:00:00+02:00       5697.0
# 2023-08-03 00:00:00+02:00       5195.0
# 2023-08-03 01:00:00+02:00       4800.0
#
# [384 rows x 1 columns]
# Actual Total Load for IT_NORD:
#                            Actual Load
# 2023-07-18 02:00:00+02:00      18036.0
# 2023-07-18 03:00:00+02:00      17687.0
# 2023-07-18 04:00:00+02:00      17749.0
# 2023-07-18 05:00:00+02:00      18030.0
# 2023-07-18 06:00:00+02:00      19972.0
# ...                                ...
# 2023-08-02 21:00:00+02:00      20550.0
# 2023-08-02 22:00:00+02:00      18770.0
# 2023-08-02 23:00:00+02:00      17072.0
# 2023-08-03 00:00:00+02:00      15676.0
# 2023-08-03 01:00:00+02:00      14660.0
#
# [384 rows x 1 columns]
# Actual Total Load for IT_SARD:
#                            Actual Load
# 2023-07-18 02:00:00+02:00        987.0
# 2023-07-18 03:00:00+02:00        963.0
# 2023-07-18 04:00:00+02:00        949.0
# 2023-07-18 05:00:00+02:00        959.0
# 2023-07-18 06:00:00+02:00        980.0
# ...                                ...
# 2023-08-02 21:00:00+02:00       1289.0
# 2023-08-02 22:00:00+02:00       1209.0
# 2023-08-02 23:00:00+02:00       1118.0
# 2023-08-03 00:00:00+02:00       1026.0
# 2023-08-03 01:00:00+02:00        959.0
#
# [384 rows x 1 columns]
# Actual Total Load for IT_SICI:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       2232.0
# 2023-07-18 03:00:00+02:00       2170.0
# 2023-07-18 04:00:00+02:00       2130.0
# 2023-07-18 05:00:00+02:00       2121.0
# 2023-07-18 06:00:00+02:00       2125.0
# ...                                ...
# 2023-08-02 21:00:00+02:00       2817.0
# 2023-08-02 22:00:00+02:00       2682.0
# 2023-08-02 23:00:00+02:00       2527.0
# 2023-08-03 00:00:00+02:00       2342.0
# 2023-08-03 01:00:00+02:00       2203.0
#
# [384 rows x 1 columns]
# Actual Total Load for IT_SUD:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       2651.0
# 2023-07-18 03:00:00+02:00       2546.0
# 2023-07-18 04:00:00+02:00       2559.0
# 2023-07-18 05:00:00+02:00       2555.0
# 2023-07-18 06:00:00+02:00       2560.0
# ...                                ...
# 2023-08-02 21:00:00+02:00       3144.0
# 2023-08-02 22:00:00+02:00       2939.0
# 2023-08-02 23:00:00+02:00       2767.0
# 2023-08-03 00:00:00+02:00       2656.0
# 2023-08-03 01:00:00+02:00       2549.0
#
# [384 rows x 1 columns]
# Actual Total Load for LT:
#                            Actual Load
# 2023-07-18 03:00:00+03:00        971.0
# 2023-07-18 04:00:00+03:00        984.0
# 2023-07-18 05:00:00+03:00       1004.0
# 2023-07-18 06:00:00+03:00       1140.0
# 2023-07-18 07:00:00+03:00       1282.0
# ...                                ...
# 2023-08-02 22:00:00+03:00       1288.0
# 2023-08-02 23:00:00+03:00       1154.0
# 2023-08-03 00:00:00+03:00       1061.0
# 2023-08-03 01:00:00+03:00       1011.0
# 2023-08-03 02:00:00+03:00        984.0
#
# [384 rows x 1 columns]
# Actual Total Load for LU:
#                            Actual Load
# 2023-07-18 02:00:00+02:00        403.0
# 2023-07-18 02:15:00+02:00        399.0
# 2023-07-18 02:30:00+02:00        397.0
# 2023-07-18 02:45:00+02:00        396.0
# 2023-07-18 03:00:00+02:00        397.0
# ...                                ...
# 2023-08-03 00:45:00+02:00        429.0
# 2023-08-03 01:00:00+02:00        423.0
# 2023-08-03 01:15:00+02:00        416.0
# 2023-08-03 01:30:00+02:00        419.0
# 2023-08-03 01:45:00+02:00        414.0
#
# [1536 rows x 1 columns]
# Actual Total Load for LV:
#                            Actual Load
# 2023-07-18 03:00:00+03:00        501.0
# 2023-07-18 04:00:00+03:00        489.0
# 2023-07-18 05:00:00+03:00        501.0
# 2023-07-18 06:00:00+03:00        568.0
# 2023-07-18 07:00:00+03:00        657.0
# ...                                ...
# 2023-08-02 22:00:00+03:00        726.0
# 2023-08-02 23:00:00+03:00        659.0
# 2023-08-03 00:00:00+03:00        593.0
# 2023-08-03 01:00:00+03:00        552.0
# 2023-08-03 02:00:00+03:00        536.0
#
# [384 rows x 1 columns]
# Actual Total Load for MD:
#                            Actual Load
# 2023-07-18 03:00:00+03:00        441.0
# 2023-07-18 04:00:00+03:00        434.0
# 2023-07-18 05:00:00+03:00        450.0
# 2023-07-18 06:00:00+03:00        513.0
# 2023-07-18 07:00:00+03:00        583.0
# ...                                ...
# 2023-08-02 22:00:00+03:00        714.0
# 2023-08-02 23:00:00+03:00        639.0
# 2023-08-03 00:00:00+03:00        559.0
# 2023-08-03 01:00:00+03:00        532.0
# 2023-08-03 02:00:00+03:00        508.0
#
# [380 rows x 1 columns]
# Actual Total Load for ME:
#                            Actual Load
# 2023-07-18 02:00:00+02:00        312.0
# 2023-07-18 03:00:00+02:00        283.0
# 2023-07-18 04:00:00+02:00        272.0
# 2023-07-18 05:00:00+02:00        269.0
# 2023-07-18 06:00:00+02:00        301.0
# ...                                ...
# 2023-08-02 21:00:00+02:00        479.0
# 2023-08-02 22:00:00+02:00        444.0
# 2023-08-02 23:00:00+02:00        408.0
# 2023-08-03 00:00:00+02:00        362.0
# 2023-08-03 01:00:00+02:00        312.0
#
# [384 rows x 1 columns]
# Actual Total Load for MK:
#                            Actual Load
# 2023-07-18 02:00:00+02:00        547.0
# 2023-07-18 03:00:00+02:00        508.0
# 2023-07-18 04:00:00+02:00        494.0
# 2023-07-18 05:00:00+02:00        505.0
# 2023-07-18 06:00:00+02:00        513.0
# ...                                ...
# 2023-08-02 21:00:00+02:00        661.0
# 2023-08-02 22:00:00+02:00        687.0
# 2023-08-02 23:00:00+02:00        656.0
# 2023-08-03 00:00:00+02:00        588.0
# 2023-08-03 01:00:00+02:00        520.0
#
# [384 rows x 1 columns]
# Actual Total Load for NL:
#                            Actual Load
# 2023-07-18 02:00:00+02:00      11521.0
# 2023-07-18 02:15:00+02:00      11471.0
# 2023-07-18 02:30:00+02:00      11423.0
# 2023-07-18 02:45:00+02:00      11422.0
# 2023-07-18 03:00:00+02:00      11433.0
# ...                                ...
# 2023-08-03 00:45:00+02:00      10184.0
# 2023-08-03 01:00:00+02:00      10201.0
# 2023-08-03 01:15:00+02:00      10199.0
# 2023-08-03 01:30:00+02:00      10231.0
# 2023-08-03 01:45:00+02:00      10253.0
#
# [1533 rows x 1 columns]
# Actual Total Load for NO:
#                            Actual Load
# 2023-07-18 02:00:00+02:00      10426.0
# 2023-07-18 03:00:00+02:00      10263.0
# 2023-07-18 04:00:00+02:00      10010.0
# 2023-07-18 05:00:00+02:00      10171.0
# 2023-07-18 06:00:00+02:00      10712.0
# ...                                ...
# 2023-08-02 21:00:00+02:00      11662.0
# 2023-08-02 22:00:00+02:00      11632.0
# 2023-08-02 23:00:00+02:00      11404.0
# 2023-08-03 00:00:00+02:00      10923.0
# 2023-08-03 01:00:00+02:00      10517.0
#
# [384 rows x 1 columns]
# Actual Total Load for NO_1:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       1949.0
# 2023-07-18 03:00:00+02:00       1911.0
# 2023-07-18 04:00:00+02:00       1851.0
# 2023-07-18 05:00:00+02:00       1947.0
# 2023-07-18 06:00:00+02:00       2052.0
# ...                                ...
# 2023-08-02 21:00:00+02:00       2552.0
# 2023-08-02 22:00:00+02:00       2498.0
# 2023-08-02 23:00:00+02:00       2381.0
# 2023-08-03 00:00:00+02:00       2250.0
# 2023-08-03 01:00:00+02:00       2167.0
#
# [384 rows x 1 columns]
# Actual Total Load for NO_2:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       2910.0
# 2023-07-18 03:00:00+02:00       2894.0
# 2023-07-18 04:00:00+02:00       2969.0
# 2023-07-18 05:00:00+02:00       2989.0
# 2023-07-18 06:00:00+02:00       3102.0
# ...                                ...
# 2023-08-02 21:00:00+02:00       3250.0
# 2023-08-02 22:00:00+02:00       3241.0
# 2023-08-02 23:00:00+02:00       3052.0
# 2023-08-03 00:00:00+02:00       2952.0
# 2023-08-03 01:00:00+02:00       2866.0
#
# [384 rows x 1 columns]
# Actual Total Load for NO_3:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       2382.0
# 2023-07-18 03:00:00+02:00       2369.0
# 2023-07-18 04:00:00+02:00       2233.0
# 2023-07-18 05:00:00+02:00       2240.0
# 2023-07-18 06:00:00+02:00       2387.0
# ...                                ...
# 2023-08-02 21:00:00+02:00       2621.0
# 2023-08-02 22:00:00+02:00       2661.0
# 2023-08-02 23:00:00+02:00       2623.0
# 2023-08-03 00:00:00+02:00       2584.0
# 2023-08-03 01:00:00+02:00       2495.0
#
# [384 rows x 1 columns]
# Actual Total Load for NO_4:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       1666.0
# 2023-07-18 03:00:00+02:00       1605.0
# 2023-07-18 04:00:00+02:00       1583.0
# 2023-07-18 05:00:00+02:00       1623.0
# 2023-07-18 06:00:00+02:00       1702.0
# ...                                ...
# 2023-08-02 21:00:00+02:00       1713.0
# 2023-08-02 22:00:00+02:00       1727.0
# 2023-08-02 23:00:00+02:00       1840.0
# 2023-08-03 00:00:00+02:00       1669.0
# 2023-08-03 01:00:00+02:00       1560.0
#
# [384 rows x 1 columns]
# Actual Total Load for NO_5:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       1519.0
# 2023-07-18 03:00:00+02:00       1483.0
# 2023-07-18 04:00:00+02:00       1375.0
# 2023-07-18 05:00:00+02:00       1372.0
# 2023-07-18 06:00:00+02:00       1467.0
# ...                                ...
# 2023-08-02 21:00:00+02:00       1527.0
# 2023-08-02 22:00:00+02:00       1505.0
# 2023-08-02 23:00:00+02:00       1508.0
# 2023-08-03 00:00:00+02:00       1467.0
# 2023-08-03 01:00:00+02:00       1429.0
#
# [384 rows x 1 columns]
# Actual Total Load for PL:
#                            Actual Load
# 2023-07-18 02:00:00+02:00      15165.0
# 2023-07-18 03:00:00+02:00      14904.0
# 2023-07-18 04:00:00+02:00      14841.0
# 2023-07-18 05:00:00+02:00      15067.0
# 2023-07-18 06:00:00+02:00      17231.0
# ...                                ...
# 2023-08-02 21:00:00+02:00      18858.0
# 2023-08-02 22:00:00+02:00      17430.0
# 2023-08-02 23:00:00+02:00      15936.0
# 2023-08-03 00:00:00+02:00      14887.0
# 2023-08-03 01:00:00+02:00      14295.0
#
# [384 rows x 1 columns]
# Actual Total Load for PT:
#                            Actual Load
# 2023-07-18 01:00:00+01:00       5065.0
# 2023-07-18 02:00:00+01:00       4894.0
# 2023-07-18 03:00:00+01:00       4786.0
# 2023-07-18 04:00:00+01:00       4743.0
# 2023-07-18 05:00:00+01:00       4779.0
# ...                                ...
# 2023-08-02 20:00:00+01:00       6775.0
# 2023-08-02 21:00:00+01:00       6704.0
# 2023-08-02 22:00:00+01:00       6275.0
# 2023-08-02 23:00:00+01:00       5682.0
# 2023-08-03 00:00:00+01:00       5415.0
#
# [384 rows x 1 columns]
# Actual Total Load for RO:
#                            Actual Load
# 2023-07-18 03:00:00+03:00       5583.0
# 2023-07-18 03:15:00+03:00       5487.0
# 2023-07-18 03:30:00+03:00       5439.0
# 2023-07-18 03:45:00+03:00       5467.0
# 2023-07-18 04:00:00+03:00       5569.0
# ...                                ...
# 2023-08-03 01:45:00+03:00       5177.0
# 2023-08-03 02:00:00+03:00       5222.0
# 2023-08-03 02:15:00+03:00       5184.0
# 2023-08-03 02:30:00+03:00       5092.0
# 2023-08-03 02:45:00+03:00       5065.0
#
# [1529 rows x 1 columns]
# Actual Total Load for RS:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       3154.0
# 2023-07-18 03:00:00+02:00       3044.0
# 2023-07-18 04:00:00+02:00       2979.0
# 2023-07-18 05:00:00+02:00       2989.0
# 2023-07-18 06:00:00+02:00       3331.0
# ...                                ...
# 2023-08-02 21:00:00+02:00       3692.0
# 2023-08-02 22:00:00+02:00       3543.0
# 2023-08-02 23:00:00+02:00       3374.0
# 2023-08-03 00:00:00+02:00       3124.0
# 2023-08-03 01:00:00+02:00       2861.0
#
# [384 rows x 1 columns]
# Actual Total Load for SE:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       9862.0
# 2023-07-18 03:00:00+02:00       9457.0
# 2023-07-18 04:00:00+02:00       9311.0
# 2023-07-18 05:00:00+02:00       9238.0
# 2023-07-18 06:00:00+02:00       9920.0
# ...                                ...
# 2023-08-02 21:00:00+02:00      11519.0
# 2023-08-02 22:00:00+02:00      11237.0
# 2023-08-02 23:00:00+02:00      10564.0
# 2023-08-03 00:00:00+02:00      10382.0
# 2023-08-03 01:00:00+02:00      10283.0
#
# [384 rows x 1 columns]
# Actual Total Load for SE_1:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       1217.0
# 2023-07-18 03:00:00+02:00        921.0
# 2023-07-18 04:00:00+02:00        918.0
# 2023-07-18 05:00:00+02:00        898.0
# 2023-07-18 06:00:00+02:00        897.0
# ...                                ...
# 2023-08-02 21:00:00+02:00       1034.0
# 2023-08-02 22:00:00+02:00        925.0
# 2023-08-02 23:00:00+02:00        774.0
# 2023-08-03 00:00:00+02:00        889.0
# 2023-08-03 01:00:00+02:00       1079.0
#
# [384 rows x 1 columns]
# Actual Total Load for SE_2:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       1255.0
# 2023-07-18 03:00:00+02:00       1151.0
# 2023-07-18 04:00:00+02:00       1154.0
# 2023-07-18 05:00:00+02:00        957.0
# 2023-07-18 06:00:00+02:00       1105.0
# ...                                ...
# 2023-08-02 21:00:00+02:00       1180.0
# 2023-08-02 22:00:00+02:00       1275.0
# 2023-08-02 23:00:00+02:00       1215.0
# 2023-08-03 00:00:00+02:00       1216.0
# 2023-08-03 01:00:00+02:00       1321.0
#
# [384 rows x 1 columns]
# Actual Total Load for SE_3:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       5878.0
# 2023-07-18 03:00:00+02:00       5848.0
# 2023-07-18 04:00:00+02:00       5720.0
# 2023-07-18 05:00:00+02:00       5808.0
# 2023-07-18 06:00:00+02:00       6166.0
# ...                                ...
# 2023-08-02 21:00:00+02:00       7320.0
# 2023-08-02 22:00:00+02:00       7093.0
# 2023-08-02 23:00:00+02:00       6717.0
# 2023-08-03 00:00:00+02:00       6445.0
# 2023-08-03 01:00:00+02:00       6215.0
#
# [384 rows x 1 columns]
# Actual Total Load for SE_4:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       1512.0
# 2023-07-18 03:00:00+02:00       1537.0
# 2023-07-18 04:00:00+02:00       1519.0
# 2023-07-18 05:00:00+02:00       1575.0
# 2023-07-18 06:00:00+02:00       1752.0
# ...                                ...
# 2023-08-02 21:00:00+02:00       1985.0
# 2023-08-02 22:00:00+02:00       1944.0
# 2023-08-02 23:00:00+02:00       1858.0
# 2023-08-03 00:00:00+02:00       1832.0
# 2023-08-03 01:00:00+02:00       1668.0
#
# [384 rows x 1 columns]
# Actual Total Load for SI:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       1211.0
# 2023-07-18 03:00:00+02:00       1216.0
# 2023-07-18 04:00:00+02:00       1218.0
# 2023-07-18 05:00:00+02:00       1258.0
# 2023-07-18 06:00:00+02:00       1504.0
# ...                                ...
# 2023-08-02 21:00:00+02:00       1227.0
# 2023-08-02 22:00:00+02:00       1150.0
# 2023-08-02 23:00:00+02:00       1036.0
# 2023-08-03 00:00:00+02:00        980.0
# 2023-08-03 01:00:00+02:00        928.0
#
# [384 rows x 1 columns]
# Actual Total Load for SK:
#                            Actual Load
# 2023-07-18 02:00:00+02:00       2330.0
# 2023-07-18 03:00:00+02:00       2306.0
# 2023-07-18 04:00:00+02:00       2346.0
# 2023-07-18 05:00:00+02:00       2417.0
# 2023-07-18 06:00:00+02:00       2712.0
# ...                                ...
# 2023-08-02 21:00:00+02:00       2705.0
# 2023-08-02 22:00:00+02:00       2528.0
# 2023-08-02 23:00:00+02:00       2357.0
# 2023-08-03 00:00:00+02:00       2247.0
# 2023-08-03 01:00:00+02:00       2151.0
#
# [384 rows x 1 columns]

# %%
# Download day-ahead total load forecast - 2
for country_code in country_codes:
    try:
        day_ahead_total_load_forecast = client.query_load_forecast(country_code=country_code, start=start, end=end)
        print(f"Day-Ahead Total Load Forecast for {country_code}:")
        print(day_ahead_total_load_forecast)  # Print the data
        
        # Rename the columns
        day_ahead_total_load_forecast.columns = ['value']

        # Convert the index to UTC and format it as string
        day_ahead_total_load_forecast.index = day_ahead_total_load_forecast.index.tz_convert('UTC').strftime('%Y-%m-%dT%H:%M:%SZ')

        # Convert the data to InfluxDB Line Protocol format
        data_points = []
        for timestamp, value in day_ahead_total_load_forecast.iterrows():
            data_point = Point("day_ahead_total_load_forecast") \
                .tag("country", country_code) \
                .field("value", value['value']) \
                .time(timestamp, WritePrecision.NS)
            data_points.append(data_point)

        # Write data points to InfluxDB
        write_api.write(bucket=influxdb_bucket, record=data_points)
        logging.info('Data extraction (day_ahead_total_load_forecast) completed for country: %s', country_code)

    except Exception as e:
        print(f'Data extraction (day_ahead_total_load_forecast) failed for {country_code}: {str(e)}')
        logging.error(f'Data extraction (day_ahead_total_load_forecast) failed for {country_code}: {str(e)}')
# Out:
# Day-Ahead Total Load Forecast for AL:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00            629.0
# 2023-07-18 02:15:00+02:00            629.0
# 2023-07-18 02:30:00+02:00            629.0
# 2023-07-18 02:45:00+02:00            629.0
# 2023-07-18 03:00:00+02:00            597.0
# ...                                    ...
# 2023-08-03 01:00:00+02:00            664.0
# 2023-08-03 01:15:00+02:00            664.0
# 2023-08-03 01:30:00+02:00            664.0
# 2023-08-03 01:45:00+02:00            664.0
# 2023-08-03 02:00:00+02:00            624.0
#
# [1537 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for AL: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for AT:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           5116.0
# 2023-07-18 02:15:00+02:00           5064.0
# 2023-07-18 02:30:00+02:00           5016.0
# 2023-07-18 02:45:00+02:00           4980.0
# 2023-07-18 03:00:00+02:00           4976.0
# ...                                    ...
# 2023-08-03 01:00:00+02:00           5044.0
# 2023-08-03 01:15:00+02:00           4980.0
# 2023-08-03 01:30:00+02:00           4916.0
# 2023-08-03 01:45:00+02:00           4872.0
# 2023-08-03 02:00:00+02:00           4948.0
#
# [1537 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for AT: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for BA:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00            909.0
# 2023-07-18 03:00:00+02:00            896.0
# 2023-07-18 04:00:00+02:00            900.0
# 2023-07-18 05:00:00+02:00            889.0
# 2023-07-18 06:00:00+02:00           1041.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           1248.0
# 2023-08-02 23:00:00+02:00           1134.0
# 2023-08-03 00:00:00+02:00           1020.0
# 2023-08-03 01:00:00+02:00            943.0
# 2023-08-03 02:00:00+02:00            902.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for BA: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for BE:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           7103.0
# 2023-07-18 02:15:00+02:00           7042.0
# 2023-07-18 02:30:00+02:00           6999.0
# 2023-07-18 02:45:00+02:00           7000.0
# 2023-07-18 03:00:00+02:00           7015.0
# ...                                    ...
# 2023-08-03 01:00:00+02:00           6976.0
# 2023-08-03 01:15:00+02:00           6948.0
# 2023-08-03 01:30:00+02:00           6879.0
# 2023-08-03 01:45:00+02:00           6792.0
# 2023-08-03 02:00:00+02:00           6790.0
#
# [1537 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for BE: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for BG:
#                            Forecasted Load
# 2023-07-18 03:00:00+03:00           3277.0
# 2023-07-18 04:00:00+03:00           3270.0
# 2023-07-18 05:00:00+03:00           3348.0
# 2023-07-18 06:00:00+03:00           3598.0
# 2023-07-18 07:00:00+03:00           3867.0
# ...                                    ...
# 2023-08-02 23:00:00+03:00           3901.0
# 2023-08-03 00:00:00+03:00           3563.0
# 2023-08-03 01:00:00+03:00           3299.0
# 2023-08-03 02:00:00+03:00           3159.0
# 2023-08-03 03:00:00+03:00           3086.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for BG: name 'write_api' is not defined
# Data extraction (day_ahead_total_load_forecast) failed for BY:
# Day-Ahead Total Load Forecast for CH:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           5381.0
# 2023-07-18 03:00:00+02:00           5443.0
# 2023-07-18 04:00:00+02:00           5809.0
# 2023-07-18 05:00:00+02:00           5490.0
# 2023-07-18 06:00:00+02:00           5850.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           6157.0
# 2023-08-02 23:00:00+02:00           6122.0
# 2023-08-03 00:00:00+02:00           6233.0
# 2023-08-03 01:00:00+02:00           5354.0
# 2023-08-03 02:00:00+02:00           5379.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for CH: name 'write_api' is not defined
# Data extraction (day_ahead_total_load_forecast) failed for CWE: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A65&processType=A01&outBiddingZone_Domain=10YDOM-REGION-1V&securityToken=6276342c-e10c-4d88-8688-cb0a1cf163ca&periodStart=202307180000&periodEnd=202308030000
# Data extraction (day_ahead_total_load_forecast) failed for CY:
# Day-Ahead Total Load Forecast for CZ:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           5214.0
# 2023-07-18 03:00:00+02:00           5134.0
# 2023-07-18 04:00:00+02:00           5186.0
# 2023-07-18 05:00:00+02:00           5428.0
# 2023-07-18 06:00:00+02:00           6339.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           5499.0
# 2023-08-02 23:00:00+02:00           5092.0
# 2023-08-03 00:00:00+02:00           4774.0
# 2023-08-03 01:00:00+02:00           4715.0
# 2023-08-03 02:00:00+02:00           4555.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for CZ: name 'write_api' is not defined
# Data extraction (day_ahead_total_load_forecast) failed for CZ_DE_SK:
# Day-Ahead Total Load Forecast for DE:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00          40002.0
# 2023-07-18 02:15:00+02:00          39776.0
# 2023-07-18 02:30:00+02:00          39739.0
# 2023-07-18 02:45:00+02:00          39797.0
# 2023-07-18 03:00:00+02:00          40046.0
# ...                                    ...
# 2023-08-03 01:00:00+02:00          38361.0
# 2023-08-03 01:15:00+02:00          38219.0
# 2023-08-03 01:30:00+02:00          37959.0
# 2023-08-03 01:45:00+02:00          37785.0
# 2023-08-03 02:00:00+02:00          37490.0
#
# [1537 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for DE: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for DE_50HZ:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           9009.0
# 2023-07-18 02:15:00+02:00           8973.0
# 2023-07-18 02:30:00+02:00           9026.0
# 2023-07-18 02:45:00+02:00           9023.0
# 2023-07-18 03:00:00+02:00           9158.0
# ...                                    ...
# 2023-08-03 01:00:00+02:00           9046.0
# 2023-08-03 01:15:00+02:00           8971.0
# 2023-08-03 01:30:00+02:00           8883.0
# 2023-08-03 01:45:00+02:00           8837.0
# 2023-08-03 02:00:00+02:00           8742.0
#
# [1537 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for DE_50HZ: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for DE_AMPRION:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00          13410.0
# 2023-07-18 02:15:00+02:00          13355.0
# 2023-07-18 02:30:00+02:00          13351.0
# 2023-07-18 02:45:00+02:00          13351.0
# 2023-07-18 03:00:00+02:00          13380.0
# ...                                    ...
# 2023-08-03 01:00:00+02:00          14038.0
# 2023-08-03 01:15:00+02:00          13957.0
# 2023-08-03 01:30:00+02:00          13867.0
# 2023-08-03 01:45:00+02:00          13790.0
# 2023-08-03 02:00:00+02:00          13655.0
#
# [1537 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for DE_AMPRION: name 'write_api' is not defined
# Data extraction (day_ahead_total_load_forecast) failed for DE_AT_LU:
# Day-Ahead Total Load Forecast for DE_LU:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00          40407.0
# 2023-07-18 02:15:00+02:00          40180.0
# 2023-07-18 02:30:00+02:00          40143.0
# 2023-07-18 02:45:00+02:00          40202.0
# 2023-07-18 03:00:00+02:00          40453.0
# ...                                    ...
# 2023-08-03 01:00:00+02:00          38771.0
# 2023-08-03 01:15:00+02:00          38626.0
# 2023-08-03 01:30:00+02:00          38362.0
# 2023-08-03 01:45:00+02:00          38187.0
# 2023-08-03 02:00:00+02:00          37893.0
#
# [1537 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for DE_LU: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for DE_TENNET:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00          11848.0
# 2023-07-18 02:15:00+02:00          11728.0
# 2023-07-18 02:30:00+02:00          11666.0
# 2023-07-18 02:45:00+02:00          11728.0
# 2023-07-18 03:00:00+02:00          11812.0
# ...                                    ...
# 2023-08-03 01:00:00+02:00           9916.0
# 2023-08-03 01:15:00+02:00           9972.0
# 2023-08-03 01:30:00+02:00           9954.0
# 2023-08-03 01:45:00+02:00           9932.0
# 2023-08-03 02:00:00+02:00           9875.0
#
# [1537 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for DE_TENNET: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for DE_TRANSNET:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           5734.0
# 2023-07-18 02:15:00+02:00           5721.0
# 2023-07-18 02:30:00+02:00           5696.0
# 2023-07-18 02:45:00+02:00           5696.0
# 2023-07-18 03:00:00+02:00           5696.0
# ...                                    ...
# 2023-08-03 01:00:00+02:00           5362.0
# 2023-08-03 01:15:00+02:00           5319.0
# 2023-08-03 01:30:00+02:00           5255.0
# 2023-08-03 01:45:00+02:00           5226.0
# 2023-08-03 02:00:00+02:00           5218.0
#
# [1537 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for DE_TRANSNET: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for DK:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           2575.0
# 2023-07-18 03:00:00+02:00           2569.0
# 2023-07-18 04:00:00+02:00           2546.0
# 2023-07-18 05:00:00+02:00           2572.0
# 2023-07-18 06:00:00+02:00           2913.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           3372.0
# 2023-08-02 23:00:00+02:00           3162.0
# 2023-08-03 00:00:00+02:00           2945.0
# 2023-08-03 01:00:00+02:00           2889.0
# 2023-08-03 02:00:00+02:00           2894.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for DK: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for DK_1:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           1556.0
# 2023-07-18 03:00:00+02:00           1552.0
# 2023-07-18 04:00:00+02:00           1548.0
# 2023-07-18 05:00:00+02:00           1591.0
# 2023-07-18 06:00:00+02:00           1793.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           1915.0
# 2023-08-02 23:00:00+02:00           1780.0
# 2023-08-03 00:00:00+02:00           1753.0
# 2023-08-03 01:00:00+02:00           1718.0
# 2023-08-03 02:00:00+02:00           1729.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for DK_1: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for DK_2:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           1019.0
# 2023-07-18 03:00:00+02:00           1017.0
# 2023-07-18 04:00:00+02:00            998.0
# 2023-07-18 05:00:00+02:00            981.0
# 2023-07-18 06:00:00+02:00           1120.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           1457.0
# 2023-08-02 23:00:00+02:00           1382.0
# 2023-08-03 00:00:00+02:00           1192.0
# 2023-08-03 01:00:00+02:00           1171.0
# 2023-08-03 02:00:00+02:00           1165.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for DK_2: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for DK_CA:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           2575.0
# 2023-07-18 03:00:00+02:00           2569.0
# 2023-07-18 04:00:00+02:00           2546.0
# 2023-07-18 05:00:00+02:00           2572.0
# 2023-07-18 06:00:00+02:00           2913.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           3372.0
# 2023-08-02 23:00:00+02:00           3162.0
# 2023-08-03 00:00:00+02:00           2945.0
# 2023-08-03 01:00:00+02:00           2889.0
# 2023-08-03 02:00:00+02:00           2894.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for DK_CA: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for EE:
#                            Forecasted Load
# 2023-07-18 03:00:00+03:00            584.0
# 2023-07-18 04:00:00+03:00            571.0
# 2023-07-18 05:00:00+03:00            584.0
# 2023-07-18 06:00:00+03:00            663.0
# 2023-07-18 07:00:00+03:00            730.0
# ...                                    ...
# 2023-08-02 23:00:00+03:00            715.0
# 2023-08-03 00:00:00+03:00            679.0
# 2023-08-03 01:00:00+03:00            624.0
# 2023-08-03 02:00:00+03:00            621.0
# 2023-08-03 03:00:00+03:00            620.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for EE: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for ES:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00          26844.0
# 2023-07-18 02:15:00+02:00          26563.0
# 2023-07-18 02:30:00+02:00          26319.0
# 2023-07-18 02:45:00+02:00          26108.0
# 2023-07-18 03:00:00+02:00          25880.0
# ...                                    ...
# 2023-08-03 01:00:00+02:00          26578.0
# 2023-08-03 01:15:00+02:00          26178.0
# 2023-08-03 01:30:00+02:00          25813.0
# 2023-08-03 01:45:00+02:00          25483.0
# 2023-08-03 02:00:00+02:00          25128.0
#
# [1537 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for ES: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for FI:
#                            Forecasted Load
# 2023-07-18 03:00:00+03:00           6214.0
# 2023-07-18 03:15:00+03:00           6187.0
# 2023-07-18 03:30:00+03:00           6174.0
# 2023-07-18 03:45:00+03:00           6161.0
# 2023-07-18 04:00:00+03:00           6146.0
# ...                                    ...
# 2023-08-03 02:00:00+03:00           6492.0
# 2023-08-03 02:15:00+03:00           6460.0
# 2023-08-03 02:30:00+03:00           6437.0
# 2023-08-03 02:45:00+03:00           6410.0
# 2023-08-03 03:00:00+03:00           6378.0
#
# [1537 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for FI: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for FR:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00          38800.0
# 2023-07-18 03:00:00+02:00          37050.0
# 2023-07-18 04:00:00+02:00          36050.0
# 2023-07-18 05:00:00+02:00          36900.0
# 2023-07-18 06:00:00+02:00          38950.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00          41800.0
# 2023-08-02 23:00:00+02:00          42850.0
# 2023-08-03 00:00:00+02:00          39350.0
# 2023-08-03 01:00:00+02:00          36400.0
# 2023-08-03 02:00:00+02:00          35200.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for FR: name 'write_api' is not defined
# Data extraction (day_ahead_total_load_forecast) failed for GB:
# Data extraction (day_ahead_total_load_forecast) failed for GB_NIR:
# Day-Ahead Total Load Forecast for GR:
#                            Forecasted Load
# 2023-07-18 03:00:00+03:00           6392.0
# 2023-07-18 04:00:00+03:00           6246.0
# 2023-07-18 05:00:00+03:00           6225.0
# 2023-07-18 06:00:00+03:00           6330.0
# 2023-07-18 07:00:00+03:00           6811.0
# ...                                    ...
# 2023-08-02 23:00:00+03:00           7279.0
# 2023-08-03 00:00:00+03:00           7098.0
# 2023-08-03 01:00:00+03:00           6632.0
# 2023-08-03 02:00:00+03:00           6352.0
# 2023-08-03 03:00:00+03:00           6140.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for GR: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for HR:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           1965.0
# 2023-07-18 03:00:00+02:00           1889.0
# 2023-07-18 04:00:00+02:00           1889.0
# 2023-07-18 05:00:00+02:00           1900.0
# 2023-07-18 06:00:00+02:00           2187.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           2568.0
# 2023-08-02 23:00:00+02:00           2336.0
# 2023-08-03 00:00:00+02:00           1870.0
# 2023-08-03 01:00:00+02:00           1806.0
# 2023-08-03 02:00:00+02:00           1746.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for HR: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for HU:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           4176.0
# 2023-07-18 02:15:00+02:00           4131.0
# 2023-07-18 02:30:00+02:00           4098.0
# 2023-07-18 02:45:00+02:00           4078.0
# 2023-07-18 03:00:00+02:00           4068.0
# ...                                    ...
# 2023-08-03 01:00:00+02:00           3889.0
# 2023-08-03 01:15:00+02:00           3844.0
# 2023-08-03 01:30:00+02:00           3798.0
# 2023-08-03 01:45:00+02:00           3750.0
# 2023-08-03 02:00:00+02:00           3702.0
#
# [1537 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for HU: name 'write_api' is not defined
# Data extraction (day_ahead_total_load_forecast) failed for IE:
# Data extraction (day_ahead_total_load_forecast) failed for IE_SEM:
# Data extraction (day_ahead_total_load_forecast) failed for IS:
# Day-Ahead Total Load Forecast for IT:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00          32639.0
# 2023-07-18 03:00:00+02:00          32145.0
# 2023-07-18 04:00:00+02:00          31899.0
# 2023-07-18 05:00:00+02:00          32628.0
# 2023-07-18 06:00:00+02:00          35466.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00          37251.0
# 2023-08-02 23:00:00+02:00          34515.0
# 2023-08-03 00:00:00+02:00          31277.0
# 2023-08-03 01:00:00+02:00          29403.0
# 2023-08-03 02:00:00+02:00          28165.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for IT: name 'write_api' is not defined
# Data extraction (day_ahead_total_load_forecast) failed for IT_BRNN:
# Day-Ahead Total Load Forecast for IT_CNOR:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           2526.0
# 2023-07-18 03:00:00+02:00           2516.0
# 2023-07-18 04:00:00+02:00           2433.0
# 2023-07-18 05:00:00+02:00           2505.0
# 2023-07-18 06:00:00+02:00           2766.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           3092.0
# 2023-08-02 23:00:00+02:00           2812.0
# 2023-08-03 00:00:00+02:00           2530.0
# 2023-08-03 01:00:00+02:00           2422.0
# 2023-08-03 02:00:00+02:00           2376.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for IT_CNOR: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for IT_CSUD:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           5235.0
# 2023-07-18 03:00:00+02:00           5137.0
# 2023-07-18 04:00:00+02:00           5011.0
# 2023-07-18 05:00:00+02:00           5125.0
# 2023-07-18 06:00:00+02:00           5583.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           6745.0
# 2023-08-02 23:00:00+02:00           6293.0
# 2023-08-03 00:00:00+02:00           5384.0
# 2023-08-03 01:00:00+02:00           5022.0
# 2023-08-03 02:00:00+02:00           4737.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for IT_CSUD: name 'write_api' is not defined
# Data extraction (day_ahead_total_load_forecast) failed for IT_FOGN:
# Data extraction (day_ahead_total_load_forecast) failed for IT_GR:
# Data extraction (day_ahead_total_load_forecast) failed for IT_MACRO_NORTH: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A65&processType=A01&outBiddingZone_Domain=10Y1001A1001A84D&securityToken=6276342c-e10c-4d88-8688-cb0a1cf163ca&periodStart=202307180000&periodEnd=202308030000
# Data extraction (day_ahead_total_load_forecast) failed for IT_MACRO_SOUTH: 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A65&processType=A01&outBiddingZone_Domain=10Y1001A1001A85B&securityToken=6276342c-e10c-4d88-8688-cb0a1cf163ca&periodStart=202307180000&periodEnd=202308030000
# Data extraction (day_ahead_total_load_forecast) failed for IT_MALTA:
# Day-Ahead Total Load Forecast for IT_NORD:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00          18261.0
# 2023-07-18 03:00:00+02:00          18059.0
# 2023-07-18 04:00:00+02:00          18148.0
# 2023-07-18 05:00:00+02:00          18665.0
# 2023-07-18 06:00:00+02:00          20654.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00          19434.0
# 2023-08-02 23:00:00+02:00          18086.0
# 2023-08-03 00:00:00+02:00          16209.0
# 2023-08-03 01:00:00+02:00          15111.0
# 2023-08-03 02:00:00+02:00          14340.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for IT_NORD: name 'write_api' is not defined
# Data extraction (day_ahead_total_load_forecast) failed for IT_NORD_AT:
# Data extraction (day_ahead_total_load_forecast) failed for IT_NORD_CH:
# Data extraction (day_ahead_total_load_forecast) failed for IT_NORD_FR:
# Data extraction (day_ahead_total_load_forecast) failed for IT_NORD_SI:
# Data extraction (day_ahead_total_load_forecast) failed for IT_PRGP:
# Data extraction (day_ahead_total_load_forecast) failed for IT_ROSN:
# Data extraction (day_ahead_total_load_forecast) failed for IT_SACO_AC:
# Data extraction (day_ahead_total_load_forecast) failed for IT_SACO_DC:
# Day-Ahead Total Load Forecast for IT_SARD:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00            935.0
# 2023-07-18 03:00:00+02:00            905.0
# 2023-07-18 04:00:00+02:00            892.0
# 2023-07-18 05:00:00+02:00            905.0
# 2023-07-18 06:00:00+02:00            927.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           1155.0
# 2023-08-02 23:00:00+02:00           1065.0
# 2023-08-03 00:00:00+02:00           1007.0
# 2023-08-03 01:00:00+02:00            967.0
# 2023-08-03 02:00:00+02:00            935.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for IT_SARD: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for IT_SICI:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           2180.0
# 2023-07-18 03:00:00+02:00           2095.0
# 2023-07-18 04:00:00+02:00           2050.0
# 2023-07-18 05:00:00+02:00           2052.0
# 2023-07-18 06:00:00+02:00           2082.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           2740.0
# 2023-08-02 23:00:00+02:00           2557.0
# 2023-08-03 00:00:00+02:00           2422.0
# 2023-08-03 01:00:00+02:00           2277.0
# 2023-08-03 02:00:00+02:00           2172.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for IT_SICI: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for IT_SUD:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           2837.0
# 2023-07-18 03:00:00+02:00           2818.0
# 2023-07-18 04:00:00+02:00           2753.0
# 2023-07-18 05:00:00+02:00           2774.0
# 2023-07-18 06:00:00+02:00           2759.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           3080.0
# 2023-08-02 23:00:00+02:00           2875.0
# 2023-08-03 00:00:00+02:00           2903.0
# 2023-08-03 01:00:00+02:00           2754.0
# 2023-08-03 02:00:00+02:00           2568.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for IT_SUD: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for LT:
#                            Forecasted Load
# 2023-07-18 03:00:00+03:00           1005.0
# 2023-07-18 04:00:00+03:00           1003.0
# 2023-07-18 05:00:00+03:00            993.0
# 2023-07-18 06:00:00+03:00           1024.0
# 2023-07-18 07:00:00+03:00           1183.0
# ...                                    ...
# 2023-08-02 23:00:00+03:00           1276.0
# 2023-08-03 00:00:00+03:00           1178.0
# 2023-08-03 01:00:00+03:00           1086.0
# 2023-08-03 02:00:00+03:00           1030.0
# 2023-08-03 03:00:00+03:00            999.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for LT: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for LU:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00            405.0
# 2023-07-18 02:15:00+02:00            404.0
# 2023-07-18 02:30:00+02:00            404.0
# 2023-07-18 02:45:00+02:00            405.0
# 2023-07-18 03:00:00+02:00            407.0
# ...                                    ...
# 2023-08-03 01:00:00+02:00            410.0
# 2023-08-03 01:15:00+02:00            407.0
# 2023-08-03 01:30:00+02:00            403.0
# 2023-08-03 01:45:00+02:00            402.0
# 2023-08-03 02:00:00+02:00            403.0
#
# [1537 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for LU: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for LV:
#                            Forecasted Load
# 2023-07-18 03:00:00+03:00            483.0
# 2023-07-18 04:00:00+03:00            467.0
# 2023-07-18 05:00:00+03:00            482.0
# 2023-07-18 06:00:00+03:00            565.0
# 2023-07-18 07:00:00+03:00            663.0
# ...                                    ...
# 2023-08-02 23:00:00+03:00            628.0
# 2023-08-03 00:00:00+03:00            566.0
# 2023-08-03 01:00:00+03:00            536.0
# 2023-08-03 02:00:00+03:00            518.0
# 2023-08-03 03:00:00+03:00            521.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for LV: name 'write_api' is not defined
# Data extraction (day_ahead_total_load_forecast) failed for MD:
# Day-Ahead Total Load Forecast for ME:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00            317.0
# 2023-07-18 03:00:00+02:00            299.0
# 2023-07-18 04:00:00+02:00            291.0
# 2023-07-18 05:00:00+02:00            288.0
# 2023-07-18 06:00:00+02:00            317.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00            454.0
# 2023-08-02 23:00:00+02:00            421.0
# 2023-08-03 00:00:00+02:00            357.0
# 2023-08-03 01:00:00+02:00            329.0
# 2023-08-03 02:00:00+02:00            300.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for ME: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for MK:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00            589.0
# 2023-07-18 03:00:00+02:00            559.0
# 2023-07-18 04:00:00+02:00            555.0
# 2023-07-18 05:00:00+02:00            552.0
# 2023-07-18 06:00:00+02:00            581.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00            727.0
# 2023-08-02 23:00:00+02:00            690.0
# 2023-08-03 00:00:00+02:00            609.0
# 2023-08-03 01:00:00+02:00            547.0
# 2023-08-03 02:00:00+02:00            504.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for MK: name 'write_api' is not defined
# Data extraction (day_ahead_total_load_forecast) failed for MT:
# Day-Ahead Total Load Forecast for NL:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00          11447.0
# 2023-07-18 02:15:00+02:00          11477.0
# 2023-07-18 02:30:00+02:00          11440.0
# 2023-07-18 02:45:00+02:00          11373.0
# 2023-07-18 03:00:00+02:00          11330.0
# ...                                    ...
# 2023-08-03 01:00:00+02:00          11622.0
# 2023-08-03 01:15:00+02:00          11530.0
# 2023-08-03 01:30:00+02:00          11464.0
# 2023-08-03 01:45:00+02:00          11386.0
# 2023-08-03 02:00:00+02:00          11344.0
#
# [1537 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for NL: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for NO:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00          10481.0
# 2023-07-18 03:00:00+02:00          10151.0
# 2023-07-18 04:00:00+02:00          10190.0
# 2023-07-18 05:00:00+02:00          10219.0
# 2023-07-18 06:00:00+02:00          10907.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00          11542.0
# 2023-08-02 23:00:00+02:00          11313.0
# 2023-08-03 00:00:00+02:00          10968.0
# 2023-08-03 01:00:00+02:00          10803.0
# 2023-08-03 02:00:00+02:00          10476.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for NO: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for NO_1:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           2090.0
# 2023-07-18 03:00:00+02:00           1915.0
# 2023-07-18 04:00:00+02:00           1950.0
# 2023-07-18 05:00:00+02:00           1966.0
# 2023-07-18 06:00:00+02:00           2215.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           2581.0
# 2023-08-02 23:00:00+02:00           2441.0
# 2023-08-03 00:00:00+02:00           2289.0
# 2023-08-03 01:00:00+02:00           2256.0
# 2023-08-03 02:00:00+02:00           2199.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for NO_1: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for NO_2:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           2689.0
# 2023-07-18 03:00:00+02:00           2643.0
# 2023-07-18 04:00:00+02:00           2662.0
# 2023-07-18 05:00:00+02:00           2737.0
# 2023-07-18 06:00:00+02:00           2892.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           2934.0
# 2023-08-02 23:00:00+02:00           2855.0
# 2023-08-03 00:00:00+02:00           2746.0
# 2023-08-03 01:00:00+02:00           2699.0
# 2023-08-03 02:00:00+02:00           2640.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for NO_2: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for NO_3:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           2457.0
# 2023-07-18 03:00:00+02:00           2430.0
# 2023-07-18 04:00:00+02:00           2407.0
# 2023-07-18 05:00:00+02:00           2343.0
# 2023-07-18 06:00:00+02:00           2437.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           2612.0
# 2023-08-02 23:00:00+02:00           2623.0
# 2023-08-03 00:00:00+02:00           2591.0
# 2023-08-03 01:00:00+02:00           2548.0
# 2023-08-03 02:00:00+02:00           2454.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for NO_3: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for NO_4:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           1660.0
# 2023-07-18 03:00:00+02:00           1617.0
# 2023-07-18 04:00:00+02:00           1597.0
# 2023-07-18 05:00:00+02:00           1600.0
# 2023-07-18 06:00:00+02:00           1668.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           1675.0
# 2023-08-02 23:00:00+02:00           1694.0
# 2023-08-03 00:00:00+02:00           1721.0
# 2023-08-03 01:00:00+02:00           1696.0
# 2023-08-03 02:00:00+02:00           1629.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for NO_4: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for NO_5:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           1585.0
# 2023-07-18 03:00:00+02:00           1546.0
# 2023-07-18 04:00:00+02:00           1574.0
# 2023-07-18 05:00:00+02:00           1573.0
# 2023-07-18 06:00:00+02:00           1695.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           1740.0
# 2023-08-02 23:00:00+02:00           1700.0
# 2023-08-03 00:00:00+02:00           1619.0
# 2023-08-03 01:00:00+02:00           1604.0
# 2023-08-03 02:00:00+02:00           1555.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for NO_5: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for PL:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00          14994.0
# 2023-07-18 03:00:00+02:00          15058.0
# 2023-07-18 04:00:00+02:00          14985.0
# 2023-07-18 05:00:00+02:00          15685.0
# 2023-07-18 06:00:00+02:00          17993.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00          18167.0
# 2023-08-02 23:00:00+02:00          16624.0
# 2023-08-03 00:00:00+02:00          15115.0
# 2023-08-03 01:00:00+02:00          14292.0
# 2023-08-03 02:00:00+02:00          13677.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for PL: name 'write_api' is not defined
# Data extraction (day_ahead_total_load_forecast) failed for PL_CZ:
# Day-Ahead Total Load Forecast for PT:
#                            Forecasted Load
# 2023-07-18 01:00:00+01:00           4952.0
# 2023-07-18 02:00:00+01:00           4803.0
# 2023-07-18 03:00:00+01:00           4720.0
# 2023-07-18 04:00:00+01:00           4690.0
# 2023-07-18 05:00:00+01:00           4715.0
# ...                                    ...
# 2023-08-02 21:00:00+01:00           6719.0
# 2023-08-02 22:00:00+01:00           6486.0
# 2023-08-02 23:00:00+01:00           5573.0
# 2023-08-03 00:00:00+01:00           5140.0
# 2023-08-03 01:00:00+01:00           4881.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for PT: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for RO:
#                            Forecasted Load
# 2023-07-18 03:00:00+03:00           5480.0
# 2023-07-18 03:15:00+03:00           5470.0
# 2023-07-18 03:30:00+03:00           5470.0
# 2023-07-18 03:45:00+03:00           5470.0
# 2023-07-18 04:00:00+03:00           5470.0
# ...                                    ...
# 2023-08-03 02:00:00+03:00           5270.0
# 2023-08-03 02:15:00+03:00           5230.0
# 2023-08-03 02:30:00+03:00           5200.0
# 2023-08-03 02:45:00+03:00           5190.0
# 2023-08-03 03:00:00+03:00           5180.0
#
# [1537 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for RO: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for RS:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           2762.0
# 2023-07-18 03:00:00+02:00           2664.0
# 2023-07-18 04:00:00+02:00           2643.0
# 2023-07-18 05:00:00+02:00           2706.0
# 2023-07-18 06:00:00+02:00           3035.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           3951.0
# 2023-08-02 23:00:00+02:00           3702.0
# 2023-08-03 00:00:00+02:00           3191.0
# 2023-08-03 01:00:00+02:00           2902.0
# 2023-08-03 02:00:00+02:00           2733.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for RS: name 'write_api' is not defined
# Data extraction (day_ahead_total_load_forecast) failed for RU:
# Data extraction (day_ahead_total_load_forecast) failed for RU_KGD:
# Day-Ahead Total Load Forecast for SE:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           9878.0
# 2023-07-18 03:00:00+02:00           9768.0
# 2023-07-18 04:00:00+02:00           9687.0
# 2023-07-18 05:00:00+02:00           9786.0
# 2023-07-18 06:00:00+02:00          10348.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00          11455.0
# 2023-08-02 23:00:00+02:00          10888.0
# 2023-08-03 00:00:00+02:00          10382.0
# 2023-08-03 01:00:00+02:00          10104.0
# 2023-08-03 02:00:00+02:00           9999.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for SE: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for SE_1:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00            997.0
# 2023-07-18 03:00:00+02:00            992.0
# 2023-07-18 04:00:00+02:00            996.0
# 2023-07-18 05:00:00+02:00           1008.0
# 2023-07-18 06:00:00+02:00           1035.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           1103.0
# 2023-08-02 23:00:00+02:00           1080.0
# 2023-08-03 00:00:00+02:00           1057.0
# 2023-08-03 01:00:00+02:00           1040.0
# 2023-08-03 02:00:00+02:00           1028.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for SE_1: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for SE_2:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           1318.0
# 2023-07-18 03:00:00+02:00           1309.0
# 2023-07-18 04:00:00+02:00           1303.0
# 2023-07-18 05:00:00+02:00           1342.0
# 2023-07-18 06:00:00+02:00           1425.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           1531.0
# 2023-08-02 23:00:00+02:00           1485.0
# 2023-08-03 00:00:00+02:00           1408.0
# 2023-08-03 01:00:00+02:00           1376.0
# 2023-08-03 02:00:00+02:00           1359.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for SE_2: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for SE_3:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           6020.0
# 2023-07-18 03:00:00+02:00           5939.0
# 2023-07-18 04:00:00+02:00           5864.0
# 2023-07-18 05:00:00+02:00           5906.0
# 2023-07-18 06:00:00+02:00           6229.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           6986.0
# 2023-08-02 23:00:00+02:00           6611.0
# 2023-08-03 00:00:00+02:00           6291.0
# 2023-08-03 01:00:00+02:00           6106.0
# 2023-08-03 02:00:00+02:00           6047.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for SE_3: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for SE_4:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           1543.0
# 2023-07-18 03:00:00+02:00           1528.0
# 2023-07-18 04:00:00+02:00           1524.0
# 2023-07-18 05:00:00+02:00           1530.0
# 2023-07-18 06:00:00+02:00           1659.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           1835.0
# 2023-08-02 23:00:00+02:00           1712.0
# 2023-08-03 00:00:00+02:00           1626.0
# 2023-08-03 01:00:00+02:00           1582.0
# 2023-08-03 02:00:00+02:00           1565.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for SE_4: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for SI:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           1181.0
# 2023-07-18 03:00:00+02:00           1171.0
# 2023-07-18 04:00:00+02:00           1193.0
# 2023-07-18 05:00:00+02:00           1260.0
# 2023-07-18 06:00:00+02:00           1506.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           1150.0
# 2023-08-02 23:00:00+02:00           1070.0
# 2023-08-03 00:00:00+02:00            971.0
# 2023-08-03 01:00:00+02:00            920.0
# 2023-08-03 02:00:00+02:00            899.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for SI: name 'write_api' is not defined
# Day-Ahead Total Load Forecast for SK:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           2300.0
# 2023-07-18 03:00:00+02:00           2280.0
# 2023-07-18 04:00:00+02:00           2330.0
# 2023-07-18 05:00:00+02:00           2520.0
# 2023-07-18 06:00:00+02:00           2800.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           2500.0
# 2023-08-02 23:00:00+02:00           2360.0
# 2023-08-03 00:00:00+02:00           2180.0
# 2023-08-03 01:00:00+02:00           2120.0
# 2023-08-03 02:00:00+02:00           2100.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for SK: name 'write_api' is not defined
# Data extraction (day_ahead_total_load_forecast) failed for TR:
# Data extraction (day_ahead_total_load_forecast) failed for UA:
# Data extraction (day_ahead_total_load_forecast) failed for UA_BEI:
# Data extraction (day_ahead_total_load_forecast) failed for UA_DOBTPP:
# Data extraction (day_ahead_total_load_forecast) failed for UA_IPS:

# %%
# Download installed generation capacity - 3
for country_code in country_codes:
    try:
        # Download the installed generation capacity data
        installed_generation_capacity = client.query_installed_generation_capacity(country_code, start=start, end=end, psr_type=None)
        print(f"Installed Generation Capacity for {country_code}:")
        print(installed_generation_capacity)
        
        # Convert the index to UTC and format it as a string
        installed_generation_capacity.index = installed_generation_capacity.index.tz_convert('UTC').strftime('%Y-%m-%dT%H:%M:%SZ')

        # Create data points for each row
        data_points = []
        for _, row in installed_generation_capacity.iterrows():
            for column in installed_generation_capacity.columns[1:]:
                production_type = column
                value = row[column]
                if pd.notnull(value):
                    data_point = Point("installed_generation_capacity") \
                        .tag("country", country_code) \
                        .tag("production_type", production_type) \
                        .field("value", value) \
                        .time(row.name)
                    data_points.append(data_point)


        # Write data points to InfluxDB
        write_api.write(bucket=influxdb_bucket, record=data_points)
        logging.info('Data extraction (installed_generation_capacity) completed for country: %s', country_code)
        print(f'Data extraction (installed_generation_capacity) completed for country: {country_code}')
    except Exception as e:
        print(f'Data extraction (installed_generation_capacity) failed for {country_code}: {str(e)}')
        logging.error(f'Data extraction (installed_generation_capacity) failed for {country_code}: {str(e)}')

# %%
#List of country codes (out of all 84) for which the upload of installed_generation_capacity failed
failed_country_codes = [
    'BY', 'CWE', 'CZ_DE_SK', 'IS', 'IT_BRNN', 'IT_CNOR', 'IT_CSUD', 'IT_FOGN',
    'IT_GR', 'IT_MACRO_NORTH', 'IT_MACRO_SOUTH', 'IT_MALTA', 'IT_NORD', 'IT_NORD_AT',
    'IT_NORD_CH', 'IT_NORD_FR', 'IT_NORD_SI', 'IT_PRGP', 'IT_ROSN', 'IT_SACO_AC',
    'IT_SACO_DC', 'IT_SARD', 'IT_SICI', 'IT_SUD', 'PL_CZ', 'RU', 'RU_KGD', 'SE_1',
    'SE_2', 'SE_3', 'SE_4', 'TR', 'UA_DOBTPP'
]
len(failed_country_codes)
failed_country_codes

# %%
# Download and save the data for each country - Actual Generation per Production Type - 4
for country_code in sorted_country_codes:
    try:
        actual_generation = client.query_generation(country_code=country_code, start=start, end=end)
        print(f"Actual Generation for {country_code}:")
        print(actual_generation)  # Print the data

        # Convert the index to UTC and format it as string
        actual_generation.index = actual_generation.index.tz_convert('UTC').strftime('%Y-%m-%dT%H:%M:%SZ')

        # Convert the data to InfluxDB Line Protocol format
        data_points = []
        for timestamp, row in actual_generation.iterrows():
            for column, value in row.items():
                if pd.notnull(value):
                    production_type = str(column).replace("/", "_").replace(" ", "_")
                    data_point = Point("actual_generation") \
                        .tag("country", country_code) \
                        .tag("production_type", production_type) \
                        .field("value", value) \
                        .time(timestamp, WritePrecision.NS)
                    data_points.append(data_point)

        # Write the data points to InfluxDB
        write_api.write(bucket=influxdb_bucket, record=data_points)
        logging.info('Data extraction (actual_generation) completed for country: %s', country_code)

    except Exception as e:
        print(f'Data extraction (actual_generation) failed for {country_code}: {str(e)}')
        logging.error(f'Data extraction (actual_generation) failed for {country_code}: {str(e)}')

# %%
#Removing Duplicates

# %%
def remove_duplicates(country_code, measurement, start, end):
    query = f'''
        from(bucket: "{influxdb_bucket}")
          |> range(start: {start}, stop: {end})
          |> filter(fn: (r) => r._measurement == "{measurement}" and r.country_code == "{country_code}")
          |> pivot(rowKey:["_time"], columnKey: ["_field"], valueColumn: "_value")
          |> keep(columns: ["_time", "_value"])
          |> distinct()
    '''

    result = query_api.query_data_frame(query)
    if not result.empty:
        result.set_index('_time', inplace=True)
        result.sort_index(inplace=True)
        return result
    else:
        return None

# Set the desired parameters
country_code = 'AT'
measurement = 'actual_total_load'
start = pd.Timestamp('2023-07-01', tz='UTC').isoformat()
end = pd.Timestamp.now(tz='UTC').isoformat()

df = remove_duplicates(country_code, measurement, start, end)
print(df)

# %%
#Remove Duplicates for all countries, every measurement
for country_code in sorted_country_codes:
    for measurement in categories.values():
        df = remove_duplicates(country_code, measurement, start, end)
        print(f"DataFrame: {df}, Country: {country_code}, Measurement: {measurement}")
