# %%
# Import Libraries
import logging
import pandas as pd
from influxdb_client import InfluxDBClient, Point, WritePrecision
from influxdb_client.client.query_api import QueryApi
import influxdb_client
from influxdb_client.client.exceptions import InfluxDBError

# %%
# Set up logging
logging.basicConfig(filename='influxdb_query.log', level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logging.info('Script started at %s', pd.Timestamp.now(tz='UTC'))

# %%
# Define InfluxDB connection details
influxdb_url = 'http://159.89.103.242:8086'
influxdb_token = 'dfRMxqDtwyHK7vDJHelAm0WKISLvKFUrmhclvaaAoMFOHRRTGNnYkV8bXd0jR9r4arvkg3l_lWNSHyKMG0WxSg=='
influxdb_org = 'entra'
influxdb_bucket = 'entra'

# %%
# Create InfluxDB client
influx_client = InfluxDBClient(url=influxdb_url, token=influxdb_token, org=influxdb_org)
# Instantiate the query API
query_api = QueryApi(influx_client)

# %%
# Define measurements
measurements = ['actual_total_load',
                'day_ahead_total_load_forecast',
                'installed_generation_capacity',
                'actual_generation']

# %%
# Country codes
country_codes = sorted(["DE_50HZ", "IT_NORD_SI", "AL", "IT_PRGP", "DE_AMPRION", "IT_ROSN", "AT", "IT_SARD", "BY", "IT_SICI",
                 "BE", "IT_SUD", "BA", "RU_KGD", "BG", "LV", "CZ_DE_SK", "LT", "HR", "LU", "CWE", "MT", "CY", "ME",
                 "CZ", "GB", "DE_AT_LU", "NL", "DE_LU", "NO_1", "DK", "NO_2", "DK_1", "NO_3", "DK_2", "NO_4", "DK_CA",
                 "NO_5", "EE", "NO", "FI", "PL_CZ", "MK", "PL", "FR", "PT", "DE", "MD", "GR", "RO", "HU", "RU", "IS",
                 "SE_1", "IE_SEM", "SE_2", "IE", "SE_3", "IT", "SE_4", "IT_SACO_AC", "RS", "IT_SACO_DC", "SK", "IT_BRNN",
                 "SI", "IT_CNOR", "GB_NIR", "IT_CSUD", "ES", "IT_FOGN", "SE", "IT_GR", "CH", "IT_MACRO_NORTH",
                 "DE_TENNET", "IT_MACRO_SOUTH", "DE_TRANSNET", "IT_MALTA", "TR", "IT_NORD", "UA", "IT_NORD_AT",
                 "UA_DOBTPP", "IT_NORD_CH", "UA_BEI", "IT_NORD_FR", "UA_IPS"])
country_codes = sorted(country_codes)
country_codes
# Out:
# ['AL',
#  'AT',
#  'BA',
#  'BE',
#  'BG',
#  'BY',
#  'CH',
#  'CWE',
#  'CY',
#  'CZ',
#  'CZ_DE_SK',
#  'DE',
#  'DE_50HZ',
#  'DE_AMPRION',
#  'DE_AT_LU',
#  'DE_LU',
#  'DE_TENNET',
#  'DE_TRANSNET',
#  'DK',
#  'DK_1',
#  'DK_2',
#  'DK_CA',
#  'EE',
#  'ES',
#  'FI',
#  'FR',
#  'GB',
#  'GB_NIR',
#  'GR',
#  'HR',
#  'HU',
#  'IE',
#  'IE_SEM',
#  'IS',
#  'IT',
#  'IT_BRNN',
#  'IT_CNOR',
#  'IT_CSUD',
#  'IT_FOGN',
#  'IT_GR',
#  'IT_MACRO_NORTH',
#  'IT_MACRO_SOUTH',
#  'IT_MALTA',
#  'IT_NORD',
#  'IT_NORD_AT',
#  'IT_NORD_CH',
#  'IT_NORD_FR',
#  'IT_NORD_SI',
#  'IT_PRGP',
#  'IT_ROSN',
#  'IT_SACO_AC',
#  'IT_SACO_DC',
#  'IT_SARD',
#  'IT_SICI',
#  'IT_SUD',
#  'LT',
#  'LU',
#  'LV',
#  'MD',
#  'ME',
#  'MK',
#  'MT',
#  'NL',
#  'NO',
#  'NO_1',
#  'NO_2',
#  'NO_3',
#  'NO_4',
#  'NO_5',
#  'PL',
#  'PL_CZ',
#  'PT',
#  'RO',
#  'RS',
#  'RU',
#  'RU_KGD',
#  'SE',
#  'SE_1',
#  'SE_2',
#  'SE_3',
#  'SE_4',
#  'SI',
#  'SK',
#  'TR',
#  'UA',
#  'UA_BEI',
#  'UA_DOBTPP',
#  'UA_IPS']

# %%
# Define dictionaries to hold missing data counts for each measurement
missing_actual_total_load = {}
missing_day_ahead_total_load_forecast = {}
missing_installed_generation_capacity = {}
missing_actual_generation = {}

# %%
for measurement in measurements[3:]:
    measurement_exists = False
    success_countries = []
    failed_countries = []

    for country_code in country_codes:
        print(f"Measurement: {measurement}; Country: {country_code}")

        # Check if measurement exists
        query_exists = f'from(bucket: "{influxdb_bucket}") |> range(start: 2015-01-01T00:00:00Z) |> filter(fn: (r) => r._measurement == "{measurement}" and r.country == "{country_code}") |> count()'
        result_exists = query_api.query(query=query_exists, org=influxdb_org)
        
        if len(result_exists) == 0 or result_exists[0].records[0].get_value() == 0:
            failed_countries.append(country_code)
            print(f'NO : The measurement "{measurement}" does not exist for country {country_code}.')
            continue
        else:
            measurement_exists = True
            success_countries.append(country_code)
            print(f'The measurement "{measurement}" exists for country {country_code}.')

        # Check for rows with zero or NaN values
        query_check = f'from(bucket: "{influxdb_bucket}") |> range(start: 2015-01-01T00:00:00Z) |> filter(fn: (r) => r._measurement == "{measurement}" and r.country == "{country_code}") |> drop(columns: ["_start", "_stop", "_time", "country", "_measurement"]) |> map(fn: (r) => ({{ r with _value: float(v: r._value) }})) |> filter(fn: (r) => r._value == 0.0) |> count()'
        result_check = query_api.query(query=query_check, org=influxdb_org)
        missing_rows = 0
        if len(result_check) > 0:
            missing_rows = result_check[0].records[0].get_value()

        print(f'Number of missing rows for {measurement} in country {country_code}: {missing_rows}')

    if measurement_exists:
        print(f'The measurement "{measurement}" exists.')
        print(f'Successful countries for {measurement}: {success_countries}')
        print(f'Failed countries for {measurement}: {failed_countries}')
    else:
        print(f'The measurement "{measurement}" does not exist.')
# Out:
# Measurement: actual_generation; Country: AL
# NO : The measurement "actual_generation" does not exist for country AL.
# Measurement: actual_generation; Country: AT
# NO : The measurement "actual_generation" does not exist for country AT.
# Measurement: actual_generation; Country: BA
# The measurement "actual_generation" exists for country BA.
# Number of missing rows for actual_generation in country BA: 154
# Measurement: actual_generation; Country: BE
# The measurement "actual_generation" exists for country BE.
# Number of missing rows for actual_generation in country BE: 13298
# Measurement: actual_generation; Country: BG
# The measurement "actual_generation" exists for country BG.
# Number of missing rows for actual_generation in country BG: 13403
# Measurement: actual_generation; Country: BY
# NO : The measurement "actual_generation" does not exist for country BY.
# Measurement: actual_generation; Country: CH
# The measurement "actual_generation" exists for country CH.
# Number of missing rows for actual_generation in country CH: 13
# Measurement: actual_generation; Country: CWE
# NO : The measurement "actual_generation" does not exist for country CWE.
# Measurement: actual_generation; Country: CY
# The measurement "actual_generation" exists for country CY.
# Number of missing rows for actual_generation in country CY: 385
# Measurement: actual_generation; Country: CZ
# The measurement "actual_generation" exists for country CZ.
# Number of missing rows for actual_generation in country CZ: 2448
# Measurement: actual_generation; Country: CZ_DE_SK
# NO : The measurement "actual_generation" does not exist for country CZ_DE_SK.
# Measurement: actual_generation; Country: DE
# NO : The measurement "actual_generation" does not exist for country DE.
# Measurement: actual_generation; Country: DE_50HZ
# NO : The measurement "actual_generation" does not exist for country DE_50HZ.
# Measurement: actual_generation; Country: DE_AMPRION
# NO : The measurement "actual_generation" does not exist for country DE_AMPRION.
# Measurement: actual_generation; Country: DE_AT_LU
# NO : The measurement "actual_generation" does not exist for country DE_AT_LU.
# Measurement: actual_generation; Country: DE_LU
# NO : The measurement "actual_generation" does not exist for country DE_LU.
# Measurement: actual_generation; Country: DE_TENNET
# NO : The measurement "actual_generation" does not exist for country DE_TENNET.
# Measurement: actual_generation; Country: DE_TRANSNET
# NO : The measurement "actual_generation" does not exist for country DE_TRANSNET.
# Measurement: actual_generation; Country: DK
# The measurement "actual_generation" exists for country DK.
# Number of missing rows for actual_generation in country DK: 4011
# Measurement: actual_generation; Country: DK_1
# The measurement "actual_generation" exists for country DK_1.
# Number of missing rows for actual_generation in country DK_1: 36
# Measurement: actual_generation; Country: DK_2
# The measurement "actual_generation" exists for country DK_2.
# Number of missing rows for actual_generation in country DK_2: 6070
# Measurement: actual_generation; Country: DK_CA
# The measurement "actual_generation" exists for country DK_CA.
# Number of missing rows for actual_generation in country DK_CA: 4011
# Measurement: actual_generation; Country: EE
# The measurement "actual_generation" exists for country EE.
# Number of missing rows for actual_generation in country EE: 693
# Measurement: actual_generation; Country: ES
# NO : The measurement "actual_generation" does not exist for country ES.
# Measurement: actual_generation; Country: FI
# The measurement "actual_generation" exists for country FI.
# Number of missing rows for actual_generation in country FI: 3430
# Measurement: actual_generation; Country: FR
# The measurement "actual_generation" exists for country FR.
# Number of missing rows for actual_generation in country FR: 43
# Measurement: actual_generation; Country: GB
# NO : The measurement "actual_generation" does not exist for country GB.
# Measurement: actual_generation; Country: GB_NIR
# The measurement "actual_generation" exists for country GB_NIR.
# Number of missing rows for actual_generation in country GB_NIR: 10
# Measurement: actual_generation; Country: GR
# The measurement "actual_generation" exists for country GR.
# Number of missing rows for actual_generation in country GR: 188
# Measurement: actual_generation; Country: HR
# The measurement "actual_generation" exists for country HR.
# Number of missing rows for actual_generation in country HR: 17
# Measurement: actual_generation; Country: HU
# NO : The measurement "actual_generation" does not exist for country HU.
# Measurement: actual_generation; Country: IE
# The measurement "actual_generation" exists for country IE.
# Number of missing rows for actual_generation in country IE: 602
# Measurement: actual_generation; Country: IE_SEM
# The measurement "actual_generation" exists for country IE_SEM.
# Number of missing rows for actual_generation in country IE_SEM: 10
# Measurement: actual_generation; Country: IS
# NO : The measurement "actual_generation" does not exist for country IS.
# Measurement: actual_generation; Country: IT
# The measurement "actual_generation" exists for country IT.
# Number of missing rows for actual_generation in country IT: 1
# Measurement: actual_generation; Country: IT_BRNN
# NO : The measurement "actual_generation" does not exist for country IT_BRNN.
# Measurement: actual_generation; Country: IT_CNOR
# The measurement "actual_generation" exists for country IT_CNOR.
# Number of missing rows for actual_generation in country IT_CNOR: 13351
# Measurement: actual_generation; Country: IT_CSUD
# The measurement "actual_generation" exists for country IT_CSUD.
# Number of missing rows for actual_generation in country IT_CSUD: 89
# Measurement: actual_generation; Country: IT_FOGN
# NO : The measurement "actual_generation" does not exist for country IT_FOGN.
# Measurement: actual_generation; Country: IT_GR
# NO : The measurement "actual_generation" does not exist for country IT_GR.
# Measurement: actual_generation; Country: IT_MACRO_NORTH
# NO : The measurement "actual_generation" does not exist for country IT_MACRO_NORTH.
# Measurement: actual_generation; Country: IT_MACRO_SOUTH
# NO : The measurement "actual_generation" does not exist for country IT_MACRO_SOUTH.
# Measurement: actual_generation; Country: IT_MALTA
# NO : The measurement "actual_generation" does not exist for country IT_MALTA.
# Measurement: actual_generation; Country: IT_NORD
# The measurement "actual_generation" exists for country IT_NORD.
# Number of missing rows for actual_generation in country IT_NORD: 38
# Measurement: actual_generation; Country: IT_NORD_AT
# NO : The measurement "actual_generation" does not exist for country IT_NORD_AT.
# Measurement: actual_generation; Country: IT_NORD_CH
# NO : The measurement "actual_generation" does not exist for country IT_NORD_CH.
# Measurement: actual_generation; Country: IT_NORD_FR
# NO : The measurement "actual_generation" does not exist for country IT_NORD_FR.
# Measurement: actual_generation; Country: IT_NORD_SI
# NO : The measurement "actual_generation" does not exist for country IT_NORD_SI.
# Measurement: actual_generation; Country: IT_PRGP
# NO : The measurement "actual_generation" does not exist for country IT_PRGP.
# Measurement: actual_generation; Country: IT_ROSN
# NO : The measurement "actual_generation" does not exist for country IT_ROSN.
# Measurement: actual_generation; Country: IT_SACO_AC
# NO : The measurement "actual_generation" does not exist for country IT_SACO_AC.
# Measurement: actual_generation; Country: IT_SACO_DC
# NO : The measurement "actual_generation" does not exist for country IT_SACO_DC.
# Measurement: actual_generation; Country: IT_SARD
# The measurement "actual_generation" exists for country IT_SARD.
# Number of missing rows for actual_generation in country IT_SARD: 2
# Measurement: actual_generation; Country: IT_SICI
# The measurement "actual_generation" exists for country IT_SICI.
# Number of missing rows for actual_generation in country IT_SICI: 2769
# Measurement: actual_generation; Country: IT_SUD
# The measurement "actual_generation" exists for country IT_SUD.
# Number of missing rows for actual_generation in country IT_SUD: 6307
# Measurement: actual_generation; Country: LT
# The measurement "actual_generation" exists for country LT.
# Number of missing rows for actual_generation in country LT: 2471
# Measurement: actual_generation; Country: LU
# The measurement "actual_generation" exists for country LU.
# Number of missing rows for actual_generation in country LU: 2
# Measurement: actual_generation; Country: LV
# The measurement "actual_generation" exists for country LV.
# Number of missing rows for actual_generation in country LV: 6134
# Measurement: actual_generation; Country: MD
# The measurement "actual_generation" exists for country MD.
# Number of missing rows for actual_generation in country MD: 552
# Measurement: actual_generation; Country: ME
# The measurement "actual_generation" exists for country ME.
# Number of missing rows for actual_generation in country ME: 3065
# Measurement: actual_generation; Country: MK
# The measurement "actual_generation" exists for country MK.
# Number of missing rows for actual_generation in country MK: 48
# Measurement: actual_generation; Country: MT
# NO : The measurement "actual_generation" does not exist for country MT.
# Measurement: actual_generation; Country: NL
# NO : The measurement "actual_generation" does not exist for country NL.
# Measurement: actual_generation; Country: NO
# The measurement "actual_generation" exists for country NO.
# Number of missing rows for actual_generation in country NO: 13607
# Measurement: actual_generation; Country: NO_1
# The measurement "actual_generation" exists for country NO_1.
# Number of missing rows for actual_generation in country NO_1: 13608
# Measurement: actual_generation; Country: NO_2
# The measurement "actual_generation" exists for country NO_2.
# Number of missing rows for actual_generation in country NO_2: 9853
# Measurement: actual_generation; Country: NO_3
# The measurement "actual_generation" exists for country NO_3.
# Number of missing rows for actual_generation in country NO_3: 1730
# Measurement: actual_generation; Country: NO_4
# The measurement "actual_generation" exists for country NO_4.
# Number of missing rows for actual_generation in country NO_4: 386
# Measurement: actual_generation; Country: NO_5
# The measurement "actual_generation" exists for country NO_5.
# Number of missing rows for actual_generation in country NO_5: 2333
# Measurement: actual_generation; Country: PL
# The measurement "actual_generation" exists for country PL.
# Number of missing rows for actual_generation in country PL: 4310
# Measurement: actual_generation; Country: PL_CZ
# NO : The measurement "actual_generation" does not exist for country PL_CZ.
# Measurement: actual_generation; Country: PT
# The measurement "actual_generation" exists for country PT.
# Number of missing rows for actual_generation in country PT: 1318
# Measurement: actual_generation; Country: RO
# The measurement "actual_generation" exists for country RO.
# Number of missing rows for actual_generation in country RO: 8720
# Measurement: actual_generation; Country: RS
# The measurement "actual_generation" exists for country RS.
# Number of missing rows for actual_generation in country RS: 3
# Measurement: actual_generation; Country: RU
# NO : The measurement "actual_generation" does not exist for country RU.
# Measurement: actual_generation; Country: RU_KGD
# NO : The measurement "actual_generation" does not exist for country RU_KGD.
# Measurement: actual_generation; Country: SE
# The measurement "actual_generation" exists for country SE.
# Number of missing rows for actual_generation in country SE: 13428
# Measurement: actual_generation; Country: SE_1
# The measurement "actual_generation" exists for country SE_1.
# Number of missing rows for actual_generation in country SE_1: 47
# Measurement: actual_generation; Country: SE_2
# The measurement "actual_generation" exists for country SE_2.
# Number of missing rows for actual_generation in country SE_2: 13568
# Measurement: actual_generation; Country: SE_3
# The measurement "actual_generation" exists for country SE_3.
# Number of missing rows for actual_generation in country SE_3: 13490
# Measurement: actual_generation; Country: SE_4
# The measurement "actual_generation" exists for country SE_4.
# Number of missing rows for actual_generation in country SE_4: 13566
# Measurement: actual_generation; Country: SI
# The measurement "actual_generation" exists for country SI.
# Number of missing rows for actual_generation in country SI: 142
# Measurement: actual_generation; Country: SK
# The measurement "actual_generation" exists for country SK.
# Number of missing rows for actual_generation in country SK: 82
# Measurement: actual_generation; Country: TR
# NO : The measurement "actual_generation" does not exist for country TR.
# Measurement: actual_generation; Country: UA
# The measurement "actual_generation" exists for country UA.
# Number of missing rows for actual_generation in country UA: 863
# Measurement: actual_generation; Country: UA_BEI
# NO : The measurement "actual_generation" does not exist for country UA_BEI.
# Measurement: actual_generation; Country: UA_DOBTPP
# NO : The measurement "actual_generation" does not exist for country UA_DOBTPP.
# Measurement: actual_generation; Country: UA_IPS
# NO : The measurement "actual_generation" does not exist for country UA_IPS.
# The measurement "actual_generation" exists.
# Successful countries for actual_generation: ['BA', 'BE', 'BG', 'CH', 'CY', 'CZ', 'DK', 'DK_1', 'DK_2', 'DK_CA', 'EE', 'FI', 'FR', 'GB_NIR', 'GR', 'HR', 'IE', 'IE_SEM', 'IT', 'IT_CNOR', 'IT_CSUD', 'IT_NORD', 'IT_SARD', 'IT_SICI', 'IT_SUD', 'LT', 'LU', 'LV', 'MD', 'ME', 'MK', 'NO', 'NO_1', 'NO_2', 'NO_3', 'NO_4', 'NO_5', 'PL', 'PT', 'RO', 'RS', 'SE', 'SE_1', 'SE_2', 'SE_3', 'SE_4', 'SI', 'SK', 'UA']
# Failed countries for actual_generation: ['AL', 'AT', 'BY', 'CWE', 'CZ_DE_SK', 'DE', 'DE_50HZ', 'DE_AMPRION', 'DE_AT_LU', 'DE_LU', 'DE_TENNET', 'DE_TRANSNET', 'ES', 'GB', 'HU', 'IS', 'IT_BRNN', 'IT_FOGN', 'IT_GR', 'IT_MACRO_NORTH', 'IT_MACRO_SOUTH', 'IT_MALTA', 'IT_NORD_AT', 'IT_NORD_CH', 'IT_NORD_FR', 'IT_NORD_SI', 'IT_PRGP', 'IT_ROSN', 'IT_SACO_AC', 'IT_SACO_DC', 'MT', 'NL', 'PL_CZ', 'RU', 'RU_KGD', 'TR', 'UA_BEI', 'UA_DOBTPP', 'UA_IPS']

# %%
logging.info('Script ended at %s', pd.Timestamp.now(tz='UTC'))
