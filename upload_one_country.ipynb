# %%
import logging
import pandas as pd
import os
import random
import time, datetime
from entsoe import EntsoePandasClient
from influxdb_client import InfluxDBClient, Point, WritePrecision
from influxdb_client.client.write_api import SYNCHRONOUS
from influxdb_client.client.query_api import QueryApi

# %%
# Set up logging
logging.basicConfig(filename='entsoe.log', level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logging.info('Script started at %s', pd.Timestamp.now(tz='UTC'))

# %%
# Set API key
API_KEY = '6276342c-e10c-4d88-8688-cb0a1cf163ca'

# %%
# Define InfluxDB connection details
influxdb_url = 'http://159.89.103.242:8086'
influxdb_token = 'dfRMxqDtwyHK7vDJHelAm0WKISLvKFUrmhclvaaAoMFOHRRTGNnYkV8bXd0jR9r4arvkg3l_lWNSHyKMG0WxSg=='
influxdb_org = 'entra'
influxdb_bucket = 'entra'

# %%
# Initialize the Entsoe client
client = EntsoePandasClient(api_key=API_KEY)

# %%
# Create InfluxDB client
influx_client = InfluxDBClient(url=influxdb_url, token=influxdb_token, org=influxdb_org)

# %%
# Create the write API
write_api = influx_client.write_api(write_options=SYNCHRONOUS)
# Instantiate the query API
query_api = QueryApi(influx_client)

# %%
# Define the time period
start = pd.Timestamp('2023-07-18', tz='UTC')
end = pd.Timestamp('2023-08-03', tz='UTC')

# %%
# Define the categories and their corresponding measurements
categories = {
    '6.1.A': 'actual_total_load',
    '6.1.B': 'day_ahead_total_load_forecast',
    '14.1.A': 'installed_generation_capacity',
    '16.1.B&C': 'actual_generation'
}

# Country codes
country_codes = sorted(["DE_50HZ", "IT_NORD_SI", "AL", "IT_PRGP", "DE_AMPRION", "IT_ROSN", "AT", "IT_SARD", "BY", "IT_SICI",
                 "BE", "IT_SUD", "BA", "RU_KGD", "BG", "LV", "CZ_DE_SK", "LT", "HR", "LU", "CWE", "MT", "CY", "ME",
                 "CZ", "GB", "DE_AT_LU", "NL", "DE_LU", "NO_1", "DK", "NO_2", "DK_1", "NO_3", "DK_2", "NO_4", "DK_CA",
                 "NO_5", "EE", "NO", "FI", "PL_CZ", "MK", "PL", "FR", "PT", "DE", "MD", "GR", "RO", "HU", "RU", "IS",
                 "SE_1", "IE_SEM", "SE_2", "IE", "SE_3", "IT", "SE_4", "IT_SACO_AC", "RS", "IT_SACO_DC", "SK", "IT_BRNN",
                 "SI", "IT_CNOR", "GB_NIR", "IT_CSUD", "ES", "IT_FOGN", "SE", "IT_GR", "CH", "IT_MACRO_NORTH",
                 "DE_TENNET", "IT_MACRO_SOUTH", "DE_TRANSNET", "IT_MALTA", "TR", "IT_NORD", "UA", "IT_NORD_AT",
                 "UA_DOBTPP", "IT_NORD_CH", "UA_BEI", "IT_NORD_FR", "UA_IPS"])
country_codes
# Out:
# ['AL',
#  'AT',
#  'BA',
#  'BE',
#  'BG',
#  'BY',
#  'CH',
#  'CWE',
#  'CY',
#  'CZ',
#  'CZ_DE_SK',
#  'DE',
#  'DE_50HZ',
#  'DE_AMPRION',
#  'DE_AT_LU',
#  'DE_LU',
#  'DE_TENNET',
#  'DE_TRANSNET',
#  'DK',
#  'DK_1',
#  'DK_2',
#  'DK_CA',
#  'EE',
#  'ES',
#  'FI',
#  'FR',
#  'GB',
#  'GB_NIR',
#  'GR',
#  'HR',
#  'HU',
#  'IE',
#  'IE_SEM',
#  'IS',
#  'IT',
#  'IT_BRNN',
#  'IT_CNOR',
#  'IT_CSUD',
#  'IT_FOGN',
#  'IT_GR',
#  'IT_MACRO_NORTH',
#  'IT_MACRO_SOUTH',
#  'IT_MALTA',
#  'IT_NORD',
#  'IT_NORD_AT',
#  'IT_NORD_CH',
#  'IT_NORD_FR',
#  'IT_NORD_SI',
#  'IT_PRGP',
#  'IT_ROSN',
#  'IT_SACO_AC',
#  'IT_SACO_DC',
#  'IT_SARD',
#  'IT_SICI',
#  'IT_SUD',
#  'LT',
#  'LU',
#  'LV',
#  'MD',
#  'ME',
#  'MK',
#  'MT',
#  'NL',
#  'NO',
#  'NO_1',
#  'NO_2',
#  'NO_3',
#  'NO_4',
#  'NO_5',
#  'PL',
#  'PL_CZ',
#  'PT',
#  'RO',
#  'RS',
#  'RU',
#  'RU_KGD',
#  'SE',
#  'SE_1',
#  'SE_2',
#  'SE_3',
#  'SE_4',
#  'SI',
#  'SK',
#  'TR',
#  'UA',
#  'UA_BEI',
#  'UA_DOBTPP',
#  'UA_IPS']

# %%
list(categories.values())
# Out:
# ['actual_total_load',
#  'day_ahead_total_load_forecast',
#  'installed_generation_capacity',
#  'actual_generation']

# %%
country_codes
# Out:
# ['AL',
#  'AT',
#  'BA',
#  'BE',
#  'BG',
#  'BY',
#  'CH',
#  'CWE',
#  'CY',
#  'CZ',
#  'CZ_DE_SK',
#  'DE',
#  'DE_50HZ',
#  'DE_AMPRION',
#  'DE_AT_LU',
#  'DE_LU',
#  'DE_TENNET',
#  'DE_TRANSNET',
#  'DK',
#  'DK_1',
#  'DK_2',
#  'DK_CA',
#  'EE',
#  'ES',
#  'FI',
#  'FR',
#  'GB',
#  'GB_NIR',
#  'GR',
#  'HR',
#  'HU',
#  'IE',
#  'IE_SEM',
#  'IS',
#  'IT',
#  'IT_BRNN',
#  'IT_CNOR',
#  'IT_CSUD',
#  'IT_FOGN',
#  'IT_GR',
#  'IT_MACRO_NORTH',
#  'IT_MACRO_SOUTH',
#  'IT_MALTA',
#  'IT_NORD',
#  'IT_NORD_AT',
#  'IT_NORD_CH',
#  'IT_NORD_FR',
#  'IT_NORD_SI',
#  'IT_PRGP',
#  'IT_ROSN',
#  'IT_SACO_AC',
#  'IT_SACO_DC',
#  'IT_SARD',
#  'IT_SICI',
#  'IT_SUD',
#  'LT',
#  'LU',
#  'LV',
#  'MD',
#  'ME',
#  'MK',
#  'MT',
#  'NL',
#  'NO',
#  'NO_1',
#  'NO_2',
#  'NO_3',
#  'NO_4',
#  'NO_5',
#  'PL',
#  'PL_CZ',
#  'PT',
#  'RO',
#  'RS',
#  'RU',
#  'RU_KGD',
#  'SE',
#  'SE_1',
#  'SE_2',
#  'SE_3',
#  'SE_4',
#  'SI',
#  'SK',
#  'TR',
#  'UA',
#  'UA_BEI',
#  'UA_DOBTPP',
#  'UA_IPS']

# %%
country_code = "EXAMPLE"
measurement = "actual_total_load"

# %%
countries_actual_total_load = ["BA", "BE", "BG", "CY", "CZ", "DE", "DE_50HZ", "DE_AMPRION", "DE_TENNET", "DE_TRANSNET", "IT_CNOR", "NO"]
done_actual_total_load = ["BA", "BE", "BG", "CY", "CZ", "DE", "DE_50HZ", "DE_AMPRION", "DE_TRANSNET", "IT_CNOR", "NO", "DE_TENNET"]
to_do_actual_total_load = [x for x in countries_actual_total_load if x not in done_actual_total_load]
to_do_actual_total_load
# Out:
# []

# %%
#Actual Total Load - 1
country_code = "COUNTRY_CODE"  # Replace "COUNTRY_CODE" with the specific country code you want to use:
# Download the actual total load data
try:
    actual_total_load = client.query_load(country_code=country_code, start=start, end=end)
    print(f"Actual Total Load for {country_code}:")
    print(actual_total_load)  # Print the data

    # Rename the columns
    actual_total_load.columns = ['value']

    # Convert the index to UTC and format it as string
    actual_total_load.index = actual_total_load.index.tz_convert('UTC').strftime('%Y-%m-%dT%H:%M:%SZ')

    # Convert the data to InfluxDB Line Protocol format
    data_points = []
    for timestamp, value in actual_total_load.iterrows():
        data_point = Point("actual_total_load") \
            .tag("country", country_code) \
            .field("value", value['value']) \
            .time(timestamp, WritePrecision.NS)
        data_points.append(data_point)
            
    write_api.write(bucket=influxdb_bucket, record=data_points)
    logging.info('Data extraction (actual_total_load) completed for country: %s', country_code)
    print(f"Data extraction (actual_total_load) completed for country: {country_code}")
except Exception as e:
    print(f"Data extraction (actual_total_load) failed for country: {country_code}: {str(e)}")
    logging.error(f'Data extraction (actual_total_load) failed for country: {country_code}: {str(e)}')

# %%
countries_day_ahead_total_load_forecast = country_codes
done_day_ahead_total_load_forecast = []
to_do_day_ahead_total_load_forecast = [x for x in countries_day_ahead_total_load_forecast if x not in done_day_ahead_total_load_forecast]
to_do_day_ahead_total_load_forecast
# Out:
# ['AL',
#  'AT',
#  'BA',
#  'BE',
#  'BG',
#  'BY',
#  'CH',
#  'CWE',
#  'CY',
#  'CZ',
#  'CZ_DE_SK',
#  'DE',
#  'DE_50HZ',
#  'DE_AMPRION',
#  'DE_AT_LU',
#  'DE_LU',
#  'DE_TENNET',
#  'DE_TRANSNET',
#  'DK',
#  'DK_1',
#  'DK_2',
#  'DK_CA',
#  'EE',
#  'ES',
#  'FI',
#  'FR',
#  'GB',
#  'GB_NIR',
#  'GR',
#  'HR',
#  'HU',
#  'IE',
#  'IE_SEM',
#  'IS',
#  'IT',
#  'IT_BRNN',
#  'IT_CNOR',
#  'IT_CSUD',
#  'IT_FOGN',
#  'IT_GR',
#  'IT_MACRO_NORTH',
#  'IT_MACRO_SOUTH',
#  'IT_MALTA',
#  'IT_NORD',
#  'IT_NORD_AT',
#  'IT_NORD_CH',
#  'IT_NORD_FR',
#  'IT_NORD_SI',
#  'IT_PRGP',
#  'IT_ROSN',
#  'IT_SACO_AC',
#  'IT_SACO_DC',
#  'IT_SARD',
#  'IT_SICI',
#  'IT_SUD',
#  'LT',
#  'LU',
#  'LV',
#  'MD',
#  'ME',
#  'MK',
#  'MT',
#  'NL',
#  'NO',
#  'NO_1',
#  'NO_2',
#  'NO_3',
#  'NO_4',
#  'NO_5',
#  'PL',
#  'PL_CZ',
#  'PT',
#  'RO',
#  'RS',
#  'RU',
#  'RU_KGD',
#  'SE',
#  'SE_1',
#  'SE_2',
#  'SE_3',
#  'SE_4',
#  'SI',
#  'SK',
#  'TR',
#  'UA',
#  'UA_BEI',
#  'UA_DOBTPP',
#  'UA_IPS']

# %%
# Download day-ahead total load forecast - 2
country_code = "COUNTRY_CODE"  # Replace "COUNTRY_CODE" with the specific country code you want to use
for country_code in countries_day_ahead_total_load_forecast:
    try:
        day_ahead_total_load_forecast = client.query_load_forecast(country_code=country_code, start=start, end=end)
        print(f"Day-Ahead Total Load Forecast for {country_code}:")
        print(day_ahead_total_load_forecast)  # Print the data

        # Rename the columns
        day_ahead_total_load_forecast.columns = ['value']

        # Convert the index to UTC and format it as string
        day_ahead_total_load_forecast.index = day_ahead_total_load_forecast.index.tz_convert('UTC').strftime('%Y-%m-%dT%H:%M:%SZ')

        # Convert the data to InfluxDB Line Protocol format
        data_points = []
        for timestamp, value in day_ahead_total_load_forecast.iterrows():
            data_point = Point("day_ahead_total_load_forecast") \
                .tag("country", country_code) \
                .field("value", value['value']) \
                .time(timestamp, WritePrecision.NS)
            data_points.append(data_point)

        # Write data points to InfluxDB
        write_api.write(bucket=influxdb_bucket, record=data_points)
        logging.info('Data extraction (day_ahead_total_load_forecast) completed for country: %s', country_code)

    except Exception as e:
        logging.error(f'Data extraction (day_ahead_total_load_forecast) failed for {country_code}: {str(e)}')
        print(f'Data extraction (day_ahead_total_load_forecast) failed for country: {country_code} - {str(e)}')
# Out:
# Day-Ahead Total Load Forecast for AL:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00            629.0
# 2023-07-18 02:15:00+02:00            629.0
# 2023-07-18 02:30:00+02:00            629.0
# 2023-07-18 02:45:00+02:00            629.0
# 2023-07-18 03:00:00+02:00            597.0
# ...                                    ...
# 2023-08-03 01:00:00+02:00            664.0
# 2023-08-03 01:15:00+02:00            664.0
# 2023-08-03 01:30:00+02:00            664.0
# 2023-08-03 01:45:00+02:00            664.0
# 2023-08-03 02:00:00+02:00            624.0
#
# [1537 rows x 1 columns]
# Day-Ahead Total Load Forecast for AT:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           5116.0
# 2023-07-18 02:15:00+02:00           5064.0
# 2023-07-18 02:30:00+02:00           5016.0
# 2023-07-18 02:45:00+02:00           4980.0
# 2023-07-18 03:00:00+02:00           4976.0
# ...                                    ...
# 2023-08-03 01:00:00+02:00           5044.0
# 2023-08-03 01:15:00+02:00           4980.0
# 2023-08-03 01:30:00+02:00           4916.0
# 2023-08-03 01:45:00+02:00           4872.0
# 2023-08-03 02:00:00+02:00           4948.0
#
# [1537 rows x 1 columns]
# Day-Ahead Total Load Forecast for BA:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00            909.0
# 2023-07-18 03:00:00+02:00            896.0
# 2023-07-18 04:00:00+02:00            900.0
# 2023-07-18 05:00:00+02:00            889.0
# 2023-07-18 06:00:00+02:00           1041.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           1248.0
# 2023-08-02 23:00:00+02:00           1134.0
# 2023-08-03 00:00:00+02:00           1020.0
# 2023-08-03 01:00:00+02:00            943.0
# 2023-08-03 02:00:00+02:00            902.0
#
# [385 rows x 1 columns]
# Day-Ahead Total Load Forecast for BE:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           7103.0
# 2023-07-18 02:15:00+02:00           7042.0
# 2023-07-18 02:30:00+02:00           6999.0
# 2023-07-18 02:45:00+02:00           7000.0
# 2023-07-18 03:00:00+02:00           7015.0
# ...                                    ...
# 2023-08-03 01:00:00+02:00           6976.0
# 2023-08-03 01:15:00+02:00           6948.0
# 2023-08-03 01:30:00+02:00           6879.0
# 2023-08-03 01:45:00+02:00           6792.0
# 2023-08-03 02:00:00+02:00           6790.0
#
# [1537 rows x 1 columns]
# Day-Ahead Total Load Forecast for BG:
#                            Forecasted Load
# 2023-07-18 03:00:00+03:00           3277.0
# 2023-07-18 04:00:00+03:00           3270.0
# 2023-07-18 05:00:00+03:00           3348.0
# 2023-07-18 06:00:00+03:00           3598.0
# 2023-07-18 07:00:00+03:00           3867.0
# ...                                    ...
# 2023-08-02 23:00:00+03:00           3901.0
# 2023-08-03 00:00:00+03:00           3563.0
# 2023-08-03 01:00:00+03:00           3299.0
# 2023-08-03 02:00:00+03:00           3159.0
# 2023-08-03 03:00:00+03:00           3086.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for country: BY -
# Day-Ahead Total Load Forecast for CH:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           5381.0
# 2023-07-18 03:00:00+02:00           5443.0
# 2023-07-18 04:00:00+02:00           5809.0
# 2023-07-18 05:00:00+02:00           5490.0
# 2023-07-18 06:00:00+02:00           5850.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           6157.0
# 2023-08-02 23:00:00+02:00           6122.0
# 2023-08-03 00:00:00+02:00           6233.0
# 2023-08-03 01:00:00+02:00           5354.0
# 2023-08-03 02:00:00+02:00           5379.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for country: CWE - 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A65&processType=A01&outBiddingZone_Domain=10YDOM-REGION-1V&securityToken=6276342c-e10c-4d88-8688-cb0a1cf163ca&periodStart=202307180000&periodEnd=202308030000
# Data extraction (day_ahead_total_load_forecast) failed for country: CY -
# Day-Ahead Total Load Forecast for CZ:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           5214.0
# 2023-07-18 03:00:00+02:00           5134.0
# 2023-07-18 04:00:00+02:00           5186.0
# 2023-07-18 05:00:00+02:00           5428.0
# 2023-07-18 06:00:00+02:00           6339.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           5499.0
# 2023-08-02 23:00:00+02:00           5092.0
# 2023-08-03 00:00:00+02:00           4774.0
# 2023-08-03 01:00:00+02:00           4715.0
# 2023-08-03 02:00:00+02:00           4555.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for country: CZ_DE_SK -
# Day-Ahead Total Load Forecast for DE:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00          40002.0
# 2023-07-18 02:15:00+02:00          39776.0
# 2023-07-18 02:30:00+02:00          39739.0
# 2023-07-18 02:45:00+02:00          39797.0
# 2023-07-18 03:00:00+02:00          40046.0
# ...                                    ...
# 2023-08-03 01:00:00+02:00          38361.0
# 2023-08-03 01:15:00+02:00          38219.0
# 2023-08-03 01:30:00+02:00          37959.0
# 2023-08-03 01:45:00+02:00          37785.0
# 2023-08-03 02:00:00+02:00          37490.0
#
# [1537 rows x 1 columns]
# Day-Ahead Total Load Forecast for DE_50HZ:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           9009.0
# 2023-07-18 02:15:00+02:00           8973.0
# 2023-07-18 02:30:00+02:00           9026.0
# 2023-07-18 02:45:00+02:00           9023.0
# 2023-07-18 03:00:00+02:00           9158.0
# ...                                    ...
# 2023-08-03 01:00:00+02:00           9046.0
# 2023-08-03 01:15:00+02:00           8971.0
# 2023-08-03 01:30:00+02:00           8883.0
# 2023-08-03 01:45:00+02:00           8837.0
# 2023-08-03 02:00:00+02:00           8742.0
#
# [1537 rows x 1 columns]
# Day-Ahead Total Load Forecast for DE_AMPRION:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00          13410.0
# 2023-07-18 02:15:00+02:00          13355.0
# 2023-07-18 02:30:00+02:00          13351.0
# 2023-07-18 02:45:00+02:00          13351.0
# 2023-07-18 03:00:00+02:00          13380.0
# ...                                    ...
# 2023-08-03 01:00:00+02:00          14038.0
# 2023-08-03 01:15:00+02:00          13957.0
# 2023-08-03 01:30:00+02:00          13867.0
# 2023-08-03 01:45:00+02:00          13790.0
# 2023-08-03 02:00:00+02:00          13655.0
#
# [1537 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for country: DE_AT_LU -
# Day-Ahead Total Load Forecast for DE_LU:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00          40407.0
# 2023-07-18 02:15:00+02:00          40180.0
# 2023-07-18 02:30:00+02:00          40143.0
# 2023-07-18 02:45:00+02:00          40202.0
# 2023-07-18 03:00:00+02:00          40453.0
# ...                                    ...
# 2023-08-03 01:00:00+02:00          38771.0
# 2023-08-03 01:15:00+02:00          38626.0
# 2023-08-03 01:30:00+02:00          38362.0
# 2023-08-03 01:45:00+02:00          38187.0
# 2023-08-03 02:00:00+02:00          37893.0
#
# [1537 rows x 1 columns]
# Day-Ahead Total Load Forecast for DE_TENNET:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00          11848.0
# 2023-07-18 02:15:00+02:00          11728.0
# 2023-07-18 02:30:00+02:00          11666.0
# 2023-07-18 02:45:00+02:00          11728.0
# 2023-07-18 03:00:00+02:00          11812.0
# ...                                    ...
# 2023-08-03 01:00:00+02:00           9916.0
# 2023-08-03 01:15:00+02:00           9972.0
# 2023-08-03 01:30:00+02:00           9954.0
# 2023-08-03 01:45:00+02:00           9932.0
# 2023-08-03 02:00:00+02:00           9875.0
#
# [1537 rows x 1 columns]
# Day-Ahead Total Load Forecast for DE_TRANSNET:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           5734.0
# 2023-07-18 02:15:00+02:00           5721.0
# 2023-07-18 02:30:00+02:00           5696.0
# 2023-07-18 02:45:00+02:00           5696.0
# 2023-07-18 03:00:00+02:00           5696.0
# ...                                    ...
# 2023-08-03 01:00:00+02:00           5362.0
# 2023-08-03 01:15:00+02:00           5319.0
# 2023-08-03 01:30:00+02:00           5255.0
# 2023-08-03 01:45:00+02:00           5226.0
# 2023-08-03 02:00:00+02:00           5218.0
#
# [1537 rows x 1 columns]
# Day-Ahead Total Load Forecast for DK:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           2575.0
# 2023-07-18 03:00:00+02:00           2569.0
# 2023-07-18 04:00:00+02:00           2546.0
# 2023-07-18 05:00:00+02:00           2572.0
# 2023-07-18 06:00:00+02:00           2913.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           3372.0
# 2023-08-02 23:00:00+02:00           3162.0
# 2023-08-03 00:00:00+02:00           2945.0
# 2023-08-03 01:00:00+02:00           2889.0
# 2023-08-03 02:00:00+02:00           2894.0
#
# [385 rows x 1 columns]
# Day-Ahead Total Load Forecast for DK_1:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           1556.0
# 2023-07-18 03:00:00+02:00           1552.0
# 2023-07-18 04:00:00+02:00           1548.0
# 2023-07-18 05:00:00+02:00           1591.0
# 2023-07-18 06:00:00+02:00           1793.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           1915.0
# 2023-08-02 23:00:00+02:00           1780.0
# 2023-08-03 00:00:00+02:00           1753.0
# 2023-08-03 01:00:00+02:00           1718.0
# 2023-08-03 02:00:00+02:00           1729.0
#
# [385 rows x 1 columns]
# Day-Ahead Total Load Forecast for DK_2:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           1019.0
# 2023-07-18 03:00:00+02:00           1017.0
# 2023-07-18 04:00:00+02:00            998.0
# 2023-07-18 05:00:00+02:00            981.0
# 2023-07-18 06:00:00+02:00           1120.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           1457.0
# 2023-08-02 23:00:00+02:00           1382.0
# 2023-08-03 00:00:00+02:00           1192.0
# 2023-08-03 01:00:00+02:00           1171.0
# 2023-08-03 02:00:00+02:00           1165.0
#
# [385 rows x 1 columns]
# Day-Ahead Total Load Forecast for DK_CA:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           2575.0
# 2023-07-18 03:00:00+02:00           2569.0
# 2023-07-18 04:00:00+02:00           2546.0
# 2023-07-18 05:00:00+02:00           2572.0
# 2023-07-18 06:00:00+02:00           2913.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           3372.0
# 2023-08-02 23:00:00+02:00           3162.0
# 2023-08-03 00:00:00+02:00           2945.0
# 2023-08-03 01:00:00+02:00           2889.0
# 2023-08-03 02:00:00+02:00           2894.0
#
# [385 rows x 1 columns]
# Day-Ahead Total Load Forecast for EE:
#                            Forecasted Load
# 2023-07-18 03:00:00+03:00            584.0
# 2023-07-18 04:00:00+03:00            571.0
# 2023-07-18 05:00:00+03:00            584.0
# 2023-07-18 06:00:00+03:00            663.0
# 2023-07-18 07:00:00+03:00            730.0
# ...                                    ...
# 2023-08-02 23:00:00+03:00            715.0
# 2023-08-03 00:00:00+03:00            679.0
# 2023-08-03 01:00:00+03:00            624.0
# 2023-08-03 02:00:00+03:00            621.0
# 2023-08-03 03:00:00+03:00            620.0
#
# [385 rows x 1 columns]
# Day-Ahead Total Load Forecast for ES:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00          26844.0
# 2023-07-18 02:15:00+02:00          26563.0
# 2023-07-18 02:30:00+02:00          26319.0
# 2023-07-18 02:45:00+02:00          26108.0
# 2023-07-18 03:00:00+02:00          25880.0
# ...                                    ...
# 2023-08-03 01:00:00+02:00          26578.0
# 2023-08-03 01:15:00+02:00          26178.0
# 2023-08-03 01:30:00+02:00          25813.0
# 2023-08-03 01:45:00+02:00          25483.0
# 2023-08-03 02:00:00+02:00          25128.0
#
# [1537 rows x 1 columns]
# Day-Ahead Total Load Forecast for FI:
#                            Forecasted Load
# 2023-07-18 03:00:00+03:00           6214.0
# 2023-07-18 03:15:00+03:00           6187.0
# 2023-07-18 03:30:00+03:00           6174.0
# 2023-07-18 03:45:00+03:00           6161.0
# 2023-07-18 04:00:00+03:00           6146.0
# ...                                    ...
# 2023-08-03 02:00:00+03:00           6492.0
# 2023-08-03 02:15:00+03:00           6460.0
# 2023-08-03 02:30:00+03:00           6437.0
# 2023-08-03 02:45:00+03:00           6410.0
# 2023-08-03 03:00:00+03:00           6378.0
#
# [1537 rows x 1 columns]
# Day-Ahead Total Load Forecast for FR:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00          38800.0
# 2023-07-18 03:00:00+02:00          37050.0
# 2023-07-18 04:00:00+02:00          36050.0
# 2023-07-18 05:00:00+02:00          36900.0
# 2023-07-18 06:00:00+02:00          38950.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00          41800.0
# 2023-08-02 23:00:00+02:00          42850.0
# 2023-08-03 00:00:00+02:00          39350.0
# 2023-08-03 01:00:00+02:00          36400.0
# 2023-08-03 02:00:00+02:00          35200.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for country: GB -
# Data extraction (day_ahead_total_load_forecast) failed for country: GB_NIR -
# Day-Ahead Total Load Forecast for GR:
#                            Forecasted Load
# 2023-07-18 03:00:00+03:00           6392.0
# 2023-07-18 04:00:00+03:00           6246.0
# 2023-07-18 05:00:00+03:00           6225.0
# 2023-07-18 06:00:00+03:00           6330.0
# 2023-07-18 07:00:00+03:00           6811.0
# ...                                    ...
# 2023-08-02 23:00:00+03:00           7279.0
# 2023-08-03 00:00:00+03:00           7098.0
# 2023-08-03 01:00:00+03:00           6632.0
# 2023-08-03 02:00:00+03:00           6352.0
# 2023-08-03 03:00:00+03:00           6140.0
#
# [385 rows x 1 columns]
# Day-Ahead Total Load Forecast for HR:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           1965.0
# 2023-07-18 03:00:00+02:00           1889.0
# 2023-07-18 04:00:00+02:00           1889.0
# 2023-07-18 05:00:00+02:00           1900.0
# 2023-07-18 06:00:00+02:00           2187.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           2568.0
# 2023-08-02 23:00:00+02:00           2336.0
# 2023-08-03 00:00:00+02:00           1870.0
# 2023-08-03 01:00:00+02:00           1806.0
# 2023-08-03 02:00:00+02:00           1746.0
#
# [385 rows x 1 columns]
# Day-Ahead Total Load Forecast for HU:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           4176.0
# 2023-07-18 02:15:00+02:00           4131.0
# 2023-07-18 02:30:00+02:00           4098.0
# 2023-07-18 02:45:00+02:00           4078.0
# 2023-07-18 03:00:00+02:00           4068.0
# ...                                    ...
# 2023-08-03 01:00:00+02:00           3889.0
# 2023-08-03 01:15:00+02:00           3844.0
# 2023-08-03 01:30:00+02:00           3798.0
# 2023-08-03 01:45:00+02:00           3750.0
# 2023-08-03 02:00:00+02:00           3702.0
#
# [1537 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for country: IE -
# Data extraction (day_ahead_total_load_forecast) failed for country: IE_SEM -
# Data extraction (day_ahead_total_load_forecast) failed for country: IS -
# Day-Ahead Total Load Forecast for IT:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00          32639.0
# 2023-07-18 03:00:00+02:00          32145.0
# 2023-07-18 04:00:00+02:00          31899.0
# 2023-07-18 05:00:00+02:00          32628.0
# 2023-07-18 06:00:00+02:00          35466.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00          37251.0
# 2023-08-02 23:00:00+02:00          34515.0
# 2023-08-03 00:00:00+02:00          31277.0
# 2023-08-03 01:00:00+02:00          29403.0
# 2023-08-03 02:00:00+02:00          28165.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for country: IT_BRNN -
# Day-Ahead Total Load Forecast for IT_CNOR:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           2526.0
# 2023-07-18 03:00:00+02:00           2516.0
# 2023-07-18 04:00:00+02:00           2433.0
# 2023-07-18 05:00:00+02:00           2505.0
# 2023-07-18 06:00:00+02:00           2766.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           3092.0
# 2023-08-02 23:00:00+02:00           2812.0
# 2023-08-03 00:00:00+02:00           2530.0
# 2023-08-03 01:00:00+02:00           2422.0
# 2023-08-03 02:00:00+02:00           2376.0
#
# [385 rows x 1 columns]
# Day-Ahead Total Load Forecast for IT_CSUD:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           5235.0
# 2023-07-18 03:00:00+02:00           5137.0
# 2023-07-18 04:00:00+02:00           5011.0
# 2023-07-18 05:00:00+02:00           5125.0
# 2023-07-18 06:00:00+02:00           5583.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           6745.0
# 2023-08-02 23:00:00+02:00           6293.0
# 2023-08-03 00:00:00+02:00           5384.0
# 2023-08-03 01:00:00+02:00           5022.0
# 2023-08-03 02:00:00+02:00           4737.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for country: IT_FOGN -
# Data extraction (day_ahead_total_load_forecast) failed for country: IT_GR -
# Data extraction (day_ahead_total_load_forecast) failed for country: IT_MACRO_NORTH - 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A65&processType=A01&outBiddingZone_Domain=10Y1001A1001A84D&securityToken=6276342c-e10c-4d88-8688-cb0a1cf163ca&periodStart=202307180000&periodEnd=202308030000
# Data extraction (day_ahead_total_load_forecast) failed for country: IT_MACRO_SOUTH - 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A65&processType=A01&outBiddingZone_Domain=10Y1001A1001A85B&securityToken=6276342c-e10c-4d88-8688-cb0a1cf163ca&periodStart=202307180000&periodEnd=202308030000
# Data extraction (day_ahead_total_load_forecast) failed for country: IT_MALTA -
# Day-Ahead Total Load Forecast for IT_NORD:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00          18261.0
# 2023-07-18 03:00:00+02:00          18059.0
# 2023-07-18 04:00:00+02:00          18148.0
# 2023-07-18 05:00:00+02:00          18665.0
# 2023-07-18 06:00:00+02:00          20654.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00          19434.0
# 2023-08-02 23:00:00+02:00          18086.0
# 2023-08-03 00:00:00+02:00          16209.0
# 2023-08-03 01:00:00+02:00          15111.0
# 2023-08-03 02:00:00+02:00          14340.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for country: IT_NORD_AT -
# Data extraction (day_ahead_total_load_forecast) failed for country: IT_NORD_CH -
# Data extraction (day_ahead_total_load_forecast) failed for country: IT_NORD_FR -
# Data extraction (day_ahead_total_load_forecast) failed for country: IT_NORD_SI -
# Data extraction (day_ahead_total_load_forecast) failed for country: IT_PRGP -
# Data extraction (day_ahead_total_load_forecast) failed for country: IT_ROSN -
# Data extraction (day_ahead_total_load_forecast) failed for country: IT_SACO_AC -
# Data extraction (day_ahead_total_load_forecast) failed for country: IT_SACO_DC -
# Day-Ahead Total Load Forecast for IT_SARD:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00            935.0
# 2023-07-18 03:00:00+02:00            905.0
# 2023-07-18 04:00:00+02:00            892.0
# 2023-07-18 05:00:00+02:00            905.0
# 2023-07-18 06:00:00+02:00            927.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           1155.0
# 2023-08-02 23:00:00+02:00           1065.0
# 2023-08-03 00:00:00+02:00           1007.0
# 2023-08-03 01:00:00+02:00            967.0
# 2023-08-03 02:00:00+02:00            935.0
#
# [385 rows x 1 columns]
# Day-Ahead Total Load Forecast for IT_SICI:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           2180.0
# 2023-07-18 03:00:00+02:00           2095.0
# 2023-07-18 04:00:00+02:00           2050.0
# 2023-07-18 05:00:00+02:00           2052.0
# 2023-07-18 06:00:00+02:00           2082.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           2740.0
# 2023-08-02 23:00:00+02:00           2557.0
# 2023-08-03 00:00:00+02:00           2422.0
# 2023-08-03 01:00:00+02:00           2277.0
# 2023-08-03 02:00:00+02:00           2172.0
#
# [385 rows x 1 columns]
# Day-Ahead Total Load Forecast for IT_SUD:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           2837.0
# 2023-07-18 03:00:00+02:00           2818.0
# 2023-07-18 04:00:00+02:00           2753.0
# 2023-07-18 05:00:00+02:00           2774.0
# 2023-07-18 06:00:00+02:00           2759.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           3080.0
# 2023-08-02 23:00:00+02:00           2875.0
# 2023-08-03 00:00:00+02:00           2903.0
# 2023-08-03 01:00:00+02:00           2754.0
# 2023-08-03 02:00:00+02:00           2568.0
#
# [385 rows x 1 columns]
# Day-Ahead Total Load Forecast for LT:
#                            Forecasted Load
# 2023-07-18 03:00:00+03:00           1005.0
# 2023-07-18 04:00:00+03:00           1003.0
# 2023-07-18 05:00:00+03:00            993.0
# 2023-07-18 06:00:00+03:00           1024.0
# 2023-07-18 07:00:00+03:00           1183.0
# ...                                    ...
# 2023-08-02 23:00:00+03:00           1276.0
# 2023-08-03 00:00:00+03:00           1178.0
# 2023-08-03 01:00:00+03:00           1086.0
# 2023-08-03 02:00:00+03:00           1030.0
# 2023-08-03 03:00:00+03:00            999.0
#
# [385 rows x 1 columns]
# Day-Ahead Total Load Forecast for LU:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00            405.0
# 2023-07-18 02:15:00+02:00            404.0
# 2023-07-18 02:30:00+02:00            404.0
# 2023-07-18 02:45:00+02:00            405.0
# 2023-07-18 03:00:00+02:00            407.0
# ...                                    ...
# 2023-08-03 01:00:00+02:00            410.0
# 2023-08-03 01:15:00+02:00            407.0
# 2023-08-03 01:30:00+02:00            403.0
# 2023-08-03 01:45:00+02:00            402.0
# 2023-08-03 02:00:00+02:00            403.0
#
# [1537 rows x 1 columns]
# Day-Ahead Total Load Forecast for LV:
#                            Forecasted Load
# 2023-07-18 03:00:00+03:00            483.0
# 2023-07-18 04:00:00+03:00            467.0
# 2023-07-18 05:00:00+03:00            482.0
# 2023-07-18 06:00:00+03:00            565.0
# 2023-07-18 07:00:00+03:00            663.0
# ...                                    ...
# 2023-08-02 23:00:00+03:00            628.0
# 2023-08-03 00:00:00+03:00            566.0
# 2023-08-03 01:00:00+03:00            536.0
# 2023-08-03 02:00:00+03:00            518.0
# 2023-08-03 03:00:00+03:00            521.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for country: MD -
# Day-Ahead Total Load Forecast for ME:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00            317.0
# 2023-07-18 03:00:00+02:00            299.0
# 2023-07-18 04:00:00+02:00            291.0
# 2023-07-18 05:00:00+02:00            288.0
# 2023-07-18 06:00:00+02:00            317.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00            454.0
# 2023-08-02 23:00:00+02:00            421.0
# 2023-08-03 00:00:00+02:00            357.0
# 2023-08-03 01:00:00+02:00            329.0
# 2023-08-03 02:00:00+02:00            300.0
#
# [385 rows x 1 columns]
# Day-Ahead Total Load Forecast for MK:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00            589.0
# 2023-07-18 03:00:00+02:00            559.0
# 2023-07-18 04:00:00+02:00            555.0
# 2023-07-18 05:00:00+02:00            552.0
# 2023-07-18 06:00:00+02:00            581.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00            727.0
# 2023-08-02 23:00:00+02:00            690.0
# 2023-08-03 00:00:00+02:00            609.0
# 2023-08-03 01:00:00+02:00            547.0
# 2023-08-03 02:00:00+02:00            504.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for country: MT -
# Day-Ahead Total Load Forecast for NL:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00          11447.0
# 2023-07-18 02:15:00+02:00          11477.0
# 2023-07-18 02:30:00+02:00          11440.0
# 2023-07-18 02:45:00+02:00          11373.0
# 2023-07-18 03:00:00+02:00          11330.0
# ...                                    ...
# 2023-08-03 01:00:00+02:00          11622.0
# 2023-08-03 01:15:00+02:00          11530.0
# 2023-08-03 01:30:00+02:00          11464.0
# 2023-08-03 01:45:00+02:00          11386.0
# 2023-08-03 02:00:00+02:00          11344.0
#
# [1537 rows x 1 columns]
# Day-Ahead Total Load Forecast for NO:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00          10481.0
# 2023-07-18 03:00:00+02:00          10151.0
# 2023-07-18 04:00:00+02:00          10190.0
# 2023-07-18 05:00:00+02:00          10219.0
# 2023-07-18 06:00:00+02:00          10907.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00          11542.0
# 2023-08-02 23:00:00+02:00          11313.0
# 2023-08-03 00:00:00+02:00          10968.0
# 2023-08-03 01:00:00+02:00          10803.0
# 2023-08-03 02:00:00+02:00          10476.0
#
# [385 rows x 1 columns]
# Day-Ahead Total Load Forecast for NO_1:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           2090.0
# 2023-07-18 03:00:00+02:00           1915.0
# 2023-07-18 04:00:00+02:00           1950.0
# 2023-07-18 05:00:00+02:00           1966.0
# 2023-07-18 06:00:00+02:00           2215.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           2581.0
# 2023-08-02 23:00:00+02:00           2441.0
# 2023-08-03 00:00:00+02:00           2289.0
# 2023-08-03 01:00:00+02:00           2256.0
# 2023-08-03 02:00:00+02:00           2199.0
#
# [385 rows x 1 columns]
# Day-Ahead Total Load Forecast for NO_2:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           2689.0
# 2023-07-18 03:00:00+02:00           2643.0
# 2023-07-18 04:00:00+02:00           2662.0
# 2023-07-18 05:00:00+02:00           2737.0
# 2023-07-18 06:00:00+02:00           2892.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           2934.0
# 2023-08-02 23:00:00+02:00           2855.0
# 2023-08-03 00:00:00+02:00           2746.0
# 2023-08-03 01:00:00+02:00           2699.0
# 2023-08-03 02:00:00+02:00           2640.0
#
# [385 rows x 1 columns]
# Day-Ahead Total Load Forecast for NO_3:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           2457.0
# 2023-07-18 03:00:00+02:00           2430.0
# 2023-07-18 04:00:00+02:00           2407.0
# 2023-07-18 05:00:00+02:00           2343.0
# 2023-07-18 06:00:00+02:00           2437.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           2612.0
# 2023-08-02 23:00:00+02:00           2623.0
# 2023-08-03 00:00:00+02:00           2591.0
# 2023-08-03 01:00:00+02:00           2548.0
# 2023-08-03 02:00:00+02:00           2454.0
#
# [385 rows x 1 columns]
# Day-Ahead Total Load Forecast for NO_4:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           1660.0
# 2023-07-18 03:00:00+02:00           1617.0
# 2023-07-18 04:00:00+02:00           1597.0
# 2023-07-18 05:00:00+02:00           1600.0
# 2023-07-18 06:00:00+02:00           1668.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           1675.0
# 2023-08-02 23:00:00+02:00           1694.0
# 2023-08-03 00:00:00+02:00           1721.0
# 2023-08-03 01:00:00+02:00           1696.0
# 2023-08-03 02:00:00+02:00           1629.0
#
# [385 rows x 1 columns]
# Day-Ahead Total Load Forecast for NO_5:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           1585.0
# 2023-07-18 03:00:00+02:00           1546.0
# 2023-07-18 04:00:00+02:00           1574.0
# 2023-07-18 05:00:00+02:00           1573.0
# 2023-07-18 06:00:00+02:00           1695.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           1740.0
# 2023-08-02 23:00:00+02:00           1700.0
# 2023-08-03 00:00:00+02:00           1619.0
# 2023-08-03 01:00:00+02:00           1604.0
# 2023-08-03 02:00:00+02:00           1555.0
#
# [385 rows x 1 columns]
# Day-Ahead Total Load Forecast for PL:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00          14994.0
# 2023-07-18 03:00:00+02:00          15058.0
# 2023-07-18 04:00:00+02:00          14985.0
# 2023-07-18 05:00:00+02:00          15685.0
# 2023-07-18 06:00:00+02:00          17993.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00          18167.0
# 2023-08-02 23:00:00+02:00          16624.0
# 2023-08-03 00:00:00+02:00          15115.0
# 2023-08-03 01:00:00+02:00          14292.0
# 2023-08-03 02:00:00+02:00          13677.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for country: PL_CZ -
# Day-Ahead Total Load Forecast for PT:
#                            Forecasted Load
# 2023-07-18 01:00:00+01:00           4952.0
# 2023-07-18 02:00:00+01:00           4803.0
# 2023-07-18 03:00:00+01:00           4720.0
# 2023-07-18 04:00:00+01:00           4690.0
# 2023-07-18 05:00:00+01:00           4715.0
# ...                                    ...
# 2023-08-02 21:00:00+01:00           6719.0
# 2023-08-02 22:00:00+01:00           6486.0
# 2023-08-02 23:00:00+01:00           5573.0
# 2023-08-03 00:00:00+01:00           5140.0
# 2023-08-03 01:00:00+01:00           4881.0
#
# [385 rows x 1 columns]
# Day-Ahead Total Load Forecast for RO:
#                            Forecasted Load
# 2023-07-18 03:00:00+03:00           5480.0
# 2023-07-18 03:15:00+03:00           5470.0
# 2023-07-18 03:30:00+03:00           5470.0
# 2023-07-18 03:45:00+03:00           5470.0
# 2023-07-18 04:00:00+03:00           5470.0
# ...                                    ...
# 2023-08-03 02:00:00+03:00           5270.0
# 2023-08-03 02:15:00+03:00           5230.0
# 2023-08-03 02:30:00+03:00           5200.0
# 2023-08-03 02:45:00+03:00           5190.0
# 2023-08-03 03:00:00+03:00           5180.0
#
# [1537 rows x 1 columns]
# Day-Ahead Total Load Forecast for RS:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           2762.0
# 2023-07-18 03:00:00+02:00           2664.0
# 2023-07-18 04:00:00+02:00           2643.0
# 2023-07-18 05:00:00+02:00           2706.0
# 2023-07-18 06:00:00+02:00           3035.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           3951.0
# 2023-08-02 23:00:00+02:00           3702.0
# 2023-08-03 00:00:00+02:00           3191.0
# 2023-08-03 01:00:00+02:00           2902.0
# 2023-08-03 02:00:00+02:00           2733.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for country: RU -
# Data extraction (day_ahead_total_load_forecast) failed for country: RU_KGD -
# Day-Ahead Total Load Forecast for SE:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           9878.0
# 2023-07-18 03:00:00+02:00           9768.0
# 2023-07-18 04:00:00+02:00           9687.0
# 2023-07-18 05:00:00+02:00           9786.0
# 2023-07-18 06:00:00+02:00          10348.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00          11455.0
# 2023-08-02 23:00:00+02:00          10888.0
# 2023-08-03 00:00:00+02:00          10382.0
# 2023-08-03 01:00:00+02:00          10104.0
# 2023-08-03 02:00:00+02:00           9999.0
#
# [385 rows x 1 columns]
# Day-Ahead Total Load Forecast for SE_1:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00            997.0
# 2023-07-18 03:00:00+02:00            992.0
# 2023-07-18 04:00:00+02:00            996.0
# 2023-07-18 05:00:00+02:00           1008.0
# 2023-07-18 06:00:00+02:00           1035.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           1103.0
# 2023-08-02 23:00:00+02:00           1080.0
# 2023-08-03 00:00:00+02:00           1057.0
# 2023-08-03 01:00:00+02:00           1040.0
# 2023-08-03 02:00:00+02:00           1028.0
#
# [385 rows x 1 columns]
# Day-Ahead Total Load Forecast for SE_2:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           1318.0
# 2023-07-18 03:00:00+02:00           1309.0
# 2023-07-18 04:00:00+02:00           1303.0
# 2023-07-18 05:00:00+02:00           1342.0
# 2023-07-18 06:00:00+02:00           1425.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           1531.0
# 2023-08-02 23:00:00+02:00           1485.0
# 2023-08-03 00:00:00+02:00           1408.0
# 2023-08-03 01:00:00+02:00           1376.0
# 2023-08-03 02:00:00+02:00           1359.0
#
# [385 rows x 1 columns]
# Day-Ahead Total Load Forecast for SE_3:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           6020.0
# 2023-07-18 03:00:00+02:00           5939.0
# 2023-07-18 04:00:00+02:00           5864.0
# 2023-07-18 05:00:00+02:00           5906.0
# 2023-07-18 06:00:00+02:00           6229.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           6986.0
# 2023-08-02 23:00:00+02:00           6611.0
# 2023-08-03 00:00:00+02:00           6291.0
# 2023-08-03 01:00:00+02:00           6106.0
# 2023-08-03 02:00:00+02:00           6047.0
#
# [385 rows x 1 columns]
# Day-Ahead Total Load Forecast for SE_4:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           1543.0
# 2023-07-18 03:00:00+02:00           1528.0
# 2023-07-18 04:00:00+02:00           1524.0
# 2023-07-18 05:00:00+02:00           1530.0
# 2023-07-18 06:00:00+02:00           1659.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           1835.0
# 2023-08-02 23:00:00+02:00           1712.0
# 2023-08-03 00:00:00+02:00           1626.0
# 2023-08-03 01:00:00+02:00           1582.0
# 2023-08-03 02:00:00+02:00           1565.0
#
# [385 rows x 1 columns]
# Day-Ahead Total Load Forecast for SI:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           1181.0
# 2023-07-18 03:00:00+02:00           1171.0
# 2023-07-18 04:00:00+02:00           1193.0
# 2023-07-18 05:00:00+02:00           1260.0
# 2023-07-18 06:00:00+02:00           1506.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           1150.0
# 2023-08-02 23:00:00+02:00           1070.0
# 2023-08-03 00:00:00+02:00            971.0
# 2023-08-03 01:00:00+02:00            920.0
# 2023-08-03 02:00:00+02:00            899.0
#
# [385 rows x 1 columns]
# Day-Ahead Total Load Forecast for SK:
#                            Forecasted Load
# 2023-07-18 02:00:00+02:00           2300.0
# 2023-07-18 03:00:00+02:00           2280.0
# 2023-07-18 04:00:00+02:00           2330.0
# 2023-07-18 05:00:00+02:00           2520.0
# 2023-07-18 06:00:00+02:00           2800.0
# ...                                    ...
# 2023-08-02 22:00:00+02:00           2500.0
# 2023-08-02 23:00:00+02:00           2360.0
# 2023-08-03 00:00:00+02:00           2180.0
# 2023-08-03 01:00:00+02:00           2120.0
# 2023-08-03 02:00:00+02:00           2100.0
#
# [385 rows x 1 columns]
# Data extraction (day_ahead_total_load_forecast) failed for country: TR -
# Data extraction (day_ahead_total_load_forecast) failed for country: UA -
# Data extraction (day_ahead_total_load_forecast) failed for country: UA_BEI -
# Data extraction (day_ahead_total_load_forecast) failed for country: UA_DOBTPP -
# Data extraction (day_ahead_total_load_forecast) failed for country: UA_IPS -

# %%
#NOTHING TO DO
countries_installed_generation_capacity = country_codes
done_installed_generation_capacity = []
to_do_installed_generation_capacity = [x for x in countries_installed_generation_capacity if x not in done_installed_generation_capacity]
to_do_installed_generation_capacity
# Out:
# ['AL',
#  'AT',
#  'BA',
#  'BE',
#  'BG',
#  'BY',
#  'CH',
#  'CWE',
#  'CY',
#  'CZ',
#  'CZ_DE_SK',
#  'DE',
#  'DE_50HZ',
#  'DE_AMPRION',
#  'DE_AT_LU',
#  'DE_LU',
#  'DE_TENNET',
#  'DE_TRANSNET',
#  'DK',
#  'DK_1',
#  'DK_2',
#  'DK_CA',
#  'EE',
#  'ES',
#  'FI',
#  'FR',
#  'GB',
#  'GB_NIR',
#  'GR',
#  'HR',
#  'HU',
#  'IE',
#  'IE_SEM',
#  'IS',
#  'IT',
#  'IT_BRNN',
#  'IT_CNOR',
#  'IT_CSUD',
#  'IT_FOGN',
#  'IT_GR',
#  'IT_MACRO_NORTH',
#  'IT_MACRO_SOUTH',
#  'IT_MALTA',
#  'IT_NORD',
#  'IT_NORD_AT',
#  'IT_NORD_CH',
#  'IT_NORD_FR',
#  'IT_NORD_SI',
#  'IT_PRGP',
#  'IT_ROSN',
#  'IT_SACO_AC',
#  'IT_SACO_DC',
#  'IT_SARD',
#  'IT_SICI',
#  'IT_SUD',
#  'LT',
#  'LU',
#  'LV',
#  'MD',
#  'ME',
#  'MK',
#  'MT',
#  'NL',
#  'NO',
#  'NO_1',
#  'NO_2',
#  'NO_3',
#  'NO_4',
#  'NO_5',
#  'PL',
#  'PL_CZ',
#  'PT',
#  'RO',
#  'RS',
#  'RU',
#  'RU_KGD',
#  'SE',
#  'SE_1',
#  'SE_2',
#  'SE_3',
#  'SE_4',
#  'SI',
#  'SK',
#  'TR',
#  'UA',
#  'UA_BEI',
#  'UA_DOBTPP',
#  'UA_IPS']

# %%
# Download installed generation capacity - 3
country_code = "COUNTRY_CODE"  # Replace "COUNTRY_CODE" with the specific country code you want to use
for country_code in country_codes:
    try:
        # Download the installed generation capacity data
        installed_generation_capacity = client.query_installed_generation_capacity(country_code, start=start, end=end, psr_type=None)
        print(f"Installed Generation Capacity for {country_code}:")
        print(installed_generation_capacity)

        # Convert the index to UTC and format it as a string
        installed_generation_capacity.index = installed_generation_capacity.index.tz_convert('UTC').strftime('%Y-%m-%dT%H:%M:%SZ')

        # Create data points for each row
        data_points = []
        for _, row in installed_generation_capacity.iterrows():
            for column in installed_generation_capacity.columns[1:]:
                production_type = column
                value = row[column]
                if pd.notnull(value):
                    data_point = Point("installed_generation_capacity") \
                        .tag("country", country_code) \
                        .tag("production_type", production_type) \
                        .field("value", value) \
                        .time(row.name)
                    data_points.append(data_point)

        # Write data points to InfluxDB
        write_api.write(bucket=influxdb_bucket, record=data_points)
        logging.info('Data extraction (installed_generation_capacity) completed for country: %s', country_code)
        print(f'Data extraction (installed_generation_capacity) completed for country: {country_code}')
    except Exception as e:
        logging.error(f'Data extraction (installed_generation_capacity) failed for {country_code}: {str(e)}')
        print(f'Data extraction (installed_generation_capacity) failed for country: {country_code} : {str(e)}')
# Out:
# Installed Generation Capacity for AL:
# Empty DataFrame
# Columns: [Biomass, Hydro Run-of-river and poundage]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: AL
# Installed Generation Capacity for AT:
# Empty DataFrame
# Columns: [Biomass, Fossil Brown coal/Lignite, Fossil Coal-derived gas, Fossil Gas, Fossil Hard coal, Fossil Oil, Fossil Oil shale, Fossil Peat, Geothermal, Hydro Pumped Storage, Hydro Run-of-river and poundage, Hydro Water Reservoir, Marine, Nuclear, Other, Other renewable, Solar, Waste, Wind Offshore, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: AT
# Installed Generation Capacity for BA:
# Empty DataFrame
# Columns: [Fossil Brown coal/Lignite, Hydro Pumped Storage, Hydro Run-of-river and poundage, Hydro Water Reservoir, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: BA
# Installed Generation Capacity for BE:
# Empty DataFrame
# Columns: [Biomass, Fossil Gas, Fossil Oil, Hydro Pumped Storage, Hydro Run-of-river and poundage, Nuclear, Other, Solar, Waste, Wind Offshore, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: BE
# Installed Generation Capacity for BG:
# Empty DataFrame
# Columns: [Biomass, Fossil Brown coal/Lignite, Fossil Coal-derived gas, Fossil Gas, Fossil Hard coal, Fossil Oil, Fossil Oil shale, Fossil Peat, Geothermal, Hydro Pumped Storage, Hydro Run-of-river and poundage, Hydro Water Reservoir, Marine, Nuclear, Other, Other renewable, Solar, Waste, Wind Offshore, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: BG
# Data extraction (installed_generation_capacity) failed for country: BY :
# Installed Generation Capacity for CH:
# Empty DataFrame
# Columns: [Hydro Pumped Storage, Hydro Run-of-river and poundage, Hydro Water Reservoir, Nuclear]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: CH
# Data extraction (installed_generation_capacity) failed for country: CWE : 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A68&processType=A33&in_Domain=10YDOM-REGION-1V&securityToken=6276342c-e10c-4d88-8688-cb0a1cf163ca&periodStart=202307180000&periodEnd=202308030000
# Data extraction (installed_generation_capacity) failed for country: CY :
# Installed Generation Capacity for CZ:
# Empty DataFrame
# Columns: [Biomass, Fossil Brown coal/Lignite, Fossil Coal-derived gas, Fossil Gas, Fossil Hard coal, Fossil Oil, Hydro Pumped Storage, Hydro Run-of-river and poundage, Hydro Water Reservoir, Nuclear, Other, Other renewable, Solar, Waste, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: CZ
# Data extraction (installed_generation_capacity) failed for country: CZ_DE_SK :
# Installed Generation Capacity for DE:
# Empty DataFrame
# Columns: [Biomass, Fossil Brown coal/Lignite, Fossil Coal-derived gas, Fossil Gas, Fossil Hard coal, Fossil Oil, Geothermal, Hydro Pumped Storage, Hydro Run-of-river and poundage, Hydro Water Reservoir, Nuclear, Other, Other renewable, Solar, Waste, Wind Offshore, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: DE
# Installed Generation Capacity for DE_50HZ:
# Empty DataFrame
# Columns: [Biomass, Fossil Brown coal/Lignite, Fossil Gas, Fossil Hard coal, Fossil Oil, Geothermal, Hydro Pumped Storage, Hydro Run-of-river and poundage, Other, Other renewable, Solar, Waste, Wind Offshore, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: DE_50HZ
# Installed Generation Capacity for DE_AMPRION:
# Empty DataFrame
# Columns: [Biomass, Fossil Brown coal/Lignite, Fossil Coal-derived gas, Fossil Gas, Fossil Hard coal, Fossil Oil, Geothermal, Hydro Pumped Storage, Hydro Run-of-river and poundage, Hydro Water Reservoir, Nuclear, Other, Other renewable, Solar, Waste, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: DE_AMPRION
# Data extraction (installed_generation_capacity) failed for country: DE_AT_LU :
# Installed Generation Capacity for DE_LU:
# Empty DataFrame
# Columns: [Biomass, Fossil Brown coal/Lignite, Fossil Coal-derived gas, Fossil Gas, Fossil Hard coal, Fossil Oil, Fossil Oil shale, Fossil Peat, Geothermal, Hydro Pumped Storage, Hydro Run-of-river and poundage, Hydro Water Reservoir, Marine, Nuclear, Other, Other renewable, Solar, Waste, Wind Offshore, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: DE_LU
# Installed Generation Capacity for DE_TENNET:
# Empty DataFrame
# Columns: [Biomass, Fossil Brown coal/Lignite, Fossil Gas, Fossil Hard coal, Fossil Oil, Geothermal, Hydro Pumped Storage, Hydro Run-of-river and poundage, Hydro Water Reservoir, Nuclear, Other, Other renewable, Solar, Waste, Wind Offshore, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: DE_TENNET
# Installed Generation Capacity for DE_TRANSNET:
# Empty DataFrame
# Columns: [Biomass, Fossil Gas, Fossil Hard coal, Fossil Oil, Geothermal, Hydro Pumped Storage, Hydro Run-of-river and poundage, Hydro Water Reservoir, Nuclear, Other, Other renewable, Solar, Waste, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: DE_TRANSNET
# Installed Generation Capacity for DK:
# Empty DataFrame
# Columns: [Biomass, Fossil Gas, Fossil Hard coal, Fossil Oil, Hydro Run-of-river and poundage, Other renewable, Solar, Waste, Wind Offshore, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: DK
# Installed Generation Capacity for DK_1:
# Empty DataFrame
# Columns: [Biomass, Fossil Gas, Fossil Hard coal, Fossil Oil, Hydro Run-of-river and poundage, Other renewable, Solar, Waste, Wind Offshore, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: DK_1
# Installed Generation Capacity for DK_2:
# Empty DataFrame
# Columns: [Biomass, Fossil Gas, Fossil Hard coal, Fossil Oil, Hydro Run-of-river and poundage, Other renewable, Solar, Waste, Wind Offshore, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: DK_2
# Installed Generation Capacity for DK_CA:
# Empty DataFrame
# Columns: [Biomass, Fossil Gas, Fossil Hard coal, Fossil Oil, Hydro Run-of-river and poundage, Other renewable, Solar, Waste, Wind Offshore, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: DK_CA
# Installed Generation Capacity for EE:
# Empty DataFrame
# Columns: [Biomass, Fossil Coal-derived gas, Fossil Gas, Fossil Oil shale, Hydro Run-of-river and poundage, Other, Solar, Waste, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: EE
# Installed Generation Capacity for ES:
# Empty DataFrame
# Columns: [Biomass, Fossil Brown coal/Lignite, Fossil Coal-derived gas, Fossil Gas, Fossil Hard coal, Fossil Oil, Fossil Oil shale, Fossil Peat, Geothermal, Hydro Pumped Storage, Hydro Run-of-river and poundage, Hydro Water Reservoir, Marine, Nuclear, Other, Other renewable, Solar, Waste, Wind Offshore, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: ES
# Installed Generation Capacity for FI:
# Empty DataFrame
# Columns: [Biomass, Fossil Gas, Fossil Hard coal, Fossil Oil, Fossil Peat, Hydro Run-of-river and poundage, Nuclear, Other, Other renewable, Solar, Waste, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: FI
# Installed Generation Capacity for FR:
# Empty DataFrame
# Columns: [Biomass, Fossil Gas, Fossil Hard coal, Fossil Oil, Geothermal, Hydro Pumped Storage, Hydro Run-of-river and poundage, Hydro Water Reservoir, Marine, Nuclear, Other, Solar, Waste, Wind Offshore, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: FR
# Data extraction (installed_generation_capacity) failed for country: GB :
# Installed Generation Capacity for GB_NIR:
#                            Fossil Gas  Fossil Hard coal  Fossil Oil  Other  \
# 2023-01-31 00:00:00+00:00      1549.0             514.0       316.0  301.0
#
#                            Solar  Wind Onshore
# 2023-01-31 00:00:00+00:00   92.0        1066.0
# Data extraction (installed_generation_capacity) completed for country: GB_NIR
# Installed Generation Capacity for GR:
# Empty DataFrame
# Columns: [Biomass, Fossil Brown coal/Lignite, Fossil Gas, Fossil Oil, Geothermal, Hydro Pumped Storage, Hydro Run-of-river and poundage, Hydro Water Reservoir, Other renewable, Solar, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: GR
# Installed Generation Capacity for HR:
# Empty DataFrame
# Columns: [Biomass, Fossil Gas, Fossil Hard coal, Fossil Oil, Geothermal, Hydro Pumped Storage, Hydro Run-of-river and poundage, Hydro Water Reservoir, Other renewable, Solar, Waste, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: HR
# Installed Generation Capacity for HU:
# Empty DataFrame
# Columns: [Biomass, Fossil Brown coal/Lignite, Fossil Gas, Fossil Hard coal, Fossil Oil, Geothermal, Hydro Run-of-river and poundage, Hydro Water Reservoir, Nuclear, Other, Other renewable, Solar, Waste, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: HU
# Installed Generation Capacity for IE:
#                            Fossil Gas  Fossil Hard coal  Fossil Oil  \
# 2023-01-31 00:00:00+00:00      4265.0             855.0      1272.0
#
#                            Fossil Peat  Geothermal  Hydro Pumped Storage  \
# 2023-01-31 00:00:00+00:00        344.0        17.0                 292.0
#
#                            Hydro Run-of-river and poundage  Other  \
# 2023-01-31 00:00:00+00:00                            216.0  647.0
#
#                            Wind Onshore
# 2023-01-31 00:00:00+00:00        1919.0
# Data extraction (installed_generation_capacity) completed for country: IE
# Installed Generation Capacity for IE_SEM:
#                            Fossil Gas  Fossil Hard coal  Fossil Oil  Other  \
# 2023-01-31 00:00:00+00:00      5814.0            1369.0      1588.0  948.0
#
#                            Wind Onshore
# 2023-01-31 00:00:00+00:00        2984.0
# Data extraction (installed_generation_capacity) completed for country: IE_SEM
# Data extraction (installed_generation_capacity) failed for country: IS :
# Installed Generation Capacity for IT:
# Empty DataFrame
# Columns: [Biomass, Fossil Brown coal/Lignite, Fossil Coal-derived gas, Fossil Gas, Fossil Hard coal, Fossil Oil, Fossil Peat, Geothermal, Hydro Pumped Storage, Hydro Run-of-river and poundage, Hydro Water Reservoir, Marine, Other, Other renewable, Solar, Waste, Wind Offshore, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: IT
# Data extraction (installed_generation_capacity) failed for country: IT_BRNN :
# Data extraction (installed_generation_capacity) failed for country: IT_CNOR :
# Data extraction (installed_generation_capacity) failed for country: IT_CSUD :
# Data extraction (installed_generation_capacity) failed for country: IT_FOGN :
# Data extraction (installed_generation_capacity) failed for country: IT_GR :
# Data extraction (installed_generation_capacity) failed for country: IT_MACRO_NORTH : 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A68&processType=A33&in_Domain=10Y1001A1001A84D&securityToken=6276342c-e10c-4d88-8688-cb0a1cf163ca&periodStart=202307180000&periodEnd=202308030000
# Data extraction (installed_generation_capacity) failed for country: IT_MACRO_SOUTH : 400 Client Error: Bad Request for url: https://web-api.tp.entsoe.eu/api?documentType=A68&processType=A33&in_Domain=10Y1001A1001A85B&securityToken=6276342c-e10c-4d88-8688-cb0a1cf163ca&periodStart=202307180000&periodEnd=202308030000
# Data extraction (installed_generation_capacity) failed for country: IT_MALTA :
# Data extraction (installed_generation_capacity) failed for country: IT_NORD :
# Data extraction (installed_generation_capacity) failed for country: IT_NORD_AT :
# Data extraction (installed_generation_capacity) failed for country: IT_NORD_CH :
# Data extraction (installed_generation_capacity) failed for country: IT_NORD_FR :
# Data extraction (installed_generation_capacity) failed for country: IT_NORD_SI :
# Data extraction (installed_generation_capacity) failed for country: IT_PRGP :
# Data extraction (installed_generation_capacity) failed for country: IT_ROSN :
# Data extraction (installed_generation_capacity) failed for country: IT_SACO_AC :
# Data extraction (installed_generation_capacity) failed for country: IT_SACO_DC :
# Data extraction (installed_generation_capacity) failed for country: IT_SARD :
# Data extraction (installed_generation_capacity) failed for country: IT_SICI :
# Data extraction (installed_generation_capacity) failed for country: IT_SUD :
# Installed Generation Capacity for LT:
# Empty DataFrame
# Columns: [Biomass, Fossil Gas, Fossil Oil, Hydro Pumped Storage, Hydro Run-of-river and poundage, Other, Other renewable, Solar, Waste, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: LT
# Installed Generation Capacity for LU:
# Empty DataFrame
# Columns: [Biomass, Fossil Brown coal/Lignite, Fossil Coal-derived gas, Fossil Gas, Fossil Hard coal, Fossil Oil, Fossil Oil shale, Fossil Peat, Geothermal, Hydro Pumped Storage, Hydro Run-of-river and poundage, Hydro Water Reservoir, Marine, Nuclear, Other, Other renewable, Solar, Waste, Wind Offshore, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: LU
# Installed Generation Capacity for LV:
# Empty DataFrame
# Columns: [Biomass, Fossil Gas, Hydro Run-of-river and poundage, Solar, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: LV
# Data extraction (installed_generation_capacity) failed for country: MD :
# Installed Generation Capacity for ME:
# Empty DataFrame
# Columns: [Fossil Brown coal/Lignite, Hydro Run-of-river and poundage, Hydro Water Reservoir, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: ME
# Installed Generation Capacity for MK:
# Empty DataFrame
# Columns: [Biomass, Fossil Brown coal/Lignite, Fossil Gas, Hydro Water Reservoir, Solar, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: MK
# Data extraction (installed_generation_capacity) failed for country: MT :
# Installed Generation Capacity for NL:
# Empty DataFrame
# Columns: [Biomass, Fossil Brown coal/Lignite, Fossil Coal-derived gas, Fossil Gas, Fossil Hard coal, Fossil Oil, Fossil Oil shale, Fossil Peat, Geothermal, Hydro Pumped Storage, Hydro Run-of-river and poundage, Hydro Water Reservoir, Marine, Nuclear, Other, Other renewable, Solar, Waste, Wind Offshore, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: NL
# Installed Generation Capacity for NO:
# Empty DataFrame
# Columns: [Biomass, Fossil Gas, Hydro Pumped Storage, Hydro Run-of-river and poundage, Hydro Water Reservoir, Other, Other renewable, Waste, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: NO
# Installed Generation Capacity for NO_1:
# Empty DataFrame
# Columns: [Biomass, Fossil Gas, Hydro Run-of-river and poundage, Hydro Water Reservoir, Waste, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: NO_1
# Installed Generation Capacity for NO_2:
# Empty DataFrame
# Columns: [Fossil Gas, Hydro Pumped Storage, Hydro Run-of-river and poundage, Hydro Water Reservoir, Waste, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: NO_2
# Installed Generation Capacity for NO_3:
# Empty DataFrame
# Columns: [Hydro Pumped Storage, Hydro Run-of-river and poundage, Hydro Water Reservoir, Other, Other renewable, Waste, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: NO_3
# Installed Generation Capacity for NO_4:
# Empty DataFrame
# Columns: [Fossil Gas, Hydro Run-of-river and poundage, Hydro Water Reservoir, Other renewable, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: NO_4
# Installed Generation Capacity for NO_5:
# Empty DataFrame
# Columns: [Fossil Gas, Hydro Pumped Storage, Hydro Run-of-river and poundage, Hydro Water Reservoir, Waste]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: NO_5
# Installed Generation Capacity for PL:
# Empty DataFrame
# Columns: [Biomass, Fossil Brown coal/Lignite, Fossil Coal-derived gas, Fossil Gas, Fossil Hard coal, Fossil Oil, Hydro Pumped Storage, Hydro Run-of-river and poundage, Hydro Water Reservoir, Other, Solar, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: PL
# Data extraction (installed_generation_capacity) failed for country: PL_CZ :
# Installed Generation Capacity for PT:
#                            Biomass  Fossil Brown coal/Lignite  \
# 2023-01-31 00:00:00+00:00    647.0                        0.0
#
#                            Fossil Coal-derived gas  Fossil Gas  \
# 2023-01-31 00:00:00+00:00                      0.0      4585.0
#
#                            Fossil Hard coal  Fossil Oil  Fossil Oil shale  \
# 2023-01-31 00:00:00+00:00               0.0         0.0               0.0
#
#                            Fossil Peat  Geothermal  Hydro Pumped Storage  \
# 2023-01-31 00:00:00+00:00          0.0         0.0                3707.0
#
#                            Hydro Run-of-river and poundage  \
# 2023-01-31 00:00:00+00:00                           2856.0
#
#                            Hydro Water Reservoir  Marine  Nuclear  Other  \
# 2023-01-31 00:00:00+00:00                 1633.0     0.0      0.0   28.0
#
#                            Other renewable   Solar  Waste  Wind Offshore  \
# 2023-01-31 00:00:00+00:00              0.0  1332.0    0.0           25.0
#
#                            Wind Onshore
# 2023-01-31 00:00:00+00:00        5328.0
# Data extraction (installed_generation_capacity) completed for country: PT
# Installed Generation Capacity for RO:
# Empty DataFrame
# Columns: [Biomass, Fossil Brown coal/Lignite, Fossil Gas, Fossil Hard coal, Hydro Run-of-river and poundage, Hydro Water Reservoir, Nuclear, Solar, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: RO
# Installed Generation Capacity for RS:
# Empty DataFrame
# Columns: [Biomass, Fossil Brown coal/Lignite, Fossil Gas, Hydro Pumped Storage, Hydro Run-of-river and poundage, Hydro Water Reservoir, Other, Solar, Waste, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: RS
# Data extraction (installed_generation_capacity) failed for country: RU :
# Data extraction (installed_generation_capacity) failed for country: RU_KGD :
# Installed Generation Capacity for SE:
# Empty DataFrame
# Columns: [Hydro Water Reservoir, Nuclear, Other, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: SE
# Data extraction (installed_generation_capacity) failed for country: SE_1 :
# Data extraction (installed_generation_capacity) failed for country: SE_2 :
# Data extraction (installed_generation_capacity) failed for country: SE_3 :
# Data extraction (installed_generation_capacity) failed for country: SE_4 :
# Installed Generation Capacity for SI:
# Empty DataFrame
# Columns: [Biomass, Fossil Brown coal/Lignite, Fossil Gas, Fossil Oil, Hydro Pumped Storage, Hydro Run-of-river and poundage, Nuclear, Solar, Waste, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: SI
# Data extraction (installed_generation_capacity) failed for country: SK :
# Data extraction (installed_generation_capacity) failed for country: TR :
# Installed Generation Capacity for UA:
# Empty DataFrame
# Columns: [Hydro Pumped Storage, Hydro Water Reservoir, Nuclear]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: UA
# Data extraction (installed_generation_capacity) failed for country: UA_BEI :
# Data extraction (installed_generation_capacity) failed for country: UA_DOBTPP :
# Installed Generation Capacity for UA_IPS:
# Empty DataFrame
# Columns: [Biomass, Fossil Gas, Fossil Hard coal, Hydro Pumped Storage, Hydro Run-of-river and poundage, Hydro Water Reservoir, Nuclear, Solar, Wind Onshore]
# Index: []
# Data extraction (installed_generation_capacity) completed for country: UA_IPS

# %%
countries_actual_generation = country_codes
done_actual_generation = []
failed = ["DE_AT_LU", "GB", "IT_BRNN", "IT_FOGN", 'IT_MACRO_NORTH', 'IT_MACRO_SOUTH', 'IT_PRGP', 'IT_ROSN']
to_do_actual_generation = [x for x in countries_actual_generation if x not in done_actual_generation and x not in failed]
to_do_actual_generation

# %%
# Define the time period
start = pd.Timestamp('2023-07-18', tz='UTC')
end = pd.Timestamp('2023-08-03', tz='UTC')

# %%
# Download and save the data for each country - Actual Generation per Production Type - 4
country_code = "EX"  # Replace "COUNTRY_CODE" with the specific country code you want to use
for country_code in to_do_actual_generation:
    try:
        actual_generation = client.query_generation(country_code=country_code, start=start, end=end)
        print(f"Actual Generation for {country_code}:")
        print(actual_generation)  # Print the data

        # Convert the index to UTC and format it as string
        actual_generation.index = actual_generation.index.tz_convert('UTC').strftime('%Y-%m-%dT%H:%M:%SZ')

        # Convert the data to InfluxDB Line Protocol format
        data_points = []
        for timestamp, row in actual_generation.iterrows():
            for column, value in row.items():
                if pd.notnull(value):
                    production_type = str(column).replace("/", "_").replace(" ", "_")
                    data_point = Point("actual_generation") \
                        .tag("country", country_code) \
                        .tag("production_type", production_type) \
                        .field("value", value) \
                        .time(timestamp, WritePrecision.NS)
                    data_points.append(data_point)

        # Write the data points to InfluxDB
        write_api.write(bucket=influxdb_bucket, record=data_points)
        logging.info('Data extraction (actual_generation) completed for country: %s', country_code)
        print(f'Data extraction (actual_generation) completed for country: {country_code}')

    except Exception as e:
        logging.error(f'Data extraction (actual_generation) failed for {country_code}: {str(e)}')
        print(f'Data extraction (actual_generation) failed for country: {country_code}')
# Out:
# Data extraction (actual_generation) failed for country: AL
# Actual Generation for AT:
#                                     Biomass                     \
#                           Actual Aggregated Actual Consumption
# 2023-07-18 02:00:00+02:00              84.0                0.0
# 2023-07-18 02:15:00+02:00              84.0                0.0
# 2023-07-18 02:30:00+02:00              84.0                0.0
# 2023-07-18 02:45:00+02:00              84.0                0.0
# 2023-07-18 03:00:00+02:00              84.0                0.0
# ...                                     ...                ...
# 2023-08-03 00:45:00+02:00             100.0                0.0
# 2023-08-03 01:00:00+02:00             100.0                0.0
# 2023-08-03 01:15:00+02:00             100.0                0.0
# 2023-08-03 01:30:00+02:00             100.0                0.0
# 2023-08-03 01:45:00+02:00             100.0                0.0
#
#                                  Fossil Gas                     \
#                           Actual Aggregated Actual Consumption
# 2023-07-18 02:00:00+02:00              86.0                0.0
# 2023-07-18 02:15:00+02:00              66.0                0.0
# 2023-07-18 02:30:00+02:00             143.0                0.0
# 2023-07-18 02:45:00+02:00              79.0                0.0
# 2023-07-18 03:00:00+02:00              68.0                0.0
# ...                                     ...                ...
# 2023-08-03 00:45:00+02:00              28.0                0.0
# 2023-08-03 01:00:00+02:00              27.0                0.0
# 2023-08-03 01:15:00+02:00              28.0                0.0
# 2023-08-03 01:30:00+02:00              30.0                0.0
# 2023-08-03 01:45:00+02:00              28.0                0.0
#
#                            Fossil Hard coal                     \
#                           Actual Aggregated Actual Consumption
# 2023-07-18 02:00:00+02:00               0.0                0.0
# 2023-07-18 02:15:00+02:00               0.0                0.0
# 2023-07-18 02:30:00+02:00               0.0                0.0
# 2023-07-18 02:45:00+02:00               0.0                0.0
# 2023-07-18 03:00:00+02:00               0.0                0.0
# ...                                     ...                ...
# 2023-08-03 00:45:00+02:00               0.0                0.0
# 2023-08-03 01:00:00+02:00               0.0                0.0
# 2023-08-03 01:15:00+02:00               0.0                0.0
# 2023-08-03 01:30:00+02:00               0.0                0.0
# 2023-08-03 01:45:00+02:00               0.0                0.0
#
#                                  Fossil Oil                     \
#                           Actual Aggregated Actual Consumption
# 2023-07-18 02:00:00+02:00               0.0                0.0
# 2023-07-18 02:15:00+02:00               0.0                0.0
# 2023-07-18 02:30:00+02:00               0.0                0.0
# 2023-07-18 02:45:00+02:00               0.0                0.0
# 2023-07-18 03:00:00+02:00               0.0                0.0
# ...                                     ...                ...
# 2023-08-03 00:45:00+02:00               0.0                0.0
# 2023-08-03 01:00:00+02:00               0.0                0.0
# 2023-08-03 01:15:00+02:00               0.0                0.0
# 2023-08-03 01:30:00+02:00               0.0                0.0
# 2023-08-03 01:45:00+02:00               0.0                0.0
#
#                                  Geothermal                     ...  \
#                           Actual Aggregated Actual Consumption  ...
# 2023-07-18 02:00:00+02:00               0.0                0.0  ...
# 2023-07-18 02:15:00+02:00               0.0                0.0  ...
# 2023-07-18 02:30:00+02:00               0.0                0.0  ...
# 2023-07-18 02:45:00+02:00               0.0                0.0  ...
# 2023-07-18 03:00:00+02:00               0.0                0.0  ...
# ...                                     ...                ...  ...
# 2023-08-03 00:45:00+02:00               0.0                0.0  ...
# 2023-08-03 01:00:00+02:00               0.0                0.0  ...
# 2023-08-03 01:15:00+02:00               0.0                0.0  ...
# 2023-08-03 01:30:00+02:00               0.0                0.0  ...
# 2023-08-03 01:45:00+02:00               0.0                0.0  ...
#
#                                       Other                     \
#                           Actual Aggregated Actual Consumption
# 2023-07-18 02:00:00+02:00              22.0                0.0
# 2023-07-18 02:15:00+02:00              22.0                0.0
# 2023-07-18 02:30:00+02:00              22.0                0.0
# 2023-07-18 02:45:00+02:00              22.0                0.0
# 2023-07-18 03:00:00+02:00              22.0                0.0
# ...                                     ...                ...
# 2023-08-03 00:45:00+02:00              22.0                0.0
# 2023-08-03 01:00:00+02:00              22.0                0.0
# 2023-08-03 01:15:00+02:00              22.0                0.0
# 2023-08-03 01:30:00+02:00              22.0                0.0
# 2023-08-03 01:45:00+02:00              22.0                0.0
#
#                             Other renewable                     \
#                           Actual Aggregated Actual Consumption
# 2023-07-18 02:00:00+02:00               0.0                0.0
# 2023-07-18 02:15:00+02:00               0.0                0.0
# 2023-07-18 02:30:00+02:00               0.0                0.0
# 2023-07-18 02:45:00+02:00               0.0                0.0
# 2023-07-18 03:00:00+02:00               0.0                0.0
# ...                                     ...                ...
# 2023-08-03 00:45:00+02:00               0.0                0.0
# 2023-08-03 01:00:00+02:00               0.0                0.0
# 2023-08-03 01:15:00+02:00               0.0                0.0
# 2023-08-03 01:30:00+02:00               0.0                0.0
# 2023-08-03 01:45:00+02:00               0.0                0.0
#
#                                       Solar                     \
#                           Actual Aggregated Actual Consumption
# 2023-07-18 02:00:00+02:00               0.0                0.0
# 2023-07-18 02:15:00+02:00               0.0                0.0
# 2023-07-18 02:30:00+02:00               0.0                0.0
# 2023-07-18 02:45:00+02:00               0.0                0.0
# 2023-07-18 03:00:00+02:00               0.0                0.0
# ...                                     ...                ...
# 2023-08-03 00:45:00+02:00               0.0                0.0
# 2023-08-03 01:00:00+02:00               0.0                0.0
# 2023-08-03 01:15:00+02:00               0.0                0.0
# 2023-08-03 01:30:00+02:00               0.0                0.0
# 2023-08-03 01:45:00+02:00               0.0                0.0
#
#                                       Waste                     \
#                           Actual Aggregated Actual Consumption
# 2023-07-18 02:00:00+02:00             100.0                0.0
# 2023-07-18 02:15:00+02:00             100.0                0.0
# 2023-07-18 02:30:00+02:00             100.0                0.0
# 2023-07-18 02:45:00+02:00             100.0                0.0
# 2023-07-18 03:00:00+02:00             100.0                0.0
# ...                                     ...                ...
# 2023-08-03 00:45:00+02:00             100.0                0.0
# 2023-08-03 01:00:00+02:00             100.0                0.0
# 2023-08-03 01:15:00+02:00             100.0                0.0
# 2023-08-03 01:30:00+02:00             100.0                0.0
# 2023-08-03 01:45:00+02:00             100.0                0.0
#
#                                Wind Onshore
#                           Actual Aggregated Actual Consumption
# 2023-07-18 02:00:00+02:00            1280.0                0.0
# 2023-07-18 02:15:00+02:00            1052.0                0.0
# 2023-07-18 02:30:00+02:00            1292.0                0.0
# 2023-07-18 02:45:00+02:00            1304.0                0.0
# 2023-07-18 03:00:00+02:00            1276.0                0.0
# ...                                     ...                ...
# 2023-08-03 00:45:00+02:00            2092.0                0.0
# 2023-08-03 01:00:00+02:00            2048.0                0.0
# 2023-08-03 01:15:00+02:00            1880.0                0.0
# 2023-08-03 01:30:00+02:00            1736.0                0.0
# 2023-08-03 01:45:00+02:00            1708.0                0.0
#
# [1536 rows x 26 columns]
# Data extraction (actual_generation) completed for country: AT
# Actual Generation for BA:
#                            Fossil Brown coal/Lignite  Hydro Pumped Storage  \
# 2023-07-18 02:00:00+02:00                     1005.0                   0.0
# 2023-07-18 03:00:00+02:00                     1004.0                   0.0
# 2023-07-18 04:00:00+02:00                     1006.0                   0.0
# 2023-07-18 05:00:00+02:00                     1004.0                   0.0
# 2023-07-18 06:00:00+02:00                     1026.0                 139.0
# ...                                              ...                   ...
# 2023-08-02 21:00:00+02:00                     1200.0                 142.0
# 2023-08-02 22:00:00+02:00                     1203.0                   2.0
# 2023-08-02 23:00:00+02:00                     1203.0                   0.0
# 2023-08-03 00:00:00+02:00                     1198.0                   0.0
# 2023-08-03 01:00:00+02:00                     1182.0                   0.0
#
#                            Hydro Run-of-river and poundage  \
# 2023-07-18 02:00:00+02:00                             18.0
# 2023-07-18 03:00:00+02:00                             18.0
# 2023-07-18 04:00:00+02:00                             21.0
# 2023-07-18 05:00:00+02:00                             21.0
# 2023-07-18 06:00:00+02:00                             27.0
# ...                                                    ...
# 2023-08-02 21:00:00+02:00                             41.0
# 2023-08-02 22:00:00+02:00                             41.0
# 2023-08-02 23:00:00+02:00                             41.0
# 2023-08-03 00:00:00+02:00                             23.0
# 2023-08-03 01:00:00+02:00                             20.0
#
#                            Hydro Water Reservoir  Other renewable  \
# 2023-07-18 02:00:00+02:00                  256.0              0.0
# 2023-07-18 03:00:00+02:00                  230.0              0.0
# 2023-07-18 04:00:00+02:00                  207.0              0.0
# 2023-07-18 05:00:00+02:00                  227.0              0.0
# 2023-07-18 06:00:00+02:00                  320.0              0.0
# ...                                          ...              ...
# 2023-08-02 21:00:00+02:00                  627.0              0.0
# 2023-08-02 22:00:00+02:00                  575.0              0.0
# 2023-08-02 23:00:00+02:00                  407.0              0.0
# 2023-08-03 00:00:00+02:00                  180.0              0.0
# 2023-08-03 01:00:00+02:00                   52.0              0.0
#
#                            Wind Onshore
# 2023-07-18 02:00:00+02:00           7.0
# 2023-07-18 03:00:00+02:00          12.0
# 2023-07-18 04:00:00+02:00          24.0
# 2023-07-18 05:00:00+02:00          22.0
# 2023-07-18 06:00:00+02:00          10.0
# ...                                 ...
# 2023-08-02 21:00:00+02:00           2.0
# 2023-08-02 22:00:00+02:00           0.0
# 2023-08-02 23:00:00+02:00           6.0
# 2023-08-03 00:00:00+02:00          18.0
# 2023-08-03 01:00:00+02:00          12.0
#
# [384 rows x 6 columns]
# Data extraction (actual_generation) completed for country: BA
# Actual Generation for BE:
#                                     Biomass        Fossil Gas  \
#                           Actual Aggregated Actual Aggregated
# 2023-07-18 02:00:00+02:00              78.0            1863.0
# 2023-07-18 03:00:00+02:00              78.0            1885.0
# 2023-07-18 04:00:00+02:00              78.0            1862.0
# 2023-07-18 05:00:00+02:00              72.0            2160.0
# 2023-07-18 06:00:00+02:00              74.0            2440.0
# ...                                     ...               ...
# 2023-08-02 21:00:00+02:00              52.0             762.0
# 2023-08-02 22:00:00+02:00              48.0             584.0
# 2023-08-02 23:00:00+02:00              53.0             546.0
# 2023-08-03 00:00:00+02:00              51.0             371.0
# 2023-08-03 01:00:00+02:00              51.0             367.0
#
#                                  Fossil Oil Hydro Pumped Storage  \
#                           Actual Aggregated    Actual Aggregated
# 2023-07-18 02:00:00+02:00               0.0                 14.0
# 2023-07-18 03:00:00+02:00               0.0                  NaN
# 2023-07-18 04:00:00+02:00               0.0                  NaN
# 2023-07-18 05:00:00+02:00               0.0                  NaN
# 2023-07-18 06:00:00+02:00               0.0                  NaN
# ...                                     ...                  ...
# 2023-08-02 21:00:00+02:00               0.0                792.0
# 2023-08-02 22:00:00+02:00               0.0                 38.0
# 2023-08-02 23:00:00+02:00               0.0                  NaN
# 2023-08-03 00:00:00+02:00               0.0                  NaN
# 2023-08-03 01:00:00+02:00               0.0                  NaN
#
#                                              Hydro Run-of-river and poundage  \
#                           Actual Consumption               Actual Aggregated
# 2023-07-18 02:00:00+02:00                3.0                             0.0
# 2023-07-18 03:00:00+02:00              582.0                             0.0
# 2023-07-18 04:00:00+02:00              606.0                             0.0
# 2023-07-18 05:00:00+02:00              175.0                             0.0
# 2023-07-18 06:00:00+02:00                5.0                             0.0
# ...                                      ...                             ...
# 2023-08-02 21:00:00+02:00                NaN                             1.0
# 2023-08-02 22:00:00+02:00                NaN                             1.0
# 2023-08-02 23:00:00+02:00               96.0                             1.0
# 2023-08-03 00:00:00+02:00              343.0                             0.0
# 2023-08-03 01:00:00+02:00              957.0                             0.0
#
#                                     Nuclear             Other  \
#                           Actual Aggregated Actual Aggregated
# 2023-07-18 02:00:00+02:00            3844.0             468.0
# 2023-07-18 03:00:00+02:00            3850.0             445.0
# 2023-07-18 04:00:00+02:00            3856.0             427.0
# 2023-07-18 05:00:00+02:00            3858.0             465.0
# 2023-07-18 06:00:00+02:00            3857.0             504.0
# ...                                     ...               ...
# 2023-08-02 21:00:00+02:00            3850.0               NaN
# 2023-08-02 22:00:00+02:00            3848.0               NaN
# 2023-08-02 23:00:00+02:00            3846.0               NaN
# 2023-08-03 00:00:00+02:00            3847.0               NaN
# 2023-08-03 01:00:00+02:00            3844.0               NaN
#
#                                       Solar             Waste  \
#                           Actual Aggregated Actual Aggregated
# 2023-07-18 02:00:00+02:00               0.0             266.0
# 2023-07-18 03:00:00+02:00               0.0             268.0
# 2023-07-18 04:00:00+02:00               0.0             268.0
# 2023-07-18 05:00:00+02:00               0.0             270.0
# 2023-07-18 06:00:00+02:00             181.0             269.0
# ...                                     ...               ...
# 2023-08-02 21:00:00+02:00               1.0             164.0
# 2023-08-02 22:00:00+02:00               0.0             163.0
# 2023-08-02 23:00:00+02:00               0.0             163.0
# 2023-08-03 00:00:00+02:00               0.0             163.0
# 2023-08-03 01:00:00+02:00               0.0             162.0
#
#                               Wind Offshore                     \
#                           Actual Aggregated Actual Consumption
# 2023-07-18 02:00:00+02:00             293.0                NaN
# 2023-07-18 03:00:00+02:00             256.0                NaN
# 2023-07-18 04:00:00+02:00             243.0                NaN
# 2023-07-18 05:00:00+02:00             117.0                NaN
# 2023-07-18 06:00:00+02:00              90.0                NaN
# ...                                     ...                ...
# 2023-08-02 21:00:00+02:00            2034.0                NaN
# 2023-08-02 22:00:00+02:00            1815.0                NaN
# 2023-08-02 23:00:00+02:00            1814.0                NaN
# 2023-08-03 00:00:00+02:00            1904.0                NaN
# 2023-08-03 01:00:00+02:00            1949.0                NaN
#
#                                Wind Onshore
#                           Actual Aggregated
# 2023-07-18 02:00:00+02:00             195.0
# 2023-07-18 03:00:00+02:00             220.0
# 2023-07-18 04:00:00+02:00             219.0
# 2023-07-18 05:00:00+02:00             209.0
# 2023-07-18 06:00:00+02:00             189.0
# ...                                     ...
# 2023-08-02 21:00:00+02:00            2006.0
# 2023-08-02 22:00:00+02:00            2067.0
# 2023-08-02 23:00:00+02:00            2099.0
# 2023-08-03 00:00:00+02:00            2074.0
# 2023-08-03 01:00:00+02:00            2100.0
#
# [384 rows x 13 columns]
# Data extraction (actual_generation) completed for country: BE
# Actual Generation for BG:
#                            Biomass  Fossil Brown coal/Lignite  Fossil Gas  \
# 2023-07-18 03:00:00+03:00     23.0                     1141.0       154.0
# 2023-07-18 04:00:00+03:00     24.0                     1123.0       155.0
# 2023-07-18 05:00:00+03:00     25.0                     1111.0       153.0
# 2023-07-18 06:00:00+03:00     23.0                     1178.0       156.0
# 2023-07-18 07:00:00+03:00     24.0                     1123.0       158.0
# ...                            ...                        ...         ...
# 2023-08-02 22:00:00+03:00     13.0                     1154.0       170.0
# 2023-08-02 23:00:00+03:00     13.0                     1093.0       170.0
# 2023-08-03 00:00:00+03:00     13.0                     1139.0       174.0
# 2023-08-03 01:00:00+03:00     13.0                     1159.0       164.0
# 2023-08-03 02:00:00+03:00     13.0                     1110.0       162.0
#
#                            Fossil Hard coal  Hydro Pumped Storage  \
# 2023-07-18 03:00:00+03:00              56.0                   0.0
# 2023-07-18 04:00:00+03:00              56.0                   0.0
# 2023-07-18 05:00:00+03:00              55.0                   0.0
# 2023-07-18 06:00:00+03:00              57.0                   0.0
# 2023-07-18 07:00:00+03:00              56.0                   0.0
# ...                                     ...                   ...
# 2023-08-02 22:00:00+03:00              57.0                   0.0
# 2023-08-02 23:00:00+03:00              57.0                   0.0
# 2023-08-03 00:00:00+03:00              57.0                   0.0
# 2023-08-03 01:00:00+03:00              58.0                   0.0
# 2023-08-03 02:00:00+03:00              59.0                   0.0
#
#                            Hydro Run-of-river and poundage  \
# 2023-07-18 03:00:00+03:00                            128.0
# 2023-07-18 04:00:00+03:00                            127.0
# 2023-07-18 05:00:00+03:00                            139.0
# 2023-07-18 06:00:00+03:00                            167.0
# 2023-07-18 07:00:00+03:00                            207.0
# ...                                                    ...
# 2023-08-02 22:00:00+03:00                            166.0
# 2023-08-02 23:00:00+03:00                            130.0
# 2023-08-03 00:00:00+03:00                             92.0
# 2023-08-03 01:00:00+03:00                             87.0
# 2023-08-03 02:00:00+03:00                             79.0
#
#                            Hydro Water Reservoir  Nuclear  Solar  Waste  \
# 2023-07-18 03:00:00+03:00                    9.0   2084.0    0.0    2.0
# 2023-07-18 04:00:00+03:00                    9.0   2085.0    0.0    2.0
# 2023-07-18 05:00:00+03:00                    9.0   2083.0    0.0    2.0
# 2023-07-18 06:00:00+03:00                    9.0   2085.0   49.0    3.0
# 2023-07-18 07:00:00+03:00                   92.0   2085.0  303.0    3.0
# ...                                          ...      ...    ...    ...
# 2023-08-02 22:00:00+03:00                  623.0   1974.0    0.0    3.0
# 2023-08-02 23:00:00+03:00                  376.0   1973.0    0.0    3.0
# 2023-08-03 00:00:00+03:00                  133.0   1973.0    0.0    3.0
# 2023-08-03 01:00:00+03:00                   30.0   1973.0    0.0    3.0
# 2023-08-03 02:00:00+03:00                    9.0   1976.0    0.0    3.0
#
#                            Wind Onshore
# 2023-07-18 03:00:00+03:00          87.0
# 2023-07-18 04:00:00+03:00          82.0
# 2023-07-18 05:00:00+03:00          99.0
# 2023-07-18 06:00:00+03:00         100.0
# 2023-07-18 07:00:00+03:00          75.0
# ...                                 ...
# 2023-08-02 22:00:00+03:00         176.0
# 2023-08-02 23:00:00+03:00         108.0
# 2023-08-03 00:00:00+03:00          72.0
# 2023-08-03 01:00:00+03:00          33.0
# 2023-08-03 02:00:00+03:00          29.0
#
# [384 rows x 11 columns]
# Data extraction (actual_generation) completed for country: BG
# Data extraction (actual_generation) failed for country: BY
# Actual Generation for CH:
#                            Hydro Pumped Storage  \
# 2023-07-18 02:00:00+02:00                 224.0
# 2023-07-18 03:00:00+02:00                 220.0
# 2023-07-18 04:00:00+02:00                 209.0
# 2023-07-18 05:00:00+02:00                 249.0
# 2023-07-18 06:00:00+02:00                 784.0
# ...                                         ...
# 2023-08-02 21:00:00+02:00                 448.0
# 2023-08-02 22:00:00+02:00                  94.0
# 2023-08-02 23:00:00+02:00                 115.0
# 2023-08-03 00:00:00+02:00                  36.0
# 2023-08-03 01:00:00+02:00                  44.0
#
#                            Hydro Run-of-river and poundage  \
# 2023-07-18 02:00:00+02:00                            325.0
# 2023-07-18 03:00:00+02:00                            306.0
# 2023-07-18 04:00:00+02:00                            298.0
# 2023-07-18 05:00:00+02:00                            297.0
# 2023-07-18 06:00:00+02:00                            340.0
# ...                                                    ...
# 2023-08-02 21:00:00+02:00                            321.0
# 2023-08-02 22:00:00+02:00                            311.0
# 2023-08-02 23:00:00+02:00                            224.0
# 2023-08-03 00:00:00+02:00                            195.0
# 2023-08-03 01:00:00+02:00                            196.0
#
#                            Hydro Water Reservoir  Nuclear  Solar  Wind Onshore
# 2023-07-18 02:00:00+02:00                 1017.0   2939.0    0.0           NaN
# 2023-07-18 03:00:00+02:00                  991.0   2940.0    0.0           NaN
# 2023-07-18 04:00:00+02:00                 1147.0   2943.0    0.0           NaN
# 2023-07-18 05:00:00+02:00                 1437.0   2946.0    0.0           NaN
# 2023-07-18 06:00:00+02:00                 1973.0   2947.0   32.0           NaN
# ...                                          ...      ...    ...           ...
# 2023-08-02 21:00:00+02:00                 1051.0    972.0    2.0           NaN
# 2023-08-02 22:00:00+02:00                  957.0    977.0    0.0           NaN
# 2023-08-02 23:00:00+02:00                  474.0    977.0    0.0           NaN
# 2023-08-03 00:00:00+02:00                  331.0    977.0    NaN           NaN
# 2023-08-03 01:00:00+02:00                  270.0    978.0    NaN           NaN
#
# [384 rows x 6 columns]
# Data extraction (actual_generation) completed for country: CH
# Data extraction (actual_generation) failed for country: CWE
# Data extraction (actual_generation) failed for country: CY
# Actual Generation for CZ:
#                                     Biomass Fossil Brown coal/Lignite  \
#                           Actual Aggregated         Actual Aggregated
# 2023-07-18 02:00:00+02:00             198.0                    2578.0
# 2023-07-18 03:00:00+02:00             198.0                    2683.0
# 2023-07-18 04:00:00+02:00             198.0                    2732.0
# 2023-07-18 05:00:00+02:00             198.0                    2712.0
# 2023-07-18 06:00:00+02:00             200.0                    2945.0
# ...                                     ...                       ...
# 2023-08-02 21:00:00+02:00             205.0                    2094.0
# 2023-08-02 22:00:00+02:00             204.0                    2023.0
# 2023-08-02 23:00:00+02:00             206.0                    2013.0
# 2023-08-03 00:00:00+02:00             205.0                    1950.0
# 2023-08-03 01:00:00+02:00             205.0                    1929.0
#
#                           Fossil Coal-derived gas        Fossil Gas  \
#                                 Actual Aggregated Actual Aggregated
# 2023-07-18 02:00:00+02:00                    24.0             814.0
# 2023-07-18 03:00:00+02:00                    24.0             796.0
# 2023-07-18 04:00:00+02:00                    24.0             834.0
# 2023-07-18 05:00:00+02:00                    24.0             705.0
# 2023-07-18 06:00:00+02:00                    24.0             852.0
# ...                                           ...               ...
# 2023-08-02 21:00:00+02:00                    24.0             112.0
# 2023-08-02 22:00:00+02:00                    24.0             104.0
# 2023-08-02 23:00:00+02:00                    24.0             103.0
# 2023-08-03 00:00:00+02:00                    24.0             102.0
# 2023-08-03 01:00:00+02:00                    24.0             102.0
#
#                            Fossil Hard coal        Fossil Oil  \
#                           Actual Aggregated Actual Aggregated
# 2023-07-18 02:00:00+02:00             119.0               9.0
# 2023-07-18 03:00:00+02:00             117.0               6.0
# 2023-07-18 04:00:00+02:00             120.0               4.0
# 2023-07-18 05:00:00+02:00             115.0               3.0
# 2023-07-18 06:00:00+02:00             128.0               7.0
# ...                                     ...               ...
# 2023-08-02 21:00:00+02:00              36.0              12.0
# 2023-08-02 22:00:00+02:00              34.0               9.0
# 2023-08-02 23:00:00+02:00              38.0              11.0
# 2023-08-03 00:00:00+02:00              34.0               6.0
# 2023-08-03 01:00:00+02:00              35.0               7.0
#
#                           Hydro Pumped Storage                     \
#                              Actual Aggregated Actual Consumption
# 2023-07-18 02:00:00+02:00                  0.0               52.0
# 2023-07-18 03:00:00+02:00                  0.0                0.0
# 2023-07-18 04:00:00+02:00                  0.0                0.0
# 2023-07-18 05:00:00+02:00                  0.0                0.0
# 2023-07-18 06:00:00+02:00                  0.0                0.0
# ...                                        ...                ...
# 2023-08-02 21:00:00+02:00                356.0                0.0
# 2023-08-02 22:00:00+02:00                146.0                0.0
# 2023-08-02 23:00:00+02:00                  0.0               40.0
# 2023-08-03 00:00:00+02:00                  0.0              626.0
# 2023-08-03 01:00:00+02:00                  0.0              862.0
#
#                           Hydro Run-of-river and poundage  \
#                                         Actual Aggregated
# 2023-07-18 02:00:00+02:00                            72.0
# 2023-07-18 03:00:00+02:00                            73.0
# 2023-07-18 04:00:00+02:00                            75.0
# 2023-07-18 05:00:00+02:00                            76.0
# 2023-07-18 06:00:00+02:00                            72.0
# ...                                                   ...
# 2023-08-02 21:00:00+02:00                            65.0
# 2023-08-02 22:00:00+02:00                            66.0
# 2023-08-02 23:00:00+02:00                            64.0
# 2023-08-03 00:00:00+02:00                            73.0
# 2023-08-03 01:00:00+02:00                            83.0
#
#                           Hydro Water Reservoir           Nuclear  \
#                               Actual Aggregated Actual Aggregated
# 2023-07-18 02:00:00+02:00                  11.0            2950.0
# 2023-07-18 03:00:00+02:00                  11.0            2954.0
# 2023-07-18 04:00:00+02:00                  11.0            2959.0
# 2023-07-18 05:00:00+02:00                  11.0            2964.0
# 2023-07-18 06:00:00+02:00                  17.0            2969.0
# ...                                         ...               ...
# 2023-08-02 21:00:00+02:00                 181.0            3384.0
# 2023-08-02 22:00:00+02:00                 120.0            3387.0
# 2023-08-02 23:00:00+02:00                 112.0            3389.0
# 2023-08-03 00:00:00+02:00                  60.0            3388.0
# 2023-08-03 01:00:00+02:00                  21.0            3393.0
#
#                                       Other   Other renewable  \
#                           Actual Aggregated Actual Aggregated
# 2023-07-18 02:00:00+02:00              83.0             261.0
# 2023-07-18 03:00:00+02:00              81.0             262.0
# 2023-07-18 04:00:00+02:00              81.0             260.0
# 2023-07-18 05:00:00+02:00              83.0             259.0
# 2023-07-18 06:00:00+02:00              94.0             264.0
# ...                                     ...               ...
# 2023-08-02 21:00:00+02:00              94.0             263.0
# 2023-08-02 22:00:00+02:00              80.0             256.0
# 2023-08-02 23:00:00+02:00              79.0             256.0
# 2023-08-03 00:00:00+02:00              79.0             256.0
# 2023-08-03 01:00:00+02:00              79.0             255.0
#
#                                       Solar             Waste  \
#                           Actual Aggregated Actual Aggregated
# 2023-07-18 02:00:00+02:00               0.0              21.0
# 2023-07-18 03:00:00+02:00               0.0              21.0
# 2023-07-18 04:00:00+02:00              14.0              21.0
# 2023-07-18 05:00:00+02:00              28.0              21.0
# 2023-07-18 06:00:00+02:00             115.0              22.0
# ...                                     ...               ...
# 2023-08-02 21:00:00+02:00              14.0              37.0
# 2023-08-02 22:00:00+02:00               0.0              37.0
# 2023-08-02 23:00:00+02:00               0.0              37.0
# 2023-08-03 00:00:00+02:00               0.0              37.0
# 2023-08-03 01:00:00+02:00               0.0              37.0
#
#                                Wind Onshore
#                           Actual Aggregated
# 2023-07-18 02:00:00+02:00              84.0
# 2023-07-18 03:00:00+02:00              55.0
# 2023-07-18 04:00:00+02:00              49.0
# 2023-07-18 05:00:00+02:00              47.0
# 2023-07-18 06:00:00+02:00              25.0
# ...                                     ...
# 2023-08-02 21:00:00+02:00             180.0
# 2023-08-02 22:00:00+02:00             198.0
# 2023-08-02 23:00:00+02:00             208.0
# 2023-08-03 00:00:00+02:00             211.0
# 2023-08-03 01:00:00+02:00             202.0
#
# [384 rows x 16 columns]
# Data extraction (actual_generation) completed for country: CZ
# Data extraction (actual_generation) failed for country: CZ_DE_SK
# Actual Generation for DE:
#                                     Biomass Fossil Brown coal/Lignite  \
#                           Actual Aggregated         Actual Aggregated
# 2023-07-18 02:00:00+02:00            4319.0                    6862.0
# 2023-07-18 02:15:00+02:00            4305.0                    6826.0
# 2023-07-18 02:30:00+02:00            4289.0                    6810.0
# 2023-07-18 02:45:00+02:00            4259.0                    6850.0
# 2023-07-18 03:00:00+02:00            4223.0                    6883.0
# ...                                     ...                       ...
# 2023-08-03 00:45:00+02:00            4349.0                    2974.0
# 2023-08-03 01:00:00+02:00            4338.0                    2959.0
# 2023-08-03 01:15:00+02:00            4328.0                    2984.0
# 2023-08-03 01:30:00+02:00            4335.0                    2964.0
# 2023-08-03 01:45:00+02:00            4313.0                    2948.0
#
#                                  Fossil Gas  Fossil Hard coal  \
#                           Actual Aggregated Actual Aggregated
# 2023-07-18 02:00:00+02:00            5826.0            1129.0
# 2023-07-18 02:15:00+02:00            5841.0            1178.0
# 2023-07-18 02:30:00+02:00            5895.0            1175.0
# 2023-07-18 02:45:00+02:00            5905.0            1262.0
# 2023-07-18 03:00:00+02:00            5836.0            1349.0
# ...                                     ...               ...
# 2023-08-03 00:45:00+02:00            2435.0            1298.0
# 2023-08-03 01:00:00+02:00            2422.0            1289.0
# 2023-08-03 01:15:00+02:00            2433.0            1285.0
# 2023-08-03 01:30:00+02:00            2426.0            1285.0
# 2023-08-03 01:45:00+02:00            2430.0            1289.0
#
#                                  Fossil Oil        Geothermal  \
#                           Actual Aggregated Actual Aggregated
# 2023-07-18 02:00:00+02:00             377.0              20.0
# 2023-07-18 02:15:00+02:00             377.0              20.0
# 2023-07-18 02:30:00+02:00             377.0              20.0
# 2023-07-18 02:45:00+02:00             377.0              20.0
# 2023-07-18 03:00:00+02:00             377.0              20.0
# ...                                     ...               ...
# 2023-08-03 00:45:00+02:00             361.0              20.0
# 2023-08-03 01:00:00+02:00             361.0              20.0
# 2023-08-03 01:15:00+02:00             361.0              20.0
# 2023-08-03 01:30:00+02:00             361.0              20.0
# 2023-08-03 01:45:00+02:00             361.0              20.0
#
#                           Hydro Pumped Storage                     \
#                              Actual Aggregated Actual Consumption
# 2023-07-18 02:00:00+02:00                442.0              337.0
# 2023-07-18 02:15:00+02:00                516.0              350.0
# 2023-07-18 02:30:00+02:00                347.0              321.0
# 2023-07-18 02:45:00+02:00                329.0              385.0
# 2023-07-18 03:00:00+02:00                207.0              561.0
# ...                                        ...                ...
# 2023-08-03 00:45:00+02:00                  5.0             2208.0
# 2023-08-03 01:00:00+02:00                194.0             2674.0
# 2023-08-03 01:15:00+02:00                155.0             2736.0
# 2023-08-03 01:30:00+02:00                119.0             3222.0
# 2023-08-03 01:45:00+02:00                 16.0             3656.0
#
#                           Hydro Run-of-river and poundage  \
#                                         Actual Aggregated
# 2023-07-18 02:00:00+02:00                          1592.0
# 2023-07-18 02:15:00+02:00                          1595.0
# 2023-07-18 02:30:00+02:00                          1592.0
# 2023-07-18 02:45:00+02:00                          1590.0
# 2023-07-18 03:00:00+02:00                          1582.0
# ...                                                   ...
# 2023-08-03 00:45:00+02:00                          1743.0
# 2023-08-03 01:00:00+02:00                          1737.0
# 2023-08-03 01:15:00+02:00                          1732.0
# 2023-08-03 01:30:00+02:00                          1730.0
# 2023-08-03 01:45:00+02:00                          1729.0
#
#                           Hydro Water Reservoir           Nuclear  \
#                               Actual Aggregated Actual Aggregated
# 2023-07-18 02:00:00+02:00                  46.0               0.0
# 2023-07-18 02:15:00+02:00                  50.0               0.0
# 2023-07-18 02:30:00+02:00                  33.0               0.0
# 2023-07-18 02:45:00+02:00                  24.0               0.0
# 2023-07-18 03:00:00+02:00                  20.0               0.0
# ...                                         ...               ...
# 2023-08-03 00:45:00+02:00                  72.0               0.0
# 2023-08-03 01:00:00+02:00                 143.0               0.0
# 2023-08-03 01:15:00+02:00                  87.0               0.0
# 2023-08-03 01:30:00+02:00                  70.0               0.0
# 2023-08-03 01:45:00+02:00                  59.0               0.0
#
#                                       Other   Other renewable  \
#                           Actual Aggregated Actual Aggregated
# 2023-07-18 02:00:00+02:00             138.0              83.0
# 2023-07-18 02:15:00+02:00             138.0              83.0
# 2023-07-18 02:30:00+02:00             138.0              83.0
# 2023-07-18 02:45:00+02:00             138.0              83.0
# 2023-07-18 03:00:00+02:00             138.0              83.0
# ...                                     ...               ...
# 2023-08-03 00:45:00+02:00             138.0              82.0
# 2023-08-03 01:00:00+02:00             138.0              82.0
# 2023-08-03 01:15:00+02:00             138.0              82.0
# 2023-08-03 01:30:00+02:00             138.0              82.0
# 2023-08-03 01:45:00+02:00             138.0              82.0
#
#                                       Solar                     \
#                           Actual Aggregated Actual Consumption
# 2023-07-18 02:00:00+02:00               0.0                0.0
# 2023-07-18 02:15:00+02:00               0.0                0.0
# 2023-07-18 02:30:00+02:00               0.0                0.0
# 2023-07-18 02:45:00+02:00               0.0                0.0
# 2023-07-18 03:00:00+02:00               0.0                0.0
# ...                                     ...                ...
# 2023-08-03 00:45:00+02:00               0.0                0.0
# 2023-08-03 01:00:00+02:00               0.0                0.0
# 2023-08-03 01:15:00+02:00               0.0                0.0
# 2023-08-03 01:30:00+02:00               0.0                0.0
# 2023-08-03 01:45:00+02:00               0.0                0.0
#
#                                       Waste     Wind Offshore  \
#                           Actual Aggregated Actual Aggregated
# 2023-07-18 02:00:00+02:00             889.0            3237.0
# 2023-07-18 02:15:00+02:00             889.0            3137.0
# 2023-07-18 02:30:00+02:00             886.0            3084.0
# 2023-07-18 02:45:00+02:00             886.0            3009.0
# 2023-07-18 03:00:00+02:00             895.0            2971.0
# ...                                     ...               ...
# 2023-08-03 00:45:00+02:00             638.0            2050.0
# 2023-08-03 01:00:00+02:00             633.0            1792.0
# 2023-08-03 01:15:00+02:00             634.0            1703.0
# 2023-08-03 01:30:00+02:00             635.0            1633.0
# 2023-08-03 01:45:00+02:00             637.0            1547.0
#
#                                Wind Onshore
#                           Actual Aggregated Actual Consumption
# 2023-07-18 02:00:00+02:00            8871.0                0.0
# 2023-07-18 02:15:00+02:00            8790.0                0.0
# 2023-07-18 02:30:00+02:00            8825.0                0.0
# 2023-07-18 02:45:00+02:00            8766.0                0.0
# 2023-07-18 03:00:00+02:00            8596.0                0.0
# ...                                     ...                ...
# 2023-08-03 00:45:00+02:00           24871.0                0.0
# 2023-08-03 01:00:00+02:00           24871.0                0.0
# 2023-08-03 01:15:00+02:00           25075.0                0.0
# 2023-08-03 01:30:00+02:00           25541.0                0.0
# 2023-08-03 01:45:00+02:00           25791.0                0.0
#
# [1536 rows x 19 columns]
# Data extraction (actual_generation) completed for country: DE
# Actual Generation for DE_50HZ:
#                                     Biomass Fossil Brown coal/Lignite  \
#                           Actual Aggregated         Actual Aggregated
# 2023-07-18 02:00:00+02:00            1009.0                    3502.0
# 2023-07-18 02:15:00+02:00            1002.0                    3474.0
# 2023-07-18 02:30:00+02:00             992.0                    3450.0
# 2023-07-18 02:45:00+02:00             988.0                    3491.0
# 2023-07-18 03:00:00+02:00             963.0                    3509.0
# ...                                     ...                       ...
# 2023-08-03 00:45:00+02:00             974.0                    1686.0
# 2023-08-03 01:00:00+02:00             972.0                    1678.0
# 2023-08-03 01:15:00+02:00             970.0                    1700.0
# 2023-08-03 01:30:00+02:00             979.0                    1682.0
# 2023-08-03 01:45:00+02:00             984.0                    1666.0
#
#                                  Fossil Gas  Fossil Hard coal  \
#                           Actual Aggregated Actual Aggregated
# 2023-07-18 02:00:00+02:00             602.0             167.0
# 2023-07-18 02:15:00+02:00             604.0             169.0
# 2023-07-18 02:30:00+02:00             604.0             169.0
# 2023-07-18 02:45:00+02:00             603.0             168.0
# 2023-07-18 03:00:00+02:00             601.0             169.0
# ...                                     ...               ...
# 2023-08-03 00:45:00+02:00             721.0             190.0
# 2023-08-03 01:00:00+02:00             726.0             191.0
# 2023-08-03 01:15:00+02:00             724.0             190.0
# 2023-08-03 01:30:00+02:00             727.0             191.0
# 2023-08-03 01:45:00+02:00             740.0             189.0
#
#                                  Fossil Oil        Geothermal  \
#                           Actual Aggregated Actual Aggregated
# 2023-07-18 02:00:00+02:00             376.0               0.0
# 2023-07-18 02:15:00+02:00             376.0               0.0
# 2023-07-18 02:30:00+02:00             376.0               0.0
# 2023-07-18 02:45:00+02:00             376.0               0.0
# 2023-07-18 03:00:00+02:00             376.0               0.0
# ...                                     ...               ...
# 2023-08-03 00:45:00+02:00             361.0               0.0
# 2023-08-03 01:00:00+02:00             361.0               0.0
# 2023-08-03 01:15:00+02:00             361.0               0.0
# 2023-08-03 01:30:00+02:00             361.0               0.0
# 2023-08-03 01:45:00+02:00             361.0               0.0
#
#                           Hydro Pumped Storage                     \
#                              Actual Aggregated Actual Consumption
# 2023-07-18 02:00:00+02:00                 81.0                4.0
# 2023-07-18 02:15:00+02:00                 89.0                3.0
# 2023-07-18 02:30:00+02:00                 75.0                3.0
# 2023-07-18 02:45:00+02:00                 69.0                3.0
# 2023-07-18 03:00:00+02:00                 68.0                3.0
# ...                                        ...                ...
# 2023-08-03 00:45:00+02:00                  0.0             1052.0
# 2023-08-03 01:00:00+02:00                109.0             1189.0
# 2023-08-03 01:15:00+02:00                 93.0             1202.0
# 2023-08-03 01:30:00+02:00                 69.0             1363.0
# 2023-08-03 01:45:00+02:00                 10.0             1395.0
#
#                           Hydro Run-of-river and poundage             Other  \
#                                         Actual Aggregated Actual Aggregated
# 2023-07-18 02:00:00+02:00                           118.0               0.0
# 2023-07-18 02:15:00+02:00                           117.0               0.0
# 2023-07-18 02:30:00+02:00                           116.0               0.0
# 2023-07-18 02:45:00+02:00                           116.0               0.0
# 2023-07-18 03:00:00+02:00                           113.0               0.0
# ...                                                   ...               ...
# 2023-08-03 00:45:00+02:00                           114.0               0.0
# 2023-08-03 01:00:00+02:00                           114.0               0.0
# 2023-08-03 01:15:00+02:00                           114.0               0.0
# 2023-08-03 01:30:00+02:00                           115.0               0.0
# 2023-08-03 01:45:00+02:00                           115.0               0.0
#
#                             Other renewable             Solar  \
#                           Actual Aggregated Actual Aggregated
# 2023-07-18 02:00:00+02:00               0.0               0.0
# 2023-07-18 02:15:00+02:00               0.0               0.0
# 2023-07-18 02:30:00+02:00               0.0               0.0
# 2023-07-18 02:45:00+02:00               0.0               0.0
# 2023-07-18 03:00:00+02:00               0.0               0.0
# ...                                     ...               ...
# 2023-08-03 00:45:00+02:00               0.0               0.0
# 2023-08-03 01:00:00+02:00               0.0               0.0
# 2023-08-03 01:15:00+02:00               0.0               0.0
# 2023-08-03 01:30:00+02:00               0.0               0.0
# 2023-08-03 01:45:00+02:00               0.0               0.0
#
#                                       Waste     Wind Offshore  \
#                           Actual Aggregated Actual Aggregated
# 2023-07-18 02:00:00+02:00             409.0            1176.0
# 2023-07-18 02:15:00+02:00             409.0            1168.0
# 2023-07-18 02:30:00+02:00             407.0            1176.0
# 2023-07-18 02:45:00+02:00             406.0            1174.0
# 2023-07-18 03:00:00+02:00             415.0            1200.0
# ...                                     ...               ...
# 2023-08-03 00:45:00+02:00             126.0             660.0
# 2023-08-03 01:00:00+02:00             121.0             589.0
# 2023-08-03 01:15:00+02:00             122.0             625.0
# 2023-08-03 01:30:00+02:00             123.0             658.0
# 2023-08-03 01:45:00+02:00             125.0             728.0
#
#                                Wind Onshore
#                           Actual Aggregated
# 2023-07-18 02:00:00+02:00            3353.0
# 2023-07-18 02:15:00+02:00            3374.0
# 2023-07-18 02:30:00+02:00            3469.0
# 2023-07-18 02:45:00+02:00            3468.0
# 2023-07-18 03:00:00+02:00            3513.0
# ...                                     ...
# 2023-08-03 00:45:00+02:00            7760.0
# 2023-08-03 01:00:00+02:00            7625.0
# 2023-08-03 01:15:00+02:00            7684.0
# 2023-08-03 01:30:00+02:00            7817.0
# ...
# 2023-08-03 01:00:00+02:00    0.0        4209.0
#
# [384 rows x 6 columns]
# Data extraction (actual_generation) completed for country: SE
# Actual Generation for SE_1:
#                            Hydro Water Reservoir  Other  Solar  Wind Onshore
# 2023-07-18 02:00:00+02:00                  881.0    3.0    0.0         409.0
# 2023-07-18 03:00:00+02:00                  686.0    3.0    0.0         315.0
# 2023-07-18 04:00:00+02:00                  703.0    3.0    0.0         329.0
# 2023-07-18 05:00:00+02:00                  797.0    3.0    0.0         342.0
# 2023-07-18 06:00:00+02:00                 1064.0    3.0    0.0         333.0
# ...                                          ...    ...    ...           ...
# 2023-08-02 21:00:00+02:00                 1065.0    3.0    0.0        1282.0
# 2023-08-02 22:00:00+02:00                  930.0    3.0    0.0        1162.0
# 2023-08-02 23:00:00+02:00                  685.0    3.0    0.0        1069.0
# 2023-08-03 00:00:00+02:00                  955.0    3.0    0.0         996.0
# 2023-08-03 01:00:00+02:00                 1007.0    3.0    0.0        1031.0
#
# [384 rows x 4 columns]
# Data extraction (actual_generation) completed for country: SE_1
# Actual Generation for SE_2:
#                            Fossil Gas  Hydro Water Reservoir  Other  Solar  \
# 2023-07-18 02:00:00+02:00         0.0                 1217.0   79.0    0.0
# 2023-07-18 03:00:00+02:00         0.0                 1257.0   86.0    0.0
# 2023-07-18 04:00:00+02:00         0.0                 1276.0   85.0    0.0
# 2023-07-18 05:00:00+02:00         0.0                 1234.0   91.0    1.0
# 2023-07-18 06:00:00+02:00         0.0                 1331.0   85.0    2.0
# ...                               ...                    ...    ...    ...
# 2023-08-02 21:00:00+02:00         0.0                 2328.0   52.0    0.0
# 2023-08-02 22:00:00+02:00         0.0                 2208.0   52.0    0.0
# 2023-08-02 23:00:00+02:00         0.0                 2084.0   53.0    0.0
# 2023-08-03 00:00:00+02:00         0.0                 1824.0   49.0    0.0
# 2023-08-03 01:00:00+02:00         0.0                 1789.0   52.0    0.0
#
#                            Wind Onshore
# 2023-07-18 02:00:00+02:00        1336.0
# 2023-07-18 03:00:00+02:00        1389.0
# 2023-07-18 04:00:00+02:00        1583.0
# 2023-07-18 05:00:00+02:00        1802.0
# 2023-07-18 06:00:00+02:00        1900.0
# ...                                 ...
# 2023-08-02 21:00:00+02:00        2502.0
# 2023-08-02 22:00:00+02:00        2494.0
# 2023-08-02 23:00:00+02:00        2463.0
# 2023-08-03 00:00:00+02:00        2268.0
# 2023-08-03 01:00:00+02:00        2180.0
#
# [384 rows x 5 columns]
# Data extraction (actual_generation) completed for country: SE_2
# Actual Generation for SE_3:
#                            Fossil Gas  Hydro Water Reservoir  Nuclear  Other  \
# 2023-07-18 02:00:00+02:00         0.0                  780.0   3963.0  187.0
# 2023-07-18 03:00:00+02:00         0.0                  761.0   3965.0  189.0
# 2023-07-18 04:00:00+02:00         0.0                  755.0   3967.0  189.0
# 2023-07-18 05:00:00+02:00         0.0                  783.0   3966.0  198.0
# 2023-07-18 06:00:00+02:00         0.0                  949.0   4110.0  229.0
# ...                               ...                    ...      ...    ...
# 2023-08-02 21:00:00+02:00         0.0                 1442.0   4253.0  162.0
# 2023-08-02 22:00:00+02:00         0.0                 1422.0   4253.0  165.0
# 2023-08-02 23:00:00+02:00         0.0                 1382.0   4281.0  163.0
# 2023-08-03 00:00:00+02:00         0.0                 1550.0   4264.0  170.0
# 2023-08-03 01:00:00+02:00         0.0                 1547.0   4262.0  170.0
#
#                            Solar  Wind Onshore
# 2023-07-18 02:00:00+02:00    0.0        2296.0
# 2023-07-18 03:00:00+02:00    0.0        2264.0
# 2023-07-18 04:00:00+02:00    1.0        2221.0
# 2023-07-18 05:00:00+02:00   13.0        2118.0
# 2023-07-18 06:00:00+02:00   46.0        2029.0
# ...                          ...           ...
# 2023-08-02 21:00:00+02:00    0.0         243.0
# 2023-08-02 22:00:00+02:00    0.0         274.0
# 2023-08-02 23:00:00+02:00    0.0         324.0
# 2023-08-03 00:00:00+02:00    0.0         372.0
# 2023-08-03 01:00:00+02:00    0.0         400.0
#
# [384 rows x 6 columns]
# Data extraction (actual_generation) completed for country: SE_3
# Actual Generation for SE_4:
#                            Fossil Gas  Hydro Water Reservoir  Other  Solar  \
# 2023-07-18 02:00:00+02:00         0.0                   42.0   65.0    0.0
# 2023-07-18 03:00:00+02:00         0.0                   46.0   65.0    0.0
# 2023-07-18 04:00:00+02:00         0.0                   42.0   65.0    0.0
# 2023-07-18 05:00:00+02:00         0.0                   47.0   66.0    4.0
# 2023-07-18 06:00:00+02:00         0.0                   50.0   68.0   26.0
# ...                               ...                    ...    ...    ...
# 2023-08-02 21:00:00+02:00         0.0                  134.0   66.0    0.0
# 2023-08-02 22:00:00+02:00         0.0                  120.0   66.0    0.0
# 2023-08-02 23:00:00+02:00         0.0                  108.0   66.0    0.0
# 2023-08-03 00:00:00+02:00         0.0                   81.0   75.0    0.0
# 2023-08-03 01:00:00+02:00         0.0                   80.0   75.0    0.0
#
#                            Wind Onshore
# 2023-07-18 02:00:00+02:00        1273.0
# 2023-07-18 03:00:00+02:00        1299.0
# 2023-07-18 04:00:00+02:00        1310.0
# 2023-07-18 05:00:00+02:00        1294.0
# 2023-07-18 06:00:00+02:00        1304.0
# ...                                 ...
# 2023-08-02 21:00:00+02:00         427.0
# 2023-08-02 22:00:00+02:00         455.0
# 2023-08-02 23:00:00+02:00         519.0
# 2023-08-03 00:00:00+02:00         570.0
# 2023-08-03 01:00:00+02:00         598.0
#
# [384 rows x 5 columns]
# Data extraction (actual_generation) completed for country: SE_4
# Actual Generation for SI:
#                            Biomass  Fossil Brown coal/Lignite  Fossil Gas  \
# 2023-07-18 02:00:00+02:00      6.0                      297.0        34.0
# 2023-07-18 03:00:00+02:00      6.0                      292.0        31.0
# 2023-07-18 04:00:00+02:00      6.0                      295.0        33.0
# 2023-07-18 05:00:00+02:00      6.0                      408.0        32.0
# 2023-07-18 06:00:00+02:00      6.0                      504.0        33.0
# ...                            ...                        ...         ...
# 2023-08-02 21:00:00+02:00      5.0                      398.0        27.0
# 2023-08-02 22:00:00+02:00      5.0                      298.0        24.0
# 2023-08-02 23:00:00+02:00      5.0                      291.0        24.0
# 2023-08-03 00:00:00+02:00      5.0                      297.0        24.0
# 2023-08-03 01:00:00+02:00      5.0                      243.0        26.0
#
#                            Fossil Oil  Hydro Pumped Storage  \
# 2023-07-18 02:00:00+02:00         0.0                   0.0
# 2023-07-18 03:00:00+02:00         0.0                   0.0
# 2023-07-18 04:00:00+02:00         0.0                   0.0
# 2023-07-18 05:00:00+02:00         0.0                   0.0
# 2023-07-18 06:00:00+02:00         0.0                   0.0
# ...                               ...                   ...
# 2023-08-02 21:00:00+02:00         0.0                   1.0
# 2023-08-02 22:00:00+02:00         0.0                   0.0
# 2023-08-02 23:00:00+02:00         0.0                   0.0
# 2023-08-03 00:00:00+02:00         0.0                   0.0
# 2023-08-03 01:00:00+02:00         0.0                   0.0
#
#                            Hydro Run-of-river and poundage  Nuclear  Solar  \
# 2023-07-18 02:00:00+02:00                            223.0    683.0    0.0
# 2023-07-18 03:00:00+02:00                            202.0    683.0    0.0
# 2023-07-18 04:00:00+02:00                            204.0    682.0    0.0
# 2023-07-18 05:00:00+02:00                            423.0    682.0    1.0
# 2023-07-18 06:00:00+02:00                            626.0    682.0   12.0
# ...                                                    ...      ...    ...
# 2023-08-02 21:00:00+02:00                            932.0    688.0    0.0
# 2023-08-02 22:00:00+02:00                            931.0    689.0    0.0
# 2023-08-02 23:00:00+02:00                            899.0    689.0    0.0
# 2023-08-03 00:00:00+02:00                            842.0    689.0    0.0
# 2023-08-03 01:00:00+02:00                            819.0    689.0    0.0
#
#                            Waste  Wind Onshore
# 2023-07-18 02:00:00+02:00    9.0           2.0
# 2023-07-18 03:00:00+02:00    9.0           2.0
# 2023-07-18 04:00:00+02:00    9.0           2.0
# 2023-07-18 05:00:00+02:00    8.0           2.0
# 2023-07-18 06:00:00+02:00   10.0           2.0
# ...                          ...           ...
# 2023-08-02 21:00:00+02:00    7.0           0.0
# 2023-08-02 22:00:00+02:00    6.0           0.0
# 2023-08-02 23:00:00+02:00    8.0           0.0
# 2023-08-03 00:00:00+02:00    8.0           0.0
# 2023-08-03 01:00:00+02:00    8.0           0.0
#
# [384 rows x 10 columns]
# Data extraction (actual_generation) completed for country: SI
# Actual Generation for SK:
#                                     Biomass Fossil Brown coal/Lignite  \
#                           Actual Aggregated         Actual Aggregated
# 2023-07-18 02:00:00+02:00             109.0                      81.0
# 2023-07-18 03:00:00+02:00             107.0                      81.0
# 2023-07-18 04:00:00+02:00             104.0                      81.0
# 2023-07-18 05:00:00+02:00             107.0                      81.0
# 2023-07-18 06:00:00+02:00             107.0                      81.0
# ...                                     ...                       ...
# 2023-08-02 21:00:00+02:00             107.0                     177.0
# 2023-08-02 22:00:00+02:00             107.0                     177.0
# 2023-08-02 23:00:00+02:00             106.0                     177.0
# 2023-08-03 00:00:00+02:00             106.0                     177.0
# 2023-08-03 01:00:00+02:00             108.0                     177.0
#
#                                  Fossil Gas  Fossil Hard coal  \
#                           Actual Aggregated Actual Aggregated
# 2023-07-18 02:00:00+02:00             347.0               0.0
# 2023-07-18 03:00:00+02:00             423.0               0.0
# 2023-07-18 04:00:00+02:00             428.0               0.0
# 2023-07-18 05:00:00+02:00             431.0               0.0
# 2023-07-18 06:00:00+02:00             424.0               0.0
# ...                                     ...               ...
# 2023-08-02 21:00:00+02:00             427.0               0.0
# 2023-08-02 22:00:00+02:00             403.0               0.0
# 2023-08-02 23:00:00+02:00             387.0               0.0
# 2023-08-03 00:00:00+02:00             203.0               0.0
# 2023-08-03 01:00:00+02:00              80.0               0.0
#
#                                  Fossil Oil Hydro Pumped Storage  \
#                           Actual Aggregated    Actual Aggregated
# 2023-07-18 02:00:00+02:00              46.0                  NaN
# 2023-07-18 03:00:00+02:00              46.0                  NaN
# 2023-07-18 04:00:00+02:00              46.0                  NaN
# 2023-07-18 05:00:00+02:00              46.0                  NaN
# 2023-07-18 06:00:00+02:00              46.0                  0.0
# ...                                     ...                  ...
# 2023-08-02 21:00:00+02:00              47.0                264.0
# 2023-08-02 22:00:00+02:00              47.0                  5.0
# 2023-08-02 23:00:00+02:00              47.0                  0.0
# 2023-08-03 00:00:00+02:00              47.0                  0.0
# 2023-08-03 01:00:00+02:00              47.0                  0.0
#
#                                              Hydro Run-of-river and poundage  \
#                           Actual Consumption               Actual Aggregated
# 2023-07-18 02:00:00+02:00               52.0                           192.0
# 2023-07-18 03:00:00+02:00              154.0                           194.0
# 2023-07-18 04:00:00+02:00              103.0                           206.0
# 2023-07-18 05:00:00+02:00                1.0                           202.0
# 2023-07-18 06:00:00+02:00                NaN                           245.0
# ...                                      ...                             ...
# 2023-08-02 21:00:00+02:00                NaN                           505.0
# 2023-08-02 22:00:00+02:00                NaN                           470.0
# 2023-08-02 23:00:00+02:00                NaN                           412.0
# 2023-08-03 00:00:00+02:00                NaN                           382.0
# 2023-08-03 01:00:00+02:00                NaN                           386.0
#
#                           Hydro Water Reservoir           Nuclear  \
#                               Actual Aggregated Actual Aggregated
# 2023-07-18 02:00:00+02:00                   2.0            2196.0
# 2023-07-18 03:00:00+02:00                   2.0            2202.0
# 2023-07-18 04:00:00+02:00                   2.0            2201.0
# 2023-07-18 05:00:00+02:00                   0.0            2205.0
# 2023-07-18 06:00:00+02:00                  31.0            2209.0
# ...                                         ...               ...
# 2023-08-02 21:00:00+02:00                  64.0            2150.0
# 2023-08-02 22:00:00+02:00                  50.0            2151.0
# 2023-08-02 23:00:00+02:00                  51.0            2154.0
# 2023-08-03 00:00:00+02:00                   2.0            2155.0
# 2023-08-03 01:00:00+02:00                   0.0            2155.0
#
#                                       Other   Other renewable  \
#                           Actual Aggregated Actual Aggregated
# 2023-07-18 02:00:00+02:00             108.0              46.0
# 2023-07-18 03:00:00+02:00             102.0              45.0
# 2023-07-18 04:00:00+02:00             100.0              45.0
# 2023-07-18 05:00:00+02:00             100.0              46.0
# 2023-07-18 06:00:00+02:00              99.0              46.0
# ...                                     ...               ...
# 2023-08-02 21:00:00+02:00             106.0              46.0
# 2023-08-02 22:00:00+02:00             104.0              46.0
# 2023-08-02 23:00:00+02:00             108.0              47.0
# 2023-08-03 00:00:00+02:00             112.0              47.0
# 2023-08-03 01:00:00+02:00             111.0              47.0
#
#                                       Solar      Wind Onshore
#                           Actual Aggregated Actual Aggregated
# 2023-07-18 02:00:00+02:00               0.0               1.0
# 2023-07-18 03:00:00+02:00               0.0               1.0
# 2023-07-18 04:00:00+02:00               0.0               1.0
# 2023-07-18 05:00:00+02:00               3.0               1.0
# 2023-07-18 06:00:00+02:00              21.0               0.0
# ...                                     ...               ...
# 2023-08-02 21:00:00+02:00               0.0               2.0
# 2023-08-02 22:00:00+02:00               0.0               2.0
# 2023-08-02 23:00:00+02:00               0.0               1.0
# 2023-08-03 00:00:00+02:00               0.0               2.0
# 2023-08-03 01:00:00+02:00               0.0               1.0
#
# [384 rows x 14 columns]
# Data extraction (actual_generation) completed for country: SK
# Data extraction (actual_generation) failed for country: TR
# Data extraction (actual_generation) failed for country: UA
# Data extraction (actual_generation) failed for country: UA_BEI
# Data extraction (actual_generation) failed for country: UA_DOBTPP
# Data extraction (actual_generation) failed for country: UA_IPS
